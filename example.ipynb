# %%
# Import class
from core.db_wd import DBWikidata

# Wikidb
db = DBWikidata()

# %%
# Get label of Belgium (Q31)
print(db.get_label("Q31"))
# Out:
# Belgium

# %%
# Gel label in all languages of Belgium (Q31)
print(db.get_labels("Q31"))
# Get label in a specific language
print(db.get_labels("Q31", "ja"))
# Out:
# {'el': 'Βέλγιο', 'ay': 'Bilkiya', 'pnb': 'بیلجیئم', 'na': 'Berdjiyum', 'mk': 'Белгија', 'bn': 'বেলজিয়াম', 'bpy': 'বেলজিয়াম', 'lt': 'Belgija', 'jam': 'Beljiom', 'sk': 'Belgicko', 'so': 'Beljim', 'tl': 'Belgium', 'uk': 'Бельгія', 'tt': 'Билгия', 'sc': 'Bèlgiu', 'bxr': 'Бельги', 'ff': 'Beljik', 'za': 'Bijliswz', 'yo': 'Bẹ́ljíọ̀m', 'ext': 'Bélgica', 'zea': 'Belhië', 'es': 'Bélgica', 'or': 'ବେଲଜିଅମ', 'myv': 'Бельгия Мастор', 'yi': 'בעלגיע', 'ga': 'An Bheilg', 'csb': 'Belgijskô', 'gag': 'Belgiya', 'oc': 'Belgica', 'pfl': 'Belgje', 'rw': 'Ububiligi', 'sco': 'Belgium', 'sgs': 'Belgėjė', 'ltg': 'Beļgeja', 'zh-sg': '比利时', 'tet': 'Béljika', 'az': 'Belçika', 'mzn': 'بلژیک', 'zh-hk': '比利時', 'bar': 'Bäigien', 'zh': '比利時', 'nl': 'België', 'lez': 'Бельгия', 'ast': 'Bélxica', 'bm': 'Bɛliziki', 'ta': 'பெல்ஜியம்', 'jv': 'Bélgié', 'inh': 'Бельги', 'hi': 'बेल्जियम', 'co': 'Belgica', 'mn': 'Бельги', 'pms': 'Belgi', 'om': 'Beeljiyeem', 'sl': 'Belgija', 'crh': 'Belçika', 'ms': 'Belgium', 'ro': 'Belgia', 'bho': 'बेल्जियम', 'av': 'Бельгия', 'lb': 'Belsch', 'en-gb': 'Belgium', 'kaa': 'Belgiya', 'ps': 'بلجیم', 'stq': 'Belgien', 'aeb-arab': 'بلجيكيا', 'lo': 'ປະເທດແບນຊິກ', 'sw': 'Ubelgiji', 'nds': 'Belgien', 'ksh': 'Belgien', 'bcl': 'Belhika', 'pag': 'Belhika', 'da': 'Belgien', 'ca': 'Bèlgica', 'crh-latn': 'Belçika', 'lv': 'Beļģija', 'rup': 'Belghia', 'ady': 'Белгие', 'ty': 'Peretita', 'gv': 'Yn Velg', 'kbp': 'Pɛliziki', 'pt-br': 'Bélgica', 'ar': 'بلجيكا', 'srn': 'Belgikondre', 'ch': 'Belgika', 'diq': 'Belçıka', 'pih': 'Beljum', 'szl': 'Belgijŏ', 'ace': 'Bèlgia', 'cv': 'Бельги', 'ak': 'Belgium', 'pt': 'Bélgica', 'io': 'Belgia', 'zh-my': '比利时', 'ru': 'Бельгия', 'tpi': 'Beljiam', 'th': 'ประเทศเบลเยียม', 'ha': 'Beljik', 'mg': 'Belzika', 'azb': 'بلژیک', 'an': 'Belchica', 'eml': 'Bélgi', 'hy': 'Բելգիա', 'vep': "Bel'gii", 'mai': 'बेल्जियम', 'nov': 'Belgia', 'ne': 'बेल्जियम', 'eo': 'Belgio', 'de': 'Belgien', 'ig': 'Belgium', 'sm': 'Peleseuma', 'pam': 'Belhika', 'war': 'Belhika', 'rmy': 'Beljiya', 'jbo': 'beldjym', 'kbd': 'Белгэ', 'ug': 'بېلگىيە', 'mdf': 'Бельгие', 'mwl': 'Bélgica', 'lrc': 'بلجیک', 'en': 'Belgium', 'as': 'বেলজিয়াম', 'bgn': 'بلجیم', 'os': 'Бельги', 'my': 'ဘယ်လ်ဂျီယမ်နိုင်ငံ', 'zh-cn': '比利时', 'sma': 'Belgia', 'dz': 'བེལ་ཇིཡམ', 'et': 'Belgia', 'cbk-zam': 'Bélgica', 'wo': 'Belsik', 'bug': 'Belgia', 'zh-tw': '比利時', 'nn': 'Belgia', 'chr': 'ᏇᎵᏥᎥᎻ', 'wuu': '比利时', 'lg': 'Bubirigi', 'nrm': 'Belgique', 'gl': 'Bélxica', 'zh-mo': '比利時', 'ee': 'Belgium', 'bi': 'Belgium', 'rm': 'Belgia', 'pdc': 'Belgien', 'ckb': 'بەلجیکا', 'ln': 'Bɛ́ljika', 'rn': 'Ububirigi', 'frp': 'Bèlg·ique', 'cy': 'Gwlad Belg', 'nso': 'Belgium', 'la': 'Belgica', 'ky': 'Бельгия', 'mr': 'बेल्जियम', 'fo': 'Belgia', 'fr': 'Belgique', 'got': '𐌱𐌰𐌹𐌻𐌲𐌰𐌻𐌰𐌽𐌳', 'is': 'Belgía', 'hsb': 'Belgiska', 'mt': 'Belġju', 'li': 'Belsj', 'vro': 'Belgiä', 'fi': 'Belgia', 'zh-hant': '比利時', 'id': 'Belgia', 'gom': 'बेल्जियम', 'gu': 'બેલ્જિયમ', 'su': 'Bélgia', 'ia': 'Belgica', 'pa': 'ਬੈਲਜੀਅਮ', 'wa': 'Beldjike', 'vi': 'Bỉ', 'ilo': 'Belhika', 'roa-tara': 'Bèlge', 'gom-latn': 'Belgium', 'af': 'België', 'ceb': 'Belhika', 'krc': 'Бельгия', 'sg': 'Bêleze', 'nb': 'Belgia', 'gsw': 'Belgie', 'si': 'බෙල්ජියම', 'zh-hans': '比利时', 'sv': 'Belgien', 'tum': 'Belgium', 'scn': 'Belgiu', 'kab': 'Biljik', 'bg': 'Белгия', 'eu': 'Belgika', 'xmf': 'ბელგია', 'vo': 'Belgän', 'it': 'Belgio', 'pap': 'Bélgika', 'gom-deva': 'बेल्जियम', 'haw': 'Pelekiuma', 'liv': 'Beļgij', 'pcd': 'Bergike', 'kl': 'Belgia', 'he': 'בלגיה', 'dsb': 'Belgiska', 'be-tarask': 'Бэльгія', 'vec': 'Belzo', 'cdo': 'Bī-lé-sì', 'nan': 'Pe̍k-ní-gī', 'gn': 'Véyhika', 'tg': 'Белгия', 'bs': 'Belgija', 'sd': 'بيلجيم', 'sh': 'Belgija', 'hu': 'Belgium', 'yue': '比利時', 'te': 'బెల్జియం', 'koi': 'Белгия', 'ba': 'Бельгия', 'sah': 'Бельгия', 'ang': 'Belgice', 'pi': 'बेल्जियम', 'uz': 'Belgiya', 'tk': 'Belgiýa', 'hif': 'Belgium', 'xal': 'Бельҗмудин Нутг', 'cu': 'Бєлгїѥ', 'new': 'बेल्जियम', 'fur': 'Belgjo', 'ht': 'Bèljik', 'sn': 'Belgium', 'tr': 'Belçika', 'ie': 'Belgia', 'gd': "A' Bheilg",  ...
# ベルギー

# %%
# Gel aliases in all languages of Belgium (Q31)
print(db.get_aliases("Q31"))
# Get aliases in a specific language of Belgium (Q31)
print(db.get_aliases("Q31", "ja"))
# Out:
# {'bg': ['Кралство Белгия'], 'en-gb': ['Southern Netherlands'], 'mk': ['Кралство Белгија'], 'zh-hk': ['比利時王國'], 'pt-br': ['Reino da Bélgica'], 'fr': ['BE', 'Belg.', 'Royaume de Belgique', 'be', '🇧🇪'], 'en': ['BE', 'BEL', 'Kingdom of Belgium', 'be', '🇧🇪'], 'zh': ['比利时', '比利时王国', '比利時王國'], 'tr': ['Belçika Krallığı'], 'jv': ['Bèlgi', 'Kraton Bélgié'], 'bho': ['बेलजियम', 'बेल्जियम राज', 'बेल्जीयम'], 'be-tarask': ['Бэльґія'], 'bn': ['বেলজিয়াম রাজ্য'], 'ta': ['பெல்சியம்', 'பெல்ஜிய பேரரசு'], 'zh-cn': ['比利时王国'], 'ko': ['벨기에 왕국', '벨기에왕국'], 'uk': ['Королівство Бельгія'], 'th': ['Belgium', 'ประเทศเบลเยี่ยม', 'ราชอาณาจักรเบลเยียม', 'ราชอาณาจักรเบลเยี่ยม', 'เบลเยียม', 'เบลเยี่ยม'], 'zh-my': ['比利时王国'], 'zh-tw': ['比利時王國'], 'ru': ['Belgique', 'Королевство Бельгия'], 'tl': ['Belhika'], 'lij': ['Belgiò'], 'zh-sg': ['比利时王国'], 'nds-nl': ['Belgie'], 'roa-tara': ['Belge', 'Belgio'], 'hy': ['Բելգիայի Թագավորություն'], 'es': ['BE', 'Belgica', 'Reino de Belgica', 'Reino de Bélgica'], 'pa': ['ਬੈਲਜੀਅਮ ਦਾ ਰਾਜ'], 'nan': ['Belgie', 'Belgien', 'Belgium', 'België', 'Pí-lī-sî', 'Tāi-pí-kok'], 'hr': ['Kraljevina Belgija'], 'pl': ['Królestwo Belgii'], 'zh-hant': ['比利時王國'], 'nb': ['Kongeriket Belgia'], 'zh-mo': ['比利時王國'], 'fi': ['Belgian kuningaskunta'], 'zh-hans': ['比利时王国'], 'nl': ['BE', 'BEL', 'Belgenland', 'Belgie', 'Koninkrijk België', 'be', '🇧🇪'], 'yue': ['Belgien', 'Belgique', 'Belgium', 'België', 'Koninkrijk België', 'Königreich Belgien', 'Royaume de Belgique'], 'ca': ['België', 'Bélgica', 'Estat belga', 'Regne de Bèlgica'], 'pam': ['Belgika', 'Belgium', 'Belika'], 'el': ['Βασίλειο του Βελγίου'], 'vls': ['BE'], 'ak': ['Ɔman Belgium'], 'ast': ['🇧🇪'], 'de': ['BE', 'BEL', 'Königreich Belgien', '🇧🇪'], 'hi': ['बेल्जियम बादशाहत', '🇧🇪'], 'mr': ['🇧🇪'], 'ne': ['🇧🇪'], 'sa': ['🇧🇪'], 'ja': ['ベルギー王国'], 'da': ['Belgique', 'België', 'Kongeriget Belgien', 'Koninkrijk België', 'Royaume de Belgique'], 'se': ['Belgia gonagasriika'], 'smn': ['Belgia kunâgâskodde'], 'sms': ['Belgia koonǥõskåʹdd'], 'szl': ['Krōlestwo Belgije'], 'mt': ['Renju tal-Belġju'], 'vec': ['BE', 'BEL', 'Bèlzega'], 'ku': ['Belgiya'], 'av': ['Белген'], 'bar': ['Bejgien'], 'bi': ['Beljiom'], 'frp': ['Bèlgica'], 'kbd': ['Белгиэ'], 'ksh': ['Beljie'], 'mzn': ['بلجیک'], 'pfl': ['Belgien'], 'ps': ['بېلجیم'], 'sat': ['ᱵᱮᱞᱡᱤᱭᱟᱢ'], 'tt': ['Бельгия'], 'tw': ['Bɛlgyiom'], 'zea': ['België'], 'ban': ['Bélgia'], 'gsw': ['Belgien'], 'grc': ['Βελγική'], 'ckb': ['بەلژیک', 'بەلژیکا'], 'frr': ['Belgien/fe'], 'km': ['បែលហ្សិក'], 'ur': ['بلجئیم', 'بیلجیم', 'مملکت بیلجیئم']}
# ['ベルギー王国']

# %%
# Gel descriptions in all languages of Belgium (Q31)
print(db.get_descriptions("Q31"))
# Get descriptions in a specific language of Belgium (Q31)
print(db.get_descriptions("Q31", "ja"))
# Out:
# {'cy': 'wlad yn Ewrop', 'sk': 'štát v Europe', 'mk': 'земја во Европа', 'vls': "pays d'europe", 'fr': "État d'Europe occidentale", 'zh': '西歐國家', 'it': "stato dell'Europa occidentale, membro dell'Unione europea", 'jv': 'nagara ing Éropah', 'pl': 'państwo w Europie', 'bn': 'পশ্চিম ইউরোপের যুক্তরাষ্ট্রীয় সাংবিধানিক রাজতন্ত্র', 'fi': 'valtio Länsi-Euroopassa', 'en-ca': 'constitutional monarchy in Western Europe', 'uk': 'держава у Західній Європі', 'id': 'negara di Eropa Barat', 'vi': 'một quốc gia có chủ quyền tại Tây Âu', 'pt': 'país da Europa', 'pa': "ਯੂਰਪ 'ਚ ਦੇਸ਼", 'zh-my': '西欧国家', 'ru': 'государство в Западной Европе', 'de-ch': 'Staat in Westeuropa', 'fa': 'کشوری در قاره اروپا', 'th': 'ราชอาณาจักรในยุโรปตะวันตก', 'zh-tw': '西歐國家', 'ilo': 'pederal nga estado idiay Lumaud nga Europa', 'es': 'país de Europa', 'tr': "Batı Avrupa'da bir ülke", 'hy': 'դաշնային թագավորություն Եվրոպայում', 'de-at': 'Staat in Westeuropa', 'hu': 'állam Nyugat-Európában', 'zh-hant': '西歐國家', 'nb': 'land i Europa', 'gsw': 'Staat in Mitteleuropa', 'eo': 'federacio en Eŭropo', 'ne': 'युरोपको देश', 'zh-hans': '西欧国家', 'sv': 'konstitutionell monarki i Västeuropa', 'nl': 'federale staat in West-Europa', 'de': 'föderaler Staat in Westeuropa', 'bg': 'държава в Западна Европа', 'la': 'civitas Europae', 'scn': "paìsi di l'Europa di punenti", 'el': 'χώρα της δυτικής Ευρώπης', 'tet': 'rai iha Europa', 'ar': 'دولة في أوروبا الغربية', 'zh-hk': '西歐國家', 'pt-br': 'país da Europa', 'sr-el': 'država u zapadnoj Evropi', 'kn': 'ಪಶ್ಚಿಮ ಯುರೋಪಿನ ಸಾಂವಿಧಾನಿಕ ರಾಜಾಡಳಿತ ಹೊಂದಿರುವ ದೇಶ', 'en': 'country in western Europe', 'ta': 'மேற்கு ஐரோப்பிய நாடு', 'zh-cn': '西欧国家', 'hsb': 'stat w zapadnej Europje', 'hi': 'पश्चिमी यूरोप में एक संघीय संवैधानिक राजशाही', 'cs': 'stát v Evropě', 'zh-sg': '西欧国家', 'he': 'מדינה באירופה', 'ro': 'stat în Europa de Vest', 'bho': 'पच्छिमी यूरोप में एगो संघीय संबैधानिक राजतंत्र', 'lb': 'Staat an Europa', 'sr-ec': 'држава у западној Европи', 'en-gb': 'country in Europe', 'hr': 'država u zapadnoj Europi', 'ja': '西ヨーロッパに位置する国家', 'ko': '서유럽에 위치한 국가', 'te': 'ఐరోపా లోని ఒక దేశం', 'br': 'stad Europa', 'zh-mo': '西歐國家', 'sw': 'nchi katika Ulaya Magharibi', 'nds': 'Staat in Mitteleuropa', 'da': 'Et land i Europa', 'sr': 'држава у западној Европи', 'ca': "país d'Europa", 'lv': 'Valsts Eiropā', 'ie': 'Un Land in Europa', 'ml': 'വടക്കുപടിഞ്ഞാറേ യൂറോപ്പിൽ ഉള്ള ഒരു രാജ്യം', 'se': 'riika Eurohpás', 'az': 'Qərbi Avropada konstusiyalı monarxiya ölkə', 'ht': 'peyi ki nan pati oksidantal kontinan Ewopeyen', 'wa': "payis di l' Urope do Coûtchant", 'gl': 'país europeo', 'sd': 'اولاھين يورپ ۾ ملڪ', 'vec': 'Stato del Nord Eoropa', 'ku': 'Welatekî Ewropayê', 'ckb': 'دەوڵەتی باڵادەست لە ڕۆژاوای ئەورووپا', 'mr': 'पश्चिम यूरपातील एक देश', 'bs': 'država u zapadnoj Evropi', 'szl': 'państwo we zachodnij Ojropie', 'pap': 'pais na Oropa', 'mt': 'pajjiż fl-Ewropa tal-Punent', 'yue': '西歐國家', 'be': 'краіна', 'be-tarask': 'краіна', 'grc': 'Εὐρώπης χώρα', 'pnb': 'لہندا یورپ دا اک دیش', 'ur': 'مغربی یورپ کا ایک ملک'}
# 西ヨーロッパに位置する国家

# %%
# Gel sitelinks of Belgium (Q31)
print(db.get_sitelinks("Q31"))
# Out:
# {'itwikivoyage': 'Belgio', 'zhwikivoyage': '比利时', 'ruwikivoyage': 'Бельгия', 'fawikiquote': 'بلژیک', 'dewikivoyage': 'Belgien', 'enwikivoyage': 'Belgium', 'hewikivoyage': 'בלגיה', 'eowikinews': 'Kategorio:Belgujo', 'frwikinews': 'Catégorie:Belgique', 'trwikinews': 'Kategori:Belçika', 'plwikiquote': 'Belgia', 'nlwikinews': 'Categorie:België', 'rowikivoyage': 'Belgia', 'svwikivoyage': 'Belgien', 'arwikinews': 'تصنيف:بلجيكا', 'frwikivoyage': 'Belgique', 'nlwikibooks': 'Atlas van Europa/België', 'enwikiquote': 'Belgium', 'rowikinews': 'Categorie:Belgia', 'jawikinews': 'カテゴリ:ベルギー', 'itwikiquote': 'Belgio', 'ptwikibooks': 'Bélgica', 'viwikivoyage': 'Bỉ', 'kowikinews': '분류:벨기에', 'ptwikinews': 'Categoria:Bélgica', 'fawikivoyage': 'بلژیک', 'fiwikinews': 'Luokka:Belgia', 'plwikivoyage': 'Belgia', 'cawikinews': 'Categoria:Bèlgica', 'srwikinews': 'Категорија:Белгија', 'ptwikivoyage': 'Bélgica', 'enwikinews': 'Category:Belgium', 'svwikinews': 'Kategori:Belgien', 'eswikivoyage': 'Bélgica', 'elwikinews': 'Κατηγορία:Βέλγιο', 'bswikinews': 'Kategorija:Belgija', 'sqwikinews': 'Kategoria:Belgjikë', 'eswikinews': 'Categoría:Bélgica', 'nlwikiquote': 'België', 'ukwikinews': 'Категорія:Бельгія', 'hewikiquote': 'בלגיה', 'cswikinews': 'Kategorie:Belgie', 'nowikinews': 'Kategori:Belgia', 'zhwikinews': 'Category:比利時', 'ukwikivoyage': 'Бельгія', 'hywikiquote': 'Բելգիա', 'frwikiquote': 'Belgique', 'nlwikivoyage': 'België', 'eswikiquote': 'Bélgica', 'huwikinews': 'Kategória:Belgium', 'plwikinews': 'Kategoria:Belgia', 'ruwikinews': 'Категория:Бельгия', 'tawikinews': 'பகுப்பு:பெல்ஜியம்', 'dewikinews': 'Kategorie:Belgien', 'liwikibooks': 'Belsj', 'itwikinews': 'Categoria:Belgio', 'elwikivoyage': 'Βέλγιο', 'fawikinews': 'رده:بلژیک', 'fiwikivoyage': 'Belgia', 'commonswiki': 'België - Belgique - Belgien', 'arwikiquote': 'بلجيكا', 'jawikivoyage': 'ベルギー', 'eowikivoyage': 'Belgio', 'trwikivoyage': 'Belçika', 'hewikinews': 'קטגוריה:בלגיה', 'eowikiquote': 'Belgio', 'etwikiquote': 'Belgia', 'enwiki': 'Belgium', 'dewiki': 'Belgien', 'frwiki': 'Belgique', 'eswiki': 'Bélgica', 'ruwiki': 'Бельгия', 'itwiki': 'Belgio', 'jawiki': 'ベルギー', 'nlwiki': 'België', 'plwiki': 'Belgia', 'ptwiki': 'Bélgica', 'zhwiki': '比利时', 'svwiki': 'Belgien', 'fawiki': 'بلژیک', 'hewiki': 'בלגיה', 'trwiki': 'Belçika', 'huwiki': 'Belgium', 'fiwiki': 'Belgia', 'arwiki': 'بلجيكا', 'viwiki': 'Bỉ', 'nowiki': 'Belgia', 'ukwiki': 'Бельгія', 'kowiki': '벨기에', 'cawiki': 'Bèlgica', 'cswiki': 'Belgie', 'srwiki': 'Белгија', 'rowiki': 'Belgia', 'idwiki': 'Belgia', 'dawiki': 'Belgien', 'simplewiki': 'Belgium', 'bgwiki': 'Белгия', 'abwiki': 'Бельгиа', 'acewiki': 'Bèlgia', 'adywiki': 'Белгие', 'afwiki': 'België', 'akwiki': 'Belgium', 'alswiki': 'Belgien', 'amwiki': 'ቤልጅግ', 'amiwiki': 'Belguim', 'anwiki': 'Belchica', 'angwiki': 'Belgice', 'arcwiki': 'ܒܠܓܝܩܐ', 'arywiki': 'بلجيكا', 'arzwiki': 'بلجيكا', 'astwiki': 'Bélxica', 'avwiki': 'Белген', 'avkwiki': 'Belga', 'awawiki': 'बेल्जियम', 'aywiki': 'Bilkiya', 'azwiki': 'Belçika', 'azbwiki': 'بلژیک', 'bawiki': 'Бельгия', 'banwiki': 'Bélgia', 'barwiki': 'Bejgien', 'bat_smgwiki': 'Belgėjė', 'bclwiki': 'Belhika', 'bewiki': 'Бельгія', 'be_x_oldwiki': 'Бэльгія', 'bhwiki': 'बेल्जियम', 'biwiki': 'Beljiom', 'bmwiki': 'Bɛliziki', 'bnwiki': 'বেলজিয়াম', 'bowiki': 'པེར་ཅིན།', 'bpywiki': 'বেলজিয়াম', 'brwiki': 'Belgia', 'bswiki': 'Belgija', 'bugwiki': 'Belgia', 'bxrwiki': 'Бельги', 'cbk_zamwiki': 'Bélgica', 'cdowiki': 'Bī-lé-sì', 'cewiki': 'Бельги', 'cebwiki': 'Belhika', 'chwiki': 'Belgika', 'chrwiki': 'ᏇᎵᏥᎥᎻ', 'ckbwiki': 'بەلجیکا', 'cowiki': 'Belgica', 'crhwiki': 'Belçika', 'csbwiki': 'Belgijskô', 'cuwiki': 'Бєлгїѥ', 'cvwiki': 'Бельги', 'cywiki': 'Gwlad Belg', 'diqwiki': 'Belçıka', 'dsbwiki': 'Belgiska', 'dtywiki': 'बेल्जियम', 'dvwiki': 'ބެލްޖިއަމް', 'dzwiki': 'བེལ་ཇིཡམ', 'eewiki': 'Belgium', 'elwiki': 'Βέλγιο', 'emlwiki': 'Bélgi', 'eowiki': 'Belgio', 'etwiki': 'Belgia', 'euwiki': 'Belgika', 'extwiki': 'Bélgica', 'ffwiki': 'Beljik', 'fiu_vrowiki': 'Belgiä', 'fowiki': 'Belgia', 'frpwi ...

# %%
# Gel Wikipedia title of Belgium (Q31)
print(db.get_wikipedia_title("ja", "Q31"))
# Gel Wikipedia link of Belgium (Q31)
print(db.get_wikipedia_link("ja", "Q31"))
# Out:
# ベルギー
# https://ja.wikipedia.org/wiki/ベルギー

# %%
# Gel claims of Belgium (Q31)
print(db.get_claims("Q31"))
# Out:
# {'string': {'P2924': [{'value': '4075290'}], 'P1667': [{'value': '1000063'}], 'P3348': [{'value': '2020'}], 'P349': [{'value': '00560624'}], 'P3365': [{'value': 'belgio'}], 'P3221': [{'value': 'destination/belgium'}], 'P2581': [{'value': '00009714n', 'references': [{'wikibase-entityid': {'P248': ['Q4837690']}}]}], 'P1566': [{'value': '2802361'}], 'P227': [{'value': '4005406-8', 'references': [{'wikibase-entityid': {'P143': ['Q48183']}}]}], 'P487': [{'value': '🇧🇪'}], 'P3916': [{'value': 'concept893'}], 'P395': [{'value': 'B'}], 'P3238': [{'value': '0'}], 'P298': [{'value': 'BEL'}], 'P3417': [{'value': 'Belgium'}, {'value': 'Belge'}], 'P998': [{'value': 'Regional/Europe/Belgium/'}], 'P486': [{'value': 'D001530'}], 'P3106': [{'value': 'world/belgium'}], 'P982': [{'value': '5b8a5ee5-0bb3-34cf-9a75-c27c44e341fc', 'references': [{'wikibase-entityid': {'P248': ['Q14005']}}]}], 'P94': [{'value': 'Great coat of arms of Belgium.svg'}, {'value': 'State Coat of Arms of Belgium.svg'}, {'value': 'Arms of Belgium (with crown).svg'}, {'value': 'Royal Arms of Belgium.svg'}], 'P2981': [{'value': 'B', 'references': [{'string': {'P854': ['http://otif.org/fileadmin/user_upload/otif_verlinkte_files/06_tech_zulass/05_Reglementation_en_vigueur/Neu_ab_01_01_2015/UTP_MARKING_2015_e_in_force.pdf']}}]}], 'P3422': [{'value': '99131'}], 'P935': [{'value': 'België - Belgique - Belgien'}], 'P214': [{'value': '144248059'}], 'P5180': [{'value': 'belgium'}], 'P605': [{'value': 'BE'}], 'P4613': [{'value': '39061'}], 'P3911': [{'value': '17201-5'}], 'P3984': [{'value': 'belgium', 'references': [{'time': {'P813': ['2018-05-06']}}]}], 'P856': [{'value': 'https://www.belgium.be/nl'}, {'value': 'https://www.belgium.be/en'}, {'value': 'https://www.belgium.be/fr'}, {'value': 'https://www.belgium.be/de'}], 'P3896': [{'value': 'Data:Belgium.map'}], 'P949': [{'value': '000981380', 'references': [{'wikibase-entityid': {'P248': ['Q54919']}, 'string': {'P214': ['259064514'], 'P854': ['http://www.viaf.org/viaf/259064514/']}, 'time': {'P813': ['2016-04-01']}}]}], 'P402': [{'value': '52411'}], 'P4725': [{'value': '19875'}], 'P3068': [{'value': 'BE'}], 'P691': [{'value': 'ge128735'}], 'P906': [{'value': '140654'}], 'P3241': [{'value': '02395a'}], 'P2258': [{'value': '206'}], 'P2979': [{'value': '205'}], 'P1225': [{'value': '10035761'}], 'P5198': [{'value': '294901094', 'references': [{'wikibase-entityid': {'P248': ['Q54856619']}, 'time': {'P813': ['2018-06-13']}}]}], 'P1315': [{'value': '1028458'}], 'P3612': [{'value': 'pays/belgique'}], 'P268': [{'value': '15238382r', 'references': [{'wikibase-entityid': {'P248': ['Q54919']}, 'string': {'P214': ['144248059']}, 'time': {'P813': ['2018-10-07']}}]}], 'P242': [{'value': 'EU-Belgium.svg'}, {'value': 'Belgium (orthographic projection).svg'}], 'P1617': [{'value': 'e68c5b82-50e8-47d8-953c-bf61a2de0a85'}], 'P1036': [{'value': '2--493'}], 'P3743': [{'value': '2.16.56'}], 'P984': [{'value': 'BEL', 'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]}], 'P2163': [{'value': '1210278'}], 'P4342': [{'value': 'Belgia'}], 'P4427': [{'value': '766'}], 'P5573': [{'value': '2969', 'references': [{'string': {'P854': ['https://www.archinform.net/service/wd_aiort.php']}, 'wikibase-entityid': {'P248': ['Q265049']}, 'time': {'P813': ['2018-08-05']}}]}], 'P1417': [{'value': 'place/Belgium'}], 'P4629': [{'value': 'Belgium'}], 'P948': [{'value': 'Belgium Banner.jpg'}], 'P2347': [{'value': '105206'}], 'P1296': [{'value': '0008719'}], 'P373': [{'value': 'Belgium'}], 'P6150': [{'value': '6974'}], 'P4672': [{'value': '3b33aed2-40bc-48a9-baa0-3ff78ba4a5aa', 'references': [{'wikibase-entityid': {'P143': ['Q28054658']}}]}], 'P2982': [{'value': '88', 'references': [{'string': {'P854': ['http://uic.org/country-codes']}}]}], 'P3222': [{'value': 'belgien'}], 'P898': [{'value': 'ˈbɛlgɪɑ'}, {'value': 'ˈbʲelʲɡʲɪjə'}, {'value': 'bɛl.ʒik'}], 'P299': [{'value': '056'}], 'P269': [{'value': '026360608'}], 'P5247': [{'value': '3035-254'}], 'P3024': [{'value': 'BEL'}] ...

# %%
# Get all information of Belgium (Q31)
print(db.get_item("Q31"))
# Out:
# {'label': 'Belgium', 'labels': {'el': 'Βέλγιο', 'ay': 'Bilkiya', 'pnb': 'بیلجیئم', 'na': 'Berdjiyum', 'mk': 'Белгија', 'bn': 'বেলজিয়াম', 'bpy': 'বেলজিয়াম', 'lt': 'Belgija', 'jam': 'Beljiom', 'sk': 'Belgicko', 'so': 'Beljim', 'tl': 'Belgium', 'uk': 'Бельгія', 'tt': 'Билгия', 'sc': 'Bèlgiu', 'bxr': 'Бельги', 'ff': 'Beljik', 'za': 'Bijliswz', 'yo': 'Bẹ́ljíọ̀m', 'ext': 'Bélgica', 'zea': 'Belhië', 'es': 'Bélgica', 'or': 'ବେଲଜିଅମ', 'myv': 'Бельгия Мастор', 'yi': 'בעלגיע', 'ga': 'An Bheilg', 'csb': 'Belgijskô', 'gag': 'Belgiya', 'oc': 'Belgica', 'pfl': 'Belgje', 'rw': 'Ububiligi', 'sco': 'Belgium', 'sgs': 'Belgėjė', 'ltg': 'Beļgeja', 'zh-sg': '比利时', 'tet': 'Béljika', 'az': 'Belçika', 'mzn': 'بلژیک', 'zh-hk': '比利時', 'bar': 'Bäigien', 'zh': '比利時', 'nl': 'België', 'lez': 'Бельгия', 'ast': 'Bélxica', 'bm': 'Bɛliziki', 'ta': 'பெல்ஜியம்', 'jv': 'Bélgié', 'inh': 'Бельги', 'hi': 'बेल्जियम', 'co': 'Belgica', 'mn': 'Бельги', 'pms': 'Belgi', 'om': 'Beeljiyeem', 'sl': 'Belgija', 'crh': 'Belçika', 'ms': 'Belgium', 'ro': 'Belgia', 'bho': 'बेल्जियम', 'av': 'Бельгия', 'lb': 'Belsch', 'en-gb': 'Belgium', 'kaa': 'Belgiya', 'ps': 'بلجیم', 'stq': 'Belgien', 'aeb-arab': 'بلجيكيا', 'lo': 'ປະເທດແບນຊິກ', 'sw': 'Ubelgiji', 'nds': 'Belgien', 'ksh': 'Belgien', 'bcl': 'Belhika', 'pag': 'Belhika', 'da': 'Belgien', 'ca': 'Bèlgica', 'crh-latn': 'Belçika', 'lv': 'Beļģija', 'rup': 'Belghia', 'ady': 'Белгие', 'ty': 'Peretita', 'gv': 'Yn Velg', 'kbp': 'Pɛliziki', 'pt-br': 'Bélgica', 'ar': 'بلجيكا', 'srn': 'Belgikondre', 'ch': 'Belgika', 'diq': 'Belçıka', 'pih': 'Beljum', 'szl': 'Belgijŏ', 'ace': 'Bèlgia', 'cv': 'Бельги', 'ak': 'Belgium', 'pt': 'Bélgica', 'io': 'Belgia', 'zh-my': '比利时', 'ru': 'Бельгия', 'tpi': 'Beljiam', 'th': 'ประเทศเบลเยียม', 'ha': 'Beljik', 'mg': 'Belzika', 'azb': 'بلژیک', 'an': 'Belchica', 'eml': 'Bélgi', 'hy': 'Բելգիա', 'vep': "Bel'gii", 'mai': 'बेल्जियम', 'nov': 'Belgia', 'ne': 'बेल्जियम', 'eo': 'Belgio', 'de': 'Belgien', 'ig': 'Belgium', 'sm': 'Peleseuma', 'pam': 'Belhika', 'war': 'Belhika', 'rmy': 'Beljiya', 'jbo': 'beldjym', 'kbd': 'Белгэ', 'ug': 'بېلگىيە', 'mdf': 'Бельгие', 'mwl': 'Bélgica', 'lrc': 'بلجیک', 'en': 'Belgium', 'as': 'বেলজিয়াম', 'bgn': 'بلجیم', 'os': 'Бельги', 'my': 'ဘယ်လ်ဂျီယမ်နိုင်ငံ', 'zh-cn': '比利时', 'sma': 'Belgia', 'dz': 'བེལ་ཇིཡམ', 'et': 'Belgia', 'cbk-zam': 'Bélgica', 'wo': 'Belsik', 'bug': 'Belgia', 'zh-tw': '比利時', 'nn': 'Belgia', 'chr': 'ᏇᎵᏥᎥᎻ', 'wuu': '比利时', 'lg': 'Bubirigi', 'nrm': 'Belgique', 'gl': 'Bélxica', 'zh-mo': '比利時', 'ee': 'Belgium', 'bi': 'Belgium', 'rm': 'Belgia', 'pdc': 'Belgien', 'ckb': 'بەلجیکا', 'ln': 'Bɛ́ljika', 'rn': 'Ububirigi', 'frp': 'Bèlg·ique', 'cy': 'Gwlad Belg', 'nso': 'Belgium', 'la': 'Belgica', 'ky': 'Бельгия', 'mr': 'बेल्जियम', 'fo': 'Belgia', 'fr': 'Belgique', 'got': '𐌱𐌰𐌹𐌻𐌲𐌰𐌻𐌰𐌽𐌳', 'is': 'Belgía', 'hsb': 'Belgiska', 'mt': 'Belġju', 'li': 'Belsj', 'vro': 'Belgiä', 'fi': 'Belgia', 'zh-hant': '比利時', 'id': 'Belgia', 'gom': 'बेल्जियम', 'gu': 'બેલ્જિયમ', 'su': 'Bélgia', 'ia': 'Belgica', 'pa': 'ਬੈਲਜੀਅਮ', 'wa': 'Beldjike', 'vi': 'Bỉ', 'ilo': 'Belhika', 'roa-tara': 'Bèlge', 'gom-latn': 'Belgium', 'af': 'België', 'ceb': 'Belhika', 'krc': 'Бельгия', 'sg': 'Bêleze', 'nb': 'Belgia', 'gsw': 'Belgie', 'si': 'බෙල්ජියම', 'zh-hans': '比利时', 'sv': 'Belgien', 'tum': 'Belgium', 'scn': 'Belgiu', 'kab': 'Biljik', 'bg': 'Белгия', 'eu': 'Belgika', 'xmf': 'ბელგია', 'vo': 'Belgän', 'it': 'Belgio', 'pap': 'Bélgika', 'gom-deva': 'बेल्जियम', 'haw': 'Pelekiuma', 'liv': 'Beļgij', 'pcd': 'Bergike', 'kl': 'Belgia', 'he': 'בלגיה', 'dsb': 'Belgiska', 'be-tarask': 'Бэльгія', 'vec': 'Belzo', 'cdo': 'Bī-lé-sì', 'nan': 'Pe̍k-ní-gī', 'gn': 'Véyhika', 'tg': 'Белгия', 'bs': 'Belgija', 'sd': 'بيلجيم', 'sh': 'Belgija', 'hu': 'Belgium', 'yue': '比利時', 'te': 'బెల్జియం', 'koi': 'Белгия', 'ba': 'Бельгия', 'sah': 'Бельгия', 'ang': 'Belgice', 'pi': 'बेल्जियम', 'uz': 'Belgiya', 'tk': 'Belgiýa', 'hif': 'Belgium', 'xal': 'Бельҗмудин Нутг', 'cu': 'Бєлгїѥ', 'new': 'बेल्जियम', 'fur': 'Belgjo', 'ht': 'Bèljik', 'sn': 'Belgium', 'tr': 'Belçika', 'ie' ...

# %%
# Get redirect of Belgium (Q31)
redirects = db.get_redirect_of("Q31")
print(redirects)
# Out:
# ['Q2766311', 'Q19747260', 'Q15719907', 'Q20086775', 'Q25653510', 'Q25705716']

# %%
# Get redirect of
print(db.get_redirect(redirects[0]))
# Out:
# Q31

# %%
# Get instance of Belgium (Q31)
instance_ofs = db.get_instance_of("Q31")
for i, wd_id in enumerate(instance_ofs):
    print(f"{i}: {wd_id} - {db.get_label(wd_id)}")
# Out:
# 0: Q3624078 - sovereign state
# 1: Q43702 - None
# 2: Q6256 - country
# 3: Q20181813 - colonial power
# 4: Q185441 - Member state of the European Union
# 5: Q1250464 - None

# %%
# Get subclass of Belgium (Q31)
print(db.get_subclass_of("Q31"))
# Out:
# None

# %%
# Get all types of Belgium (Q31)
types = db.get_all_types("Q31")
for i, wd_id in enumerate(types):
    print(f"{i}: {wd_id} - {db.get_label(wd_id)}")
# Out:
# 0: Q1250464 - None
# 1: Q43229 - None
# 2: Q1896989 - None
# 3: Q6256 - country
# 4: Q185441 - Member state of the European Union
# 5: Q3624078 - sovereign state
# 6: Q177634 - None
# 7: Q9200127 - None
# 8: Q43702 - None
# 9: Q1063239 - polity
# 10: Q1646605 - member state
# 11: Q96196009 - state (former or current)
# 12: Q155076 - None
# 13: Q1048835 - None
# 14: Q7275 - state
# 15: Q20181813 - colonial power
# 16: Q56061 - administrative territorial entity

# %%
# Print provenance list
def print_provenance_list(iter_obj):
    for i, provenance in enumerate(iter_obj):
        if i > 3:
            break
        subject = provenance["subject"]
        predicate = provenance["predicate"]
        value = provenance["value"]
        reference_node = provenance["reference"]
        print(
            f"{i+1}: <{subject}[{db.get_label(subject)}] - {predicate}[{db.get_label(predicate)}] - {value}>]]"
        )
        print(f"  Reference Node:")
        for ref_type, ref_objs in reference_node.items():
            for ref_prop, ref_v in ref_objs.items():
                print(f"    {ref_prop}[{db.get_label(ref_prop)}]: {ref_v}")
    print()


# Get provenance of Belgium (Q31)
print_provenance_list(db.get_provenance_analysis("Q31"))
# Get provenance of Belgium (Q31), and Tokyo (Q1490)
print_provenance_list(db.get_provenance_analysis(["Q31", "Q1490"]))
# Get provenance of all items
print_provenance_list(db.get_provenance_analysis())
# Out:
# 1: <Q31[Belgium] - P2581[BabelNet ID] - 00009714n>]]
#   Reference Node:
#     P248[stated in]: ['Q4837690']
# 2: <Q31[Belgium] - P227[GND ID] - 4005406-8>]]
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q48183']
# 3: <Q31[Belgium] - P982[MusicBrainz area ID] - 5b8a5ee5-0bb3-34cf-9a75-c27c44e341fc>]]
#   Reference Node:
#     P248[stated in]: ['Q14005']
# 4: <Q31[Belgium] - P2981[UIC alphabetical country code] - B>]]
#   Reference Node:
#     P854[None]: ['http://otif.org/fileadmin/user_upload/otif_verlinkte_files/06_tech_zulass/05_Reglementation_en_vigueur/Neu_ab_01_01_2015/UTP_MARKING_2015_e_in_force.pdf']
#
# 1: <Q31[Belgium] - P2581[BabelNet ID] - 00009714n>]]
#   Reference Node:
#     P248[stated in]: ['Q4837690']
# 2: <Q31[Belgium] - P227[GND ID] - 4005406-8>]]
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q48183']
# 3: <Q31[Belgium] - P982[MusicBrainz area ID] - 5b8a5ee5-0bb3-34cf-9a75-c27c44e341fc>]]
#   Reference Node:
#     P248[stated in]: ['Q14005']
# 4: <Q31[Belgium] - P2981[UIC alphabetical country code] - B>]]
#   Reference Node:
#     P854[None]: ['http://otif.org/fileadmin/user_upload/otif_verlinkte_files/06_tech_zulass/05_Reglementation_en_vigueur/Neu_ab_01_01_2015/UTP_MARKING_2015_e_in_force.pdf']
#
# 1: <Q1[universe] - P373[None] - Universe>]]
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q328']
# 2: <Q1[universe] - P18[None] - Hubble ultra deep field.jpg>]]
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q48183']
#     P4656[Wikimedia import URL]: ['https://de.wikipedia.org/w/index.php?title=Universum&oldid=211589784']
#     P813[None]: ['2021-05-22']
# 3: <Q1[universe] - P18[None] - CMB Timeline300 no WMAP.jpg>]]
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q328']
#     P4656[Wikimedia import URL]: ['https://en.wikipedia.org/w/index.php?title=Universe&oldid=1023252612']
#     P813[None]: ['2021-05-22']
# 4: <Q1[universe] - P18[None] - NASA-HS201427a-HubbleUltraDeepField2014-20140603.jpg>]]
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q328']
#     P4656[Wikimedia import URL]: ['https://en.wikipedia.org/w/index.php?title=Universe&oldid=1023252612']
#     P813[None]: ['2021-05-22']

# %%
# import config as cf
# import time
#
#
# def find_wikidata_items_haswbstatements(params):
#     start = time.time()
#     wd_ids = db.get_haswbstatement(params)
#     end = time.time() - start
#     print(params)
#     print(f"Total: {len(wd_ids):,} in {end:.2f}s")
#     for i, wd_id in enumerate(wd_ids[:3]):
#         print(f"{i+1}. {wd_id} - {db.get_label(wd_id)}")
#     print(f"{4}. ...")
#     print()
#
#
# find_wikidata_items_haswbstatements([
#     # ??? - Graduate University for Advanced Studies
#     [cf.ATTR_OPTS.AND, None, "Q2983844"]
# ])
#
# find_wikidata_items_haswbstatements([
#         # instance of - human
#         [cf.ATTR_OPTS.AND, "P31", "Q5"],
#         # gender - male
#         [cf.ATTR_OPTS.AND, "P21", "Q6581097"],
#         # educated at - Todai
#         [cf.ATTR_OPTS.AND, "P69", "Q7842"],
#         # employer - Graduate University for Advanced Studies
#         [cf.ATTR_OPTS.AND, "P108", "Q2983844"],
#     ])
#
# find_wikidata_items_haswbstatements([
#         # instance of - human
#         [cf.ATTR_OPTS.AND, None, "Q5"],
#         # gender - male
#         [cf.ATTR_OPTS.AND, None, "Q6581097"],
#         # educated at - Todai
#         [cf.ATTR_OPTS.AND, None, "Q7842"],
#         # employer - Graduate University for Advanced Studies
#         [cf.ATTR_OPTS.AND, None, "Q2983844"],
#     ])
#
# find_wikidata_items_haswbstatements([
#         # ? - scholarly article
#         [cf.ATTR_OPTS.AND, None, "Q13442814"],
#         # ? - DNA
#         [cf.ATTR_OPTS.OR, None, "Q7430"],
#         # ? - X-ray diffraction
#         [cf.ATTR_OPTS.OR, None, "Q12101244"],
#         # ? - DNA
#         [cf.ATTR_OPTS.OR, None, "Q911331"],
#         # Francis Crick
#         [cf.ATTR_OPTS.AND, None, "Q123280"],
#         # ? - Nature
#         [cf.ATTR_OPTS.AND, None, "Q180445"],
#     ])
