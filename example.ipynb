# %%
# Import class
from core.db_wd import DBWikidata

# Wikidb
db = DBWikidata()

# %% [markdown]
# ### 1. Get Entity Information

# %% [markdown]
# Get label

# %%
db.get_label("Q31")
# Out:
# 'Belgium'

# %% [markdown]
# Gel label in all languages

# %%
db.get_labels("Q31")
# Out:
# {'el': 'Βέλγιο',
#  'ay': 'Bilkiya',
#  'pnb': 'بیلجیئم',
#  'na': 'Berdjiyum',
#  'mk': 'Белгија',
#  'bn': 'বেলজিয়াম',
#  'bpy': 'বেলজিয়াম',
#  'lt': 'Belgija',
#  'jam': 'Beljiom',
#  'sk': 'Belgicko',
#  'so': 'Beljim',
#  'tl': 'Belgium',
#  'uk': 'Бельгія',
#  'tt': 'Билгия',
#  'sc': 'Bèlgiu',
#  'bxr': 'Бельги',
#  'ff': 'Beljik',
#  'za': 'Bijliswz',
#  'yo': 'Bẹ́ljíọ̀m',
#  'ext': 'Bélgica',
#  'zea': 'Belhië',
#  'es': 'Bélgica',
#  'or': 'ବେଲଜିଅମ',
#  'myv': 'Бельгия Мастор',
#  'yi': 'בעלגיע',
#  'ga': 'An Bheilg',
#  'csb': 'Belgijskô',
#  'gag': 'Belgiya',
#  'oc': 'Belgica',
#  'pfl': 'Belgje',
#  'rw': 'Ububiligi',
#  'sco': 'Belgium',
#  'sgs': 'Belgėjė',
#  'ltg': 'Beļgeja',
#  'zh-sg': '比利时',
#  'tet': 'Béljika',
#  'az': 'Belçika',
#  'mzn': 'بلژیک',
#  'zh-hk': '比利時',
#  'bar': 'Bäigien',
#  'zh': '比利時',
#  'nl': 'België',
#  'lez': 'Бельгия',
#  'ast': 'Bélxica',
#  'bm': 'Bɛliziki',
#  'ta': 'பெல்ஜியம்',
#  'jv': 'Bélgié',
#  'inh': 'Бельги',
#  'hi': 'बेल्जियम',
#  'co': 'Belgica',
#  'mn': 'Бельги',
#  'pms': 'Belgi',
#  'om': 'Beeljiyeem',
#  'sl': 'Belgija',
#  'crh': 'Belçika',
#  'ms': 'Belgium',
#  'ro': 'Belgia',
#  'bho': 'बेल्जियम',
#  'av': 'Бельгия',
#  'lb': 'Belsch',
#  'en-gb': 'Belgium',
#  'kaa': 'Belgiya',
#  'ps': 'بلجیم',
#  'stq': 'Belgien',
#  'aeb-arab': 'بلجيكيا',
#  'lo': 'ປະເທດແບນຊິກ',
#  'sw': 'Ubelgiji',
#  'nds': 'Belgien',
#  'ksh': 'Belgien',
#  'bcl': 'Belhika',
#  'pag': 'Belhika',
#  'da': 'Belgien',
#  'ca': 'Bèlgica',
#  'crh-latn': 'Belçika',
#  'lv': 'Beļģija',
#  'rup': 'Belghia',
#  'ady': 'Белгие',
#  'ty': 'Peretita',
#  'gv': 'Yn Velg',
#  'kbp': 'Pɛliziki',
#  'pt-br': 'Bélgica',
#  'ar': 'بلجيكا',
#  'srn': 'Belgikondre',
#  'ch': 'Belgika',
#  'diq': 'Belçıka',
#  'pih': 'Beljum',
#  'szl': 'Belgijŏ',
#  'ace': 'Bèlgia',
#  'cv': 'Бельги',
#  'ak': 'Belgium',
#  'pt': 'Bélgica',
#  'io': 'Belgia',
#  'zh-my': '比利时',
#  'ru': 'Бельгия',
#  'tpi': 'Beljiam',
#  'th': 'ประเทศเบลเยียม',
#  'ha': 'Beljik',
#  'mg': 'Belzika',
#  'azb': 'بلژیک',
#  'an': 'Belchica',
#  'eml': 'Bélgi',
#  'hy': 'Բելգիա',
#  'vep': "Bel'gii",
#  'mai': 'बेल्जियम',
#  'nov': 'Belgia',
#  'ne': 'बेल्जियम',
#  'eo': 'Belgio',
#  'de': 'Belgien',
#  'ig': 'Belgium',
#  'sm': 'Peleseuma',
#  'pam': 'Belhika',
#  'war': 'Belhika',
#  'rmy': 'Beljiya',
#  'jbo': 'beldjym',
#  'kbd': 'Белгэ',
#  'ug': 'بېلگىيە',
#  'mdf': 'Бельгие',
#  'mwl': 'Bélgica',
#  'lrc': 'بلجیک',
#  'en': 'Belgium',
#  'as': 'বেলজিয়াম',
#  'bgn': 'بلجیم',
#  'os': 'Бельги',
#  'my': 'ဘယ်လ်ဂျီယမ်နိုင်ငံ',
#  'zh-cn': '比利时',
#  'sma': 'Belgia',
#  'dz': 'བེལ་ཇིཡམ',
#  'et': 'Belgia',
#  'cbk-zam': 'Bélgica',
#  'wo': 'Belsik',
#  'bug': 'Belgia',
#  'zh-tw': '比利時',
#  'nn': 'Belgia',
#  'chr': 'ᏇᎵᏥᎥᎻ',
#  'wuu': '比利时',
#  'lg': 'Bubirigi',
#  'nrm': 'Belgique',
#  'gl': 'Bélxica',
#  'zh-mo': '比利時',
#  'ee': 'Belgium',
#  'bi': 'Belgium',
#  'rm': 'Belgia',
#  'pdc': 'Belgien',
#  'ckb': 'بەلجیکا',
#  'ln': 'Bɛ́ljika',
#  'rn': 'Ububirigi',
#  'frp': 'Bèlg·ique',
#  'cy': 'Gwlad Belg',
#  'nso': 'Belgium',
#  'la': 'Belgica',
#  'ky': 'Бельгия',
#  'mr': 'बेल्जियम',
#  'fo': 'Belgia',
#  'fr': 'Belgique',
#  'got': '𐌱𐌰𐌹𐌻𐌲𐌰𐌻𐌰𐌽𐌳',
#  'is': 'Belgía',
#  'hsb': 'Belgiska',
#  'mt': 'Belġju',
#  'li': 'Belsj',
#  'vro': 'Belgiä',
#  'fi': 'Belgia',
#  'zh-hant': '比利時',
#  'id': 'Belgia',
#  'gom': 'बेल्जियम',
#  'gu': 'બેલ્જિયમ',
#  'su': 'Bélgia',
#  'ia': 'Belgica',
#  'pa': 'ਬੈਲਜੀਅਮ',
#  'wa': 'Beldjike',
#  'vi': 'Bỉ',
#  'ilo': 'Belhika',
#  'roa-tara': 'Bèlge',
#  'gom-latn': 'Belgium',
#  'af': 'België',
#  'ceb': 'Belhika',
#  'krc': 'Бельгия',
#  'sg': 'Bêleze',
#  'nb': 'Belgia',
#  'gsw': 'Belgie',
#  'si': 'බෙල්ජියම',
#  'zh-hans': '比利时',
#  'sv': 'Belgien',
#  'tum': 'Belgium',
#  'scn': 'Belgiu',
#  'kab': 'Biljik',
#  'bg': 'Белгия',
#  'eu': 'Belgika',
#  'xmf': 'ბელგია',
#  'vo': 'Belgän',
#  'it': 'Belgio',
#  'pap': 'Bélgika',
#  'gom-deva': 'बेल्जियम',
#  'haw': 'Pelekiuma',
#  'liv': 'Beļgij',
#  'pcd': 'Bergike',
#  'kl': 'Belgia',
#  'he': 'בלגיה',
#  'dsb': 'Belgiska',
#  'be-tarask': 'Бэльгія',
#  'vec': 'Belzo',
#  'cdo': 'Bī-lé-sì',
#  'nan': 'Pe̍k-ní-gī',
#  'gn': 'Véyhika',
#  'tg': 'Белгия',
#  'bs': 'Belgija',
#  'sd': 'بيلجيم',
#  'sh': 'Belgija',
#  'hu': 'Belgium',
#  'yue': '比利時',
#  'te': 'బెల్జియం',
#  'koi': 'Белгия',
#  'ba': 'Бельгия',
#  'sah': 'Бельгия',
#  'ang': 'Belgice',
#  'pi': 'बेल्जियम',
#  'uz': 'Belgiya',
#  'tk': 'Belgiýa',
#  'hif': 'Belgium',
#  'xal': 'Бельҗмудин Нутг',
#  'cu': 'Бєлгїѥ',
#  'new': 'बेल्जियम',
#  'fur': 'Belgjo',
#  'ht': 'Bèljik',
#  'sn': 'Belgium',
#  'tr': 'Belçika',
#  'ie': 'Belgia',
#  'gd': "A' Bheilg",
#  'be': 'Бельгія',
#  'ka': 'ბელგია',
#  'ce': 'Бельги',
#  'kv': 'Бельгия',
#  'fa': 'بلژیک',
#  'nds-nl': 'België',
#  'bo': 'པེར་ཅིན།',
#  'mi': 'Pehiamu',
#  'pl': 'Belgia',
#  'en-ca': 'Belgium',
#  'tw': 'Belgium',
#  'am': 'ቤልጅግ',
#  'sr-el': 'Belgija',
#  'udm': 'Бельгия',
#  'kk': 'Бельгия',
#  'kn': 'ಬೆಲ್ಜಿಯಂ',
#  'nap': 'Belge',
#  'ur': 'بیلجیئم',
#  'frr': 'Belgien',
#  'vls': 'België',
#  'sq': 'Belgjika',
#  'kg': 'Belezi',
#  'pnt': 'Βέλγιον',
#  'de-ch': 'Belgien',
#  'mhr': 'Бельгий',
#  'ml': 'ബെൽജിയം',
#  'rue': 'Белґія',
#  'fy': 'Belgje',
#  'ku': 'Belçîka',
#  'olo': "Bel'gii",
#  'arc': 'ܒܠܓܝܩܐ',
#  'ss': 'IBhelijiyamu',
#  'ts': 'Belgium',
#  'dv': 'ބެލްޖިއަމް',
#  'arz': 'بلجيكا',
#  'se': 'Belgia',
#  'nah': 'Belgica',
#  'qu': 'Bilhika',
#  'cs': 'Belgie',
#  'kw': 'Pow Belg',
#  'lij': 'Belgio',
#  'lad': 'Beljika',
#  'sr-ec': 'Белгија',
#  'hr': 'Belgija',
#  'ja': 'ベルギー',
#  'ko': '벨기에',
#  'lfn': 'Beljia',
#  'br': 'Belgia',
#  'lzh': '比利時',
#  'sa': 'बेल्जियम्',
#  'lmo': 'Belgi',
#  'hak': 'Pí-li-sṳ̀',
#  'dty': 'बेल्जियम',
#  'sr': 'Белгија',
#  'de-at': 'Belgien',
#  'hyw': 'Պելճիքա',
#  'ab': 'Бельгиа',
#  'kea': 'Béljika',
#  'ban': 'Belgia',
#  'szy': 'Belguim',
#  'gcr': 'Bèljik',
#  'km': 'បែលស៊ិក',
#  'sat': 'ᱵᱮᱞᱡᱤᱭᱚᱢ',
#  'ary': 'بلجيكا',
#  'map-bms': 'Belgia',
#  'shn': 'မိူင်းပႄႇၵျီႇယမ်ႇ',
#  'smn': 'Belgia',
#  'sms': 'Belgia',
#  'awa': 'बेल्जियम',
#  'avk': 'Belga',
#  'lld': 'Belje',
#  'mad': 'Belgia',
#  'tay': 'Belguim',
#  'shi': 'Bljika',
#  'ny': 'Belgium',
#  'grc': 'Βέλγιον',
#  'mni': 'ꯕꯦꯜꯖꯤꯌꯝ',
#  'als': 'Belgien',
#  'trv': 'Belguim'}

# %% [markdown]
# Get label in a specific language

# %%
db.get_labels("Q31", "ja")
# Out:
# 'ベルギー'

# %% [markdown]
# Gel aliases in all languages

# %%
db.get_aliases("Q31")
# Out:
# {'bg': ['Кралство Белгия'],
#  'en-gb': ['Southern Netherlands'],
#  'mk': ['Кралство Белгија'],
#  'zh-hk': ['比利時王國'],
#  'pt-br': ['Reino da Bélgica'],
#  'fr': ['BE', 'Belg.', 'Royaume de Belgique', 'be', '🇧🇪'],
#  'en': ['BE', 'BEL', 'Kingdom of Belgium', 'be', '🇧🇪'],
#  'zh': ['比利时', '比利时王国', '比利時王國'],
#  'tr': ['Belçika Krallığı'],
#  'jv': ['Bèlgi', 'Kraton Bélgié'],
#  'bho': ['बेलजियम', 'बेल्जियम राज', 'बेल्जीयम'],
#  'be-tarask': ['Бэльґія'],
#  'bn': ['বেলজিয়াম রাজ্য'],
#  'ta': ['பெல்சியம்', 'பெல்ஜிய பேரரசு'],
#  'zh-cn': ['比利时王国'],
#  'ko': ['벨기에 왕국', '벨기에왕국'],
#  'uk': ['Королівство Бельгія'],
#  'th': ['Belgium',
#   'ประเทศเบลเยี่ยม',
#   'ราชอาณาจักรเบลเยียม',
#   'ราชอาณาจักรเบลเยี่ยม',
#   'เบลเยียม',
#   'เบลเยี่ยม'],
#  'zh-my': ['比利时王国'],
#  'zh-tw': ['比利時王國'],
#  'ru': ['Belgique', 'Королевство Бельгия'],
#  'tl': ['Belhika'],
#  'lij': ['Belgiò'],
#  'zh-sg': ['比利时王国'],
#  'nds-nl': ['Belgie'],
#  'roa-tara': ['Belge', 'Belgio'],
#  'hy': ['Բելգիայի Թագավորություն'],
#  'es': ['BE', 'Belgica', 'Reino de Belgica', 'Reino de Bélgica'],
#  'pa': ['ਬੈਲਜੀਅਮ ਦਾ ਰਾਜ'],
#  'nan': ['Belgie', 'Belgien', 'Belgium', 'België', 'Pí-lī-sî', 'Tāi-pí-kok'],
#  'hr': ['Kraljevina Belgija'],
#  'pl': ['Królestwo Belgii'],
#  'zh-hant': ['比利時王國'],
#  'nb': ['Kongeriket Belgia'],
#  'zh-mo': ['比利時王國'],
#  'fi': ['Belgian kuningaskunta'],
#  'zh-hans': ['比利时王国'],
#  'nl': ['BE', 'BEL', 'Belgenland', 'Belgie', 'Koninkrijk België', 'be', '🇧🇪'],
#  'yue': ['Belgien',
#   'Belgique',
#   'Belgium',
#   'België',
#   'Koninkrijk België',
#   'Königreich Belgien',
#   'Royaume de Belgique'],
#  'ca': ['België', 'Bélgica', 'Estat belga', 'Regne de Bèlgica'],
#  'pam': ['Belgika', 'Belgium', 'Belika'],
#  'el': ['Βασίλειο του Βελγίου'],
#  'vls': ['BE'],
#  'ak': ['Ɔman Belgium'],
#  'ast': ['🇧🇪'],
#  'de': ['BE', 'BEL', 'Königreich Belgien', '🇧🇪'],
#  'hi': ['बेल्जियम बादशाहत', '🇧🇪'],
#  'mr': ['🇧🇪'],
#  'ne': ['🇧🇪'],
#  'sa': ['🇧🇪'],
#  'ja': ['ベルギー王国'],
#  'da': ['Belgique',
#   'België',
#   'Kongeriget Belgien',
#   'Koninkrijk België',
#   'Royaume de Belgique'],
#  'se': ['Belgia gonagasriika'],
#  'smn': ['Belgia kunâgâskodde'],
#  'sms': ['Belgia koonǥõskåʹdd'],
#  'szl': ['Krōlestwo Belgije'],
#  'mt': ['Renju tal-Belġju'],
#  'vec': ['BE', 'BEL', 'Bèlzega'],
#  'ku': ['Belgiya'],
#  'av': ['Белген'],
#  'bar': ['Bejgien'],
#  'bi': ['Beljiom'],
#  'frp': ['Bèlgica'],
#  'kbd': ['Белгиэ'],
#  'ksh': ['Beljie'],
#  'mzn': ['بلجیک'],
#  'pfl': ['Belgien'],
#  'ps': ['بېلجیم'],
#  'sat': ['ᱵᱮᱞᱡᱤᱭᱟᱢ'],
#  'tt': ['Бельгия'],
#  'tw': ['Bɛlgyiom'],
#  'zea': ['België'],
#  'ban': ['Bélgia'],
#  'gsw': ['Belgien'],
#  'grc': ['Βελγική'],
#  'ckb': ['بەلژیک', 'بەلژیکا'],
#  'frr': ['Belgien/fe'],
#  'km': ['បែលហ្សិក'],
#  'ur': ['بلجئیم', 'بیلجیم', 'مملکت بیلجیئم']}

# %% [markdown]
# Get aliases in a specific language

# %%
db.get_aliases("Q31", "ja")
# Out:
# ['ベルギー王国']

# %% [markdown]
# Gel descriptions in all languages

# %%
db.get_descriptions("Q31")
# Out:
# {'cy': 'wlad yn Ewrop',
#  'sk': 'štát v Europe',
#  'mk': 'земја во Европа',
#  'vls': "pays d'europe",
#  'fr': "État d'Europe occidentale",
#  'zh': '西歐國家',
#  'it': "stato dell'Europa occidentale, membro dell'Unione europea",
#  'jv': 'nagara ing Éropah',
#  'pl': 'państwo w Europie',
#  'bn': 'পশ্চিম ইউরোপের যুক্তরাষ্ট্রীয় সাংবিধানিক রাজতন্ত্র',
#  'fi': 'valtio Länsi-Euroopassa',
#  'en-ca': 'constitutional monarchy in Western Europe',
#  'uk': 'держава у Західній Європі',
#  'id': 'negara di Eropa Barat',
#  'vi': 'một quốc gia có chủ quyền tại Tây Âu',
#  'pt': 'país da Europa',
#  'pa': "ਯੂਰਪ 'ਚ ਦੇਸ਼",
#  'zh-my': '西欧国家',
#  'ru': 'государство в Западной Европе',
#  'de-ch': 'Staat in Westeuropa',
#  'fa': 'کشوری در قاره اروپا',
#  'th': 'ราชอาณาจักรในยุโรปตะวันตก',
#  'zh-tw': '西歐國家',
#  'ilo': 'pederal nga estado idiay Lumaud nga Europa',
#  'es': 'país de Europa',
#  'tr': "Batı Avrupa'da bir ülke",
#  'hy': 'դաշնային թագավորություն Եվրոպայում',
#  'de-at': 'Staat in Westeuropa',
#  'hu': 'állam Nyugat-Európában',
#  'zh-hant': '西歐國家',
#  'nb': 'land i Europa',
#  'gsw': 'Staat in Mitteleuropa',
#  'eo': 'federacio en Eŭropo',
#  'ne': 'युरोपको देश',
#  'zh-hans': '西欧国家',
#  'sv': 'konstitutionell monarki i Västeuropa',
#  'nl': 'federale staat in West-Europa',
#  'de': 'föderaler Staat in Westeuropa',
#  'bg': 'държава в Западна Европа',
#  'la': 'civitas Europae',
#  'scn': "paìsi di l'Europa di punenti",
#  'el': 'χώρα της δυτικής Ευρώπης',
#  'tet': 'rai iha Europa',
#  'ar': 'دولة في أوروبا الغربية',
#  'zh-hk': '西歐國家',
#  'pt-br': 'país da Europa',
#  'sr-el': 'država u zapadnoj Evropi',
#  'kn': 'ಪಶ್ಚಿಮ ಯುರೋಪಿನ ಸಾಂವಿಧಾನಿಕ ರಾಜಾಡಳಿತ ಹೊಂದಿರುವ ದೇಶ',
#  'en': 'country in western Europe',
#  'ta': 'மேற்கு ஐரோப்பிய நாடு',
#  'zh-cn': '西欧国家',
#  'hsb': 'stat w zapadnej Europje',
#  'hi': 'पश्चिमी यूरोप में एक संघीय संवैधानिक राजशाही',
#  'cs': 'stát v Evropě',
#  'zh-sg': '西欧国家',
#  'he': 'מדינה באירופה',
#  'ro': 'stat în Europa de Vest',
#  'bho': 'पच्छिमी यूरोप में एगो संघीय संबैधानिक राजतंत्र',
#  'lb': 'Staat an Europa',
#  'sr-ec': 'држава у западној Европи',
#  'en-gb': 'country in Europe',
#  'hr': 'država u zapadnoj Europi',
#  'ja': '西ヨーロッパに位置する国家',
#  'ko': '서유럽에 위치한 국가',
#  'te': 'ఐరోపా లోని ఒక దేశం',
#  'br': 'stad Europa',
#  'zh-mo': '西歐國家',
#  'sw': 'nchi katika Ulaya Magharibi',
#  'nds': 'Staat in Mitteleuropa',
#  'da': 'Et land i Europa',
#  'sr': 'држава у западној Европи',
#  'ca': "país d'Europa",
#  'lv': 'Valsts Eiropā',
#  'ie': 'Un Land in Europa',
#  'ml': 'വടക്കുപടിഞ്ഞാറേ യൂറോപ്പിൽ ഉള്ള ഒരു രാജ്യം',
#  'se': 'riika Eurohpás',
#  'az': 'Qərbi Avropada konstusiyalı monarxiya ölkə',
#  'ht': 'peyi ki nan pati oksidantal kontinan Ewopeyen',
#  'wa': "payis di l' Urope do Coûtchant",
#  'gl': 'país europeo',
#  'sd': 'اولاھين يورپ ۾ ملڪ',
#  'vec': 'Stato del Nord Eoropa',
#  'ku': 'Welatekî Ewropayê',
#  'ckb': 'دەوڵەتی باڵادەست لە ڕۆژاوای ئەورووپا',
#  'mr': 'पश्चिम यूरपातील एक देश',
#  'bs': 'država u zapadnoj Evropi',
#  'szl': 'państwo we zachodnij Ojropie',
#  'pap': 'pais na Oropa',
#  'mt': 'pajjiż fl-Ewropa tal-Punent',
#  'yue': '西歐國家',
#  'be': 'краіна',
#  'be-tarask': 'краіна',
#  'grc': 'Εὐρώπης χώρα',
#  'pnb': 'لہندا یورپ دا اک دیش',
#  'ur': 'مغربی یورپ کا ایک ملک'}

# %% [markdown]
# Get descriptions in a specific language

# %%
db.get_descriptions("Q31", "ja")
# Out:
# '西ヨーロッパに位置する国家'

# %% [markdown]
# Gel sitelinks

# %%
db.get_sitelinks("Q31")
# Out:
# {'itwikivoyage': 'Belgio',
#  'zhwikivoyage': '比利时',
#  'ruwikivoyage': 'Бельгия',
#  'fawikiquote': 'بلژیک',
#  'dewikivoyage': 'Belgien',
#  'enwikivoyage': 'Belgium',
#  'hewikivoyage': 'בלגיה',
#  'eowikinews': 'Kategorio:Belgujo',
#  'frwikinews': 'Catégorie:Belgique',
#  'trwikinews': 'Kategori:Belçika',
#  'plwikiquote': 'Belgia',
#  'nlwikinews': 'Categorie:België',
#  'rowikivoyage': 'Belgia',
#  'svwikivoyage': 'Belgien',
#  'arwikinews': 'تصنيف:بلجيكا',
#  'frwikivoyage': 'Belgique',
#  'nlwikibooks': 'Atlas van Europa/België',
#  'enwikiquote': 'Belgium',
#  'rowikinews': 'Categorie:Belgia',
#  'jawikinews': 'カテゴリ:ベルギー',
#  'itwikiquote': 'Belgio',
#  'ptwikibooks': 'Bélgica',
#  'viwikivoyage': 'Bỉ',
#  'kowikinews': '분류:벨기에',
#  'ptwikinews': 'Categoria:Bélgica',
#  'fawikivoyage': 'بلژیک',
#  'fiwikinews': 'Luokka:Belgia',
#  'plwikivoyage': 'Belgia',
#  'cawikinews': 'Categoria:Bèlgica',
#  'srwikinews': 'Категорија:Белгија',
#  'ptwikivoyage': 'Bélgica',
#  'enwikinews': 'Category:Belgium',
#  'svwikinews': 'Kategori:Belgien',
#  'eswikivoyage': 'Bélgica',
#  'elwikinews': 'Κατηγορία:Βέλγιο',
#  'bswikinews': 'Kategorija:Belgija',
#  'sqwikinews': 'Kategoria:Belgjikë',
#  'eswikinews': 'Categoría:Bélgica',
#  'nlwikiquote': 'België',
#  'ukwikinews': 'Категорія:Бельгія',
#  'hewikiquote': 'בלגיה',
#  'cswikinews': 'Kategorie:Belgie',
#  'nowikinews': 'Kategori:Belgia',
#  'zhwikinews': 'Category:比利時',
#  'ukwikivoyage': 'Бельгія',
#  'hywikiquote': 'Բելգիա',
#  'frwikiquote': 'Belgique',
#  'nlwikivoyage': 'België',
#  'eswikiquote': 'Bélgica',
#  'huwikinews': 'Kategória:Belgium',
#  'plwikinews': 'Kategoria:Belgia',
#  'ruwikinews': 'Категория:Бельгия',
#  'tawikinews': 'பகுப்பு:பெல்ஜியம்',
#  'dewikinews': 'Kategorie:Belgien',
#  'liwikibooks': 'Belsj',
#  'itwikinews': 'Categoria:Belgio',
#  'elwikivoyage': 'Βέλγιο',
#  'fawikinews': 'رده:بلژیک',
#  'fiwikivoyage': 'Belgia',
#  'commonswiki': 'België - Belgique - Belgien',
#  'arwikiquote': 'بلجيكا',
#  'jawikivoyage': 'ベルギー',
#  'eowikivoyage': 'Belgio',
#  'trwikivoyage': 'Belçika',
#  'hewikinews': 'קטגוריה:בלגיה',
#  'eowikiquote': 'Belgio',
#  'etwikiquote': 'Belgia',
#  'enwiki': 'Belgium',
#  'dewiki': 'Belgien',
#  'frwiki': 'Belgique',
#  'eswiki': 'Bélgica',
#  'ruwiki': 'Бельгия',
#  'itwiki': 'Belgio',
#  'jawiki': 'ベルギー',
#  'nlwiki': 'België',
#  'plwiki': 'Belgia',
#  'ptwiki': 'Bélgica',
#  'zhwiki': '比利时',
#  'svwiki': 'Belgien',
#  'fawiki': 'بلژیک',
#  'hewiki': 'בלגיה',
#  'trwiki': 'Belçika',
#  'huwiki': 'Belgium',
#  'fiwiki': 'Belgia',
#  'arwiki': 'بلجيكا',
#  'viwiki': 'Bỉ',
#  'nowiki': 'Belgia',
#  'ukwiki': 'Бельгія',
#  'kowiki': '벨기에',
#  'cawiki': 'Bèlgica',
#  'cswiki': 'Belgie',
#  'srwiki': 'Белгија',
#  'rowiki': 'Belgia',
#  'idwiki': 'Belgia',
#  'dawiki': 'Belgien',
#  'simplewiki': 'Belgium',
#  'bgwiki': 'Белгия',
#  'abwiki': 'Бельгиа',
#  'acewiki': 'Bèlgia',
#  'adywiki': 'Белгие',
#  'afwiki': 'België',
#  'akwiki': 'Belgium',
#  'alswiki': 'Belgien',
#  'amwiki': 'ቤልጅግ',
#  'amiwiki': 'Belguim',
#  'anwiki': 'Belchica',
#  'angwiki': 'Belgice',
#  'arcwiki': 'ܒܠܓܝܩܐ',
#  'arywiki': 'بلجيكا',
#  'arzwiki': 'بلجيكا',
#  'astwiki': 'Bélxica',
#  'avwiki': 'Белген',
#  'avkwiki': 'Belga',
#  'awawiki': 'बेल्जियम',
#  'aywiki': 'Bilkiya',
#  'azwiki': 'Belçika',
#  'azbwiki': 'بلژیک',
#  'bawiki': 'Бельгия',
#  'banwiki': 'Bélgia',
#  'barwiki': 'Bejgien',
#  'bat_smgwiki': 'Belgėjė',
#  'bclwiki': 'Belhika',
#  'bewiki': 'Бельгія',
#  'be_x_oldwiki': 'Бэльгія',
#  'bhwiki': 'बेल्जियम',
#  'biwiki': 'Beljiom',
#  'bmwiki': 'Bɛliziki',
#  'bnwiki': 'বেলজিয়াম',
#  'bowiki': 'པེར་ཅིན།',
#  'bpywiki': 'বেলজিয়াম',
#  'brwiki': 'Belgia',
#  'bswiki': 'Belgija',
#  'bugwiki': 'Belgia',
#  'bxrwiki': 'Бельги',
#  'cbk_zamwiki': 'Bélgica',
#  'cdowiki': 'Bī-lé-sì',
#  'cewiki': 'Бельги',
#  'cebwiki': 'Belhika',
#  'chwiki': 'Belgika',
#  'chrwiki': 'ᏇᎵᏥᎥᎻ',
#  'ckbwiki': 'بەلجیکا',
#  'cowiki': 'Belgica',
#  'crhwiki': 'Belçika',
#  'csbwiki': 'Belgijskô',
#  'cuwiki': 'Бєлгїѥ',
#  'cvwiki': 'Бельги',
#  'cywiki': 'Gwlad Belg',
#  'diqwiki': 'Belçıka',
#  'dsbwiki': 'Belgiska',
#  'dtywiki': 'बेल्जियम',
#  'dvwiki': 'ބެލްޖިއަމް',
#  'dzwiki': 'བེལ་ཇིཡམ',
#  'eewiki': 'Belgium',
#  'elwiki': 'Βέλγιο',
#  'emlwiki': 'Bélgi',
#  'eowiki': 'Belgio',
#  'etwiki': 'Belgia',
#  'euwiki': 'Belgika',
#  'extwiki': 'Bélgica',
#  'ffwiki': 'Beljik',
#  'fiu_vrowiki': 'Belgiä',
#  'fowiki': 'Belgia',
#  'frpwiki': 'Bèlgica',
#  'frrwiki': 'Belgien/fe',
#  'furwiki': 'Belgjo',
#  'fywiki': 'Belgje',
#  'gawiki': 'An Bheilg',
#  'gagwiki': 'Belgiya',
#  'gcrwiki': 'Bèljik',
#  'gdwiki': "A' Bheilg",
#  'glwiki': 'Bélxica',
#  'gnwiki': 'Véyhika',
#  'gomwiki': 'बेल्जियम',
#  'gotwiki': '𐌱𐌰𐌹𐌻𐌲𐌰𐌻𐌰𐌽𐌳',
#  'guwiki': 'બેલ્જિયમ',
#  'gvwiki': 'Yn Velg',
#  'hawiki': 'Beljik',
#  'hakwiki': 'Pí-li-sṳ̀',
#  'hawwiki': 'Pelekiuma',
#  'hiwiki': 'बेल्जियम',
#  'hifwiki': 'Belgium',
#  'hrwiki': 'Belgija',
#  'hsbwiki': 'Belgiska',
#  'htwiki': 'Bèljik',
#  'hywiki': 'Բելգիա',
#  'hywwiki': 'Պելճիքա',
#  'iawiki': 'Belgica',
#  'iewiki': 'Belgia',
#  'igwiki': 'Belgium',
#  'ilowiki': 'Belhika',
#  'inhwiki': 'Бельги',
#  'iowiki': 'Belgia',
#  'iswiki': 'Belgía',
#  'jamwiki': 'Beljiom',
#  'jbowiki': 'beldjym',
#  'jvwiki': 'Bèlgi',
#  'kawiki': 'ბელგია',
#  'kaawiki': 'Belgiya',
#  'kabwiki': 'Biljik',
#  'kbdwiki': 'Белгиэ',
#  'kbpwiki': 'Pɛliziki',
#  'kgwiki': 'Belezi',
#  'kkwiki': 'Бельгия',
#  'klwiki': 'Belgia',
#  'kmwiki': 'បែលហ្សិក',
#  'knwiki': 'ಬೆಲ್ಜಿಯಂ',
#  'koiwiki': 'Белгия',
#  'krcwiki': 'Бельгия',
#  'kshwiki': 'Beljie',
#  'kuwiki': 'Belçîka',
#  'kvwiki': 'Бельгия',
#  'kwwiki': 'Pow Belg',
#  'kywiki': 'Бельгия',
#  'lawiki': 'Belgica',
#  'ladwiki': 'Beljika',
#  'lbwiki': 'Belsch',
#  'lezwiki': 'Бельгия',
#  'lfnwiki': 'Beljia',
#  'lgwiki': 'Bubirigi',
#  'liwiki': 'Belsj',
#  'lijwiki': 'Belgio',
#  'lldwiki': 'Belje',
#  'lmowiki': 'Belgi',
#  'lnwiki': 'Bɛ́ljika',
#  'lowiki': 'ປະເທດແບນຊິກ',
#  'ltwiki': 'Belgija',
#  'ltgwiki': 'Beļgeja',
#  'lvwiki': 'Beļģija',
#  'madwiki': 'Belgia',
#  'maiwiki': 'बेल्जियम',
#  'map_bmswiki': 'Belgia',
#  'mdfwiki': 'Бельгие',
#  'mgwiki': 'Belzika',
#  'mhrwiki': 'Бельгий',
#  'miwiki': 'Pehiamu',
#  'mkwiki': 'Белгија',
#  'mlwiki': 'ബെൽജിയം',
#  'mnwiki': 'Бельги',
#  'mniwiki': 'ꯕꯦꯜꯖꯤꯌꯝ',
#  'mrwiki': 'बेल्जियम',
#  'mswiki': 'Belgium',
#  'mtwiki': 'Belġju',
#  'mwlwiki': 'Bélgica',
#  'mywiki': 'ဘယ်လ်ဂျီယမ်နိုင်ငံ',
#  'myvwiki': 'Бельгия Мастор',
#  'mznwiki': 'بلجیک',
#  'nawiki': 'Berdjiyum',
#  'nahwiki': 'Belgica',
#  'napwiki': 'Belge',
#  'ndswiki': 'Belgien',
#  'nds_nlwiki': 'België',
#  'newiki': 'बेल्जियम',
#  'newwiki': 'बेल्जियम',
#  'nnwiki': 'Belgia',
#  'novwiki': 'Belgia',
#  'nrmwiki': 'Belgique',
#  'nsowiki': 'Belgium',
#  'nywiki': 'Belgium',
#  'ocwiki': 'Belgica',
#  'olowiki': "Bel'gii",
#  'omwiki': 'Beeljiyeem',
#  'oswiki': 'Бельги',
#  'pawiki': 'ਬੈਲਜੀਅਮ',
#  'pagwiki': 'Belhika',
#  'pamwiki': 'Belgika',
#  'papwiki': 'Bélgika',
#  'pcdwiki': 'Bergike',
#  'pdcwiki': 'Belgien',
#  'pflwiki': 'Belgien',
#  'piwiki': 'बेल्जियम',
#  'pihwiki': 'Beljum',
#  'pmswiki': 'Belgi',
#  'pnbwiki': 'بیلجیم',
#  'pntwiki': 'Βέλγιον',
#  'pswiki': 'بېلجیم',
#  'quwiki': 'Bilhika',
#  'rmwiki': 'Belgia',
#  'rmywiki': 'Beljiya',
#  'rnwiki': 'Ububirigi',
#  'roa_tarawiki': 'Bèlge',
#  'ruewiki': 'Белґія',
#  'rwwiki': 'Ububiligi',
#  'sawiki': 'बेल्जियम्',
#  'sahwiki': 'Бельгия',
#  'satwiki': 'ᱵᱮᱞᱡᱤᱭᱟᱢ',
#  'scwiki': 'Bèlgiu',
#  'scnwiki': 'Belgiu',
#  'scowiki': 'Belgium',
#  'sdwiki': 'بيلجيم',
#  'sewiki': 'Belgia',
#  'sgwiki': 'Bêleze',
#  'shwiki': 'Belgija',
#  'shiwiki': 'Bljika',
#  'shnwiki': 'မိူင်းပႄႇၵျီႇယမ်ႇ',
#  'siwiki': 'බෙල්ජියම',
#  'skwiki': 'Belgicko',
#  'slwiki': 'Belgija',
#  'smwiki': 'Peleseuma',
#  'smnwiki': 'Belgia',
#  'snwiki': 'Belgium',
#  'sowiki': 'Beljim',
#  'sqwiki': 'Belgjika',
#  'srnwiki': 'Belgikondre',
#  'sswiki': 'IBhelijiyamu',
#  'stqwiki': 'Belgien',
#  'suwiki': 'Bélgia',
#  'swwiki': 'Ubelgiji',
#  'szlwiki': 'Belgijŏ',
#  'szywiki': 'Belguim',
#  'tawiki': 'பெல்ஜியம்',
#  'taywiki': 'Belguim',
#  'tewiki': 'బెల్జియం',
#  'tetwiki': 'Béljika',
#  'tgwiki': 'Белгия',
#  'thwiki': 'ประเทศเบลเยียม',
#  'tkwiki': 'Belgiýa',
#  'tlwiki': 'Belhika',
#  'tpiwiki': 'Beljiam',
#  'trvwiki': 'Belguim',
#  'tswiki': 'Belgium',
#  'ttwiki': 'Бельгия',
#  'tumwiki': 'Belgium',
#  'twwiki': 'Bɛlgyiom',
#  'udmwiki': 'Бельгия',
#  'ugwiki': 'بېلگىيە',
#  'urwiki': 'بلجئیم',
#  'uzwiki': 'Belgiya',
#  'vecwiki': 'Belzo',
#  'vepwiki': "Bel'gii",
#  'vlswiki': 'België',
#  'vowiki': 'Belgän',
#  'wawiki': 'Beldjike',
#  'warwiki': 'Belhika',
#  'wowiki': 'Belsik',
#  'wuuwiki': '比利时',
#  'xalwiki': 'Бельҗмудин Нутг',
#  'xmfwiki': 'ბელგია',
#  'yiwiki': 'בעלגיע',
#  'yowiki': 'Bẹ́ljíọ̀m',
#  'zawiki': 'Bijliswz',
#  'zeawiki': 'België',
#  'zh_classicalwiki': '比利時',
#  'zh_min_nanwiki': 'Pe̍k-ní-gī',
#  'zh_yuewiki': '比利時'}

# %%
# Gel Wikipedia title of Belgium (Q31)
db.get_wikipedia_title("ja", "Q31")
# Out:
# 'ベルギー'

# %%
# Gel Wikipedia link of Belgium (Q31)
db.get_wikipedia_link("ja", "Q31")
# Out:
# 'https://ja.wikipedia.org/wiki/ベルギー'

# %% [markdown]
# Gel statements

# %%
db.get_claims("Q31")
# Out:
# {'string': {'P2924': [{'value': '4075290'}],
#   'P1667': [{'value': '1000063'}],
#   'P3348': [{'value': '2020'}],
#   'P349': [{'value': '00560624'}],
#   'P3365': [{'value': 'belgio'}],
#   'P3221': [{'value': 'destination/belgium'}],
#   'P2581': [{'value': '00009714n',
#     'references': [{'wikibase-entityid': {'P248': ['Q4837690']}}]}],
#   'P1566': [{'value': '2802361'}],
#   'P227': [{'value': '4005406-8',
#     'references': [{'wikibase-entityid': {'P143': ['Q48183']}}]}],
#   'P487': [{'value': '🇧🇪'}],
#   'P3916': [{'value': 'concept893'}],
#   'P395': [{'value': 'B'}],
#   'P3238': [{'value': '0'}],
#   'P298': [{'value': 'BEL'}],
#   'P3417': [{'value': 'Belgium'}, {'value': 'Belge'}],
#   'P998': [{'value': 'Regional/Europe/Belgium/'}],
#   'P486': [{'value': 'D001530'}],
#   'P3106': [{'value': 'world/belgium'}],
#   'P982': [{'value': '5b8a5ee5-0bb3-34cf-9a75-c27c44e341fc',
#     'references': [{'wikibase-entityid': {'P248': ['Q14005']}}]}],
#   'P94': [{'value': 'Great coat of arms of Belgium.svg'},
#    {'value': 'State Coat of Arms of Belgium.svg'},
#    {'value': 'Arms of Belgium (with crown).svg'},
#    {'value': 'Royal Arms of Belgium.svg'}],
#   'P2981': [{'value': 'B',
#     'references': [{'string': {'P854': ['http://otif.org/fileadmin/user_upload/otif_verlinkte_files/06_tech_zulass/05_Reglementation_en_vigueur/Neu_ab_01_01_2015/UTP_MARKING_2015_e_in_force.pdf']}}]}],
#   'P3422': [{'value': '99131'}],
#   'P935': [{'value': 'België - Belgique - Belgien'}],
#   'P214': [{'value': '144248059'}],
#   'P5180': [{'value': 'belgium'}],
#   'P605': [{'value': 'BE'}],
#   'P4613': [{'value': '39061'}],
#   'P3911': [{'value': '17201-5'}],
#   'P3984': [{'value': 'belgium',
#     'references': [{'time': {'P813': ['2018-05-06']}}]}],
#   'P856': [{'value': 'https://www.belgium.be/nl'},
#    {'value': 'https://www.belgium.be/en'},
#    {'value': 'https://www.belgium.be/fr'},
#    {'value': 'https://www.belgium.be/de'}],
#   'P3896': [{'value': 'Data:Belgium.map'}],
#   'P949': [{'value': '000981380',
#     'references': [{'wikibase-entityid': {'P248': ['Q54919']},
#       'string': {'P214': ['259064514'],
#        'P854': ['http://www.viaf.org/viaf/259064514/']},
#       'time': {'P813': ['2016-04-01']}}]}],
#   'P402': [{'value': '52411'}],
#   'P4725': [{'value': '19875'}],
#   'P3068': [{'value': 'BE'}],
#   'P691': [{'value': 'ge128735'}],
#   'P906': [{'value': '140654'}],
#   'P3241': [{'value': '02395a'}],
#   'P2258': [{'value': '206'}],
#   'P2979': [{'value': '205'}],
#   'P1225': [{'value': '10035761'}],
#   'P5198': [{'value': '294901094',
#     'references': [{'wikibase-entityid': {'P248': ['Q54856619']},
#       'time': {'P813': ['2018-06-13']}}]}],
#   'P1315': [{'value': '1028458'}],
#   'P3612': [{'value': 'pays/belgique'}],
#   'P268': [{'value': '15238382r',
#     'references': [{'wikibase-entityid': {'P248': ['Q54919']},
#       'string': {'P214': ['144248059']},
#       'time': {'P813': ['2018-10-07']}}]}],
#   'P242': [{'value': 'EU-Belgium.svg'},
#    {'value': 'Belgium (orthographic projection).svg'}],
#   'P1617': [{'value': 'e68c5b82-50e8-47d8-953c-bf61a2de0a85'}],
#   'P1036': [{'value': '2--493'}],
#   'P3743': [{'value': '2.16.56'}],
#   'P984': [{'value': 'BEL',
#     'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]}],
#   'P2163': [{'value': '1210278'}],
#   'P4342': [{'value': 'Belgia'}],
#   'P4427': [{'value': '766'}],
#   'P5573': [{'value': '2969',
#     'references': [{'string': {'P854': ['https://www.archinform.net/service/wd_aiort.php']},
#       'wikibase-entityid': {'P248': ['Q265049']},
#       'time': {'P813': ['2018-08-05']}}]}],
#   'P1417': [{'value': 'place/Belgium'}],
#   'P4629': [{'value': 'Belgium'}],
#   'P948': [{'value': 'Belgium Banner.jpg'}],
#   'P2347': [{'value': '105206'}],
#   'P1296': [{'value': '0008719'}],
#   'P373': [{'value': 'Belgium'}],
#   'P6150': [{'value': '6974'}],
#   'P4672': [{'value': '3b33aed2-40bc-48a9-baa0-3ff78ba4a5aa',
#     'references': [{'wikibase-entityid': {'P143': ['Q28054658']}}]}],
#   'P2982': [{'value': '88',
#     'references': [{'string': {'P854': ['http://uic.org/country-codes']}}]}],
#   'P3222': [{'value': 'belgien'}],
#   'P898': [{'value': 'ˈbɛlgɪɑ'},
#    {'value': 'ˈbʲelʲɡʲɪjə'},
#    {'value': 'bɛl.ʒik'}],
#   'P299': [{'value': '056'}],
#   'P269': [{'value': '026360608'}],
#   'P5247': [{'value': '3035-254'}],
#   'P3024': [{'value': 'BEL'}],
#   'P474': [{'value': '+32'}],
#   'P646': [{'value': '/m/0154j',
#     'references': [{'wikibase-entityid': {'P248': ['Q15241312']},
#       'time': {'P577': ['2013-10-28']}}]}],
#   'P3175': [{'value': 'ube'}],
#   'P244': [{'value': 'n80126041'}],
#   'P297': [{'value': 'BE'}],
#   'P901': [{'value': 'BE',
#     'references': [{'wikibase-entityid': {'P248': ['Q3063249']},
#       'string': {'P1065': ['https://web.archive.org/web/20010208080459/http://www.itl.nist.gov:80/fipspubs/fip10-4.htm']}}]}],
#   'P3509': [{'value': 'belgien'}],
#   'P41': [{'value': 'Flag of Belgium (civil).svg'},
#    {'value': 'Flag of Belgium.svg'}],
#   'P5019': [{'value': 'belgien'}],
#   'P1842': [{'value': 'Belgium'}],
#   'P6573': [{'value': 'Belgien'}],
#   'P5250': [{'value': '1249'}],
#   'P4801': [{'value': 'countries/be'}],
#   'P6363': [{'value': 'http://data.thenextweb.com/tnw/entity/belgium',
#     'references': [{'string': {'P854': ['https://thenextweb.com/vocabulary/belgium/']}}]}],
#   'P5905': [{'value': '4020-55916'}],
#   'P6404': [{'value': 'belgio'}],
#   'P7012': [{'value': 'belgium'}],
#   'P6766': [{'value': '85632997'}],
#   'P5002': [{'value': '77978'}],
#   'P6849': [{'value': 'belgien'}],
#   'P989': [{'value': 'Nl-België-article.ogg'}],
#   'P7471': [{'value': '7008',
#     'references': [{'wikibase-entityid': {'P248': ['Q16958215']}}]}],
#   'P1245': [{'value': '5689'}],
#   'P7314': [{'value': 'belcika'}],
#   'P902': [{'value': '003349'}],
#   'P3067': [{'value': '540-549'}],
#   'P5400': [{'value': 'wxtrbw'}],
#   'P7870': [{'value': '6826'}],
#   'P7818': [{'value': 'Belgique'}],
#   'P7829': [{'value': 'Belgium'}],
#   'P7827': [{'value': 'Bélgica'}],
#   'P7832': [{'value': 'Belgika'}],
#   'P7822': [{'value': 'Belgio'}],
#   'P443': [{'value': 'Lb-Belsch.ogg'},
#    {'value': 'LL-Q7913 (ron)-KlaudiuMihaila-Belgia.wav'}],
#   'P5437': [{'value': '4839'}],
#   'P7982': [{'value': '6718'}],
#   'P6058': [{'value': 'pays/wd/108227'}],
#   'P7859': [{'value': 'lccn-n80126041',
#     'references': [{'string': {'P214': ['144248059']}}]}],
#   'P7322': [{'value': '14'}],
#   'P8349': [{'value': '11670'}],
#   'P8408': [{'value': 'Belgium',
#     'references': [{'wikibase-entityid': {'P248': ['Q64139102']},
#       'time': {'P813': ['2020-07-09']}}]}],
#   'P6385': [{'value': 'strany_mira/BELGIYA.html'}],
#   'P8406': [{'value': 'T007414'}],
#   'P8519': [{'value': '3995'}],
#   'P5063': [{'value': 'i83329'}],
#   'P1438': [{'value': '10489'}],
#   'P3749': [{'value': '5182502652099301362'}],
#   'P6200': [{'value': 'cz4pr2gdgrdt'}],
#   'P8714': [{'value': 'BEL'}],
#   'P5587': [{'value': 'xv8b9nqg4r1hd2b'}],
#   'P7157': [{'value': '124'}],
#   'P8826': [{'value': 'H0005189'}],
#   'P6839': [{'value': 'UsefulNotes/Belgium'}],
#   'P8309': [{'value': '18-193836'}],
#   'P4527': [{'value': '8617'}],
#   'P5456': [{'value': 'belgium'}],
#   'P8974': [{'value': 'p/b4bc3740-2d3e-4ce2-875c-a2f6eb090a45'}],
#   'P9037': [{'value': 'ffd382be-2f2b-4c19-ae5a-6ba50f65aec5',
#     'references': [{'wikibase-entityid': {'P248': ['Q63411600']},
#       'string': {'P9037': ['ffd382be-2f2b-4c19-ae5a-6ba50f65aec5'],
#        'P691': ['ge128735']},
#       'time': {'P813': ['2020-12-22']}}]}],
#   'P9100': [{'value': 'belgium'}],
#   'P8814': [{'value': '08868745-n'}],
#   'P9123': [{'value': 'Bèlgica'}],
#   'P6592': [{'value': '7'}],
#   'P9223': [{'value': '5f4e5f29-55d6-4216-8da8-951c4651586d'}],
#   'P5739': [{'value': '6967'}],
#   'P9318': [{'value': 'belgia'}],
#   'P6293': [{'value': 'Y105206'}],
#   'P7850': [{'value': 'T84-674'}],
#   'P7960': [{'value': 'T115-332'}],
#   'P3553': [{'value': '19627981'}],
#   'P8217': [{'value': '2075743'}],
#   'P9368': [{'value': 'belgium',
#     'references': [{'string': {'P854': ['https://www.channelnewsasia.com/news/topic/belgium']},
#       'monolingualtext': {'P1476': ['BELGIUM latest news & coverage']},
#       'time': {'P813': ['2021-07-20']}}]}],
#   'P9629': [{'value': '2405'}],
#   'P9757': [{'value': '1062'}],
#   'P7841': [{'value': 'Բելգիա'}],
#   'P9948': [{'value': 'belgium'}],
#   'P8189': [{'value': '987007559777605171'}],
#   'P8248': [{'value': 'SG--5961',
#     'references': [{'wikibase-entityid': {'P248': ['Q95449814']}}]}],
#   'P3847': [{'value': 'place:belgium'}, {'value': 'belgium'}],
#   'P8885': [{'value': '벨기에'}],
#   'P10234': [{'value': 'belgien'}, {'value': 'belgium_en'}],
#   'P9466': [{'value': 'Belgien'}],
#   'P10297': [{'value': 'm0154j'}]},
#  'wikibase-entityid': {'P1344': [{'value': 'Q1088364'}],
#   'P1151': [{'value': 'Q3247091'}],
#   'P1546': [{'value': 'Q1308013'}],
#   'P5125': [{'value': 'Q7112200'}],
#   'P38': [{'value': 'Q4916',
#     'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#    {'value': 'Q232415'}],
#   'P1792': [{'value': 'Q7021332',
#     'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]}],
#   'P2852': [{'value': 'Q1061257'},
#    {'value': 'Q25648793',
#     'references': [{'string': {'P854': ['http://www.itu.int/net/itu-t/inrdb/e129_important_numbers.aspx']},
#       'time': {'P813': ['2016-07-10']},
#       'monolingualtext': {'P1680': ['ITU-T E.129 National-only numbers linked with emergency services and other services of social value'],
#        'P1476': ['International Numbering Resources Database']},
#       'wikibase-entityid': {'P98': ['Q376150']}}]},
#    {'value': 'Q25648794',
#     'references': [{'string': {'P854': ['http://www.itu.int/net/itu-t/inrdb/e129_important_numbers.aspx']},
#       'time': {'P813': ['2016-07-10']},
#       'monolingualtext': {'P1680': ['ITU-T E.129 National-only numbers linked with emergency services and other services of social value'],
#        'P1476': ['International Numbering Resources Database']},
#       'wikibase-entityid': {'P98': ['Q376150']}}]},
#    {'value': 'Q25648798'}],
#   'P2853': [{'value': 'Q1378312',
#     'references': [{'string': {'P854': ['http://www.iec.ch/worldplugs/list_bylocation.htm']},
#       'time': {'P813': ['2016-06-10']},
#       'wikibase-entityid': {'P98': ['Q193858']},
#       'monolingualtext': {'P1476': ['World Plugs']}}]},
#    {'value': 'Q2335536',
#     'references': [{'string': {'P854': ['http://www.iec.ch/worldplugs/list_bylocation.htm']},
#       'time': {'P813': ['2016-06-10']},
#       'wikibase-entityid': {'P98': ['Q193858']},
#       'monolingualtext': {'P1476': ['World Plugs']}}]}],
#   'P2633': [{'value': 'Q1115035'}],
#   'P1313': [{'value': 'Q213107'}],
#   'P417': [{'value': 'Q128267'}],
#   'P17': [{'value': 'Q31'}],
#   'P2959': [{'value': 'Q25929919'},
#    {'value': 'Q42311082',
#     'references': [{'wikibase-entityid': {'P3452': ['Q42311082']}}]},
#    {'value': 'Q52884026',
#     'references': [{'wikibase-entityid': {'P3452': ['Q52884026']}}]}],
#   'P122': [{'value': 'Q41614'}, {'value': 'Q3330103'}],
#   'P1552': [{'value': 'Q3174312',
#     'references': [{'string': {'P854': ['https://freedomhouse.org/report/freedom-world/freedom-world-2017']}}]}],
#   'P793': [{'value': 'Q223933'}, {'value': 'Q1160895'}],
#   'P530': [{'value': 'Q32'},
#    {'value': 'Q38'},
#    {'value': 'Q183',
#     'references': [{'wikibase-entityid': {'P3452': ['Q183']}}]},
#    {'value': 'Q347'},
#    {'value': 'Q408'},
#    {'value': 'Q212',
#     'references': [{'wikibase-entityid': {'P3452': ['Q212']}}]},
#    {'value': 'Q1246'},
#    {'value': 'Q142'},
#    {'value': 'Q145'},
#    {'value': 'Q16'},
#    {'value': 'Q252'},
#    {'value': 'Q35'},
#    {'value': 'Q43'},
#    {'value': 'Q55'},
#    {'value': 'Q77'},
#    {'value': 'Q833'},
#    {'value': 'Q843'},
#    {'value': 'Q865'},
#    {'value': 'Q96'},
#    {'value': 'Q974'},
#    {'value': 'Q30'},
#    {'value': 'Q159'},
#    {'value': 'Q668'},
#    {'value': 'Q41'},
#    {'value': 'Q148'},
#    {'value': 'Q230'},
#    {'value': 'Q801'},
#    {'value': 'Q29999'},
#    {'value': 'Q28'},
#    {'value': 'Q423',
#     'references': [{'time': {'P813': ['2020-06-03']},
#       'string': {'P854': ['https://www.ncnk.org/sites/default/files/content/resources/publications/NCNK_Issue_Brief_DPRK_Diplomatic_Relations.pdf']}}]}],
#   'P1906': [{'value': 'Q13592862'}],
#   'P194': [{'value': 'Q1137059'}],
#   'P2184': [{'value': 'Q205317'}],
#   'P37': [{'value': 'Q7411',
#     'references': [{'wikibase-entityid': {'P457': ['Q2865544']}},
#      {'string': {'P854': ['http://www.belgium.be/en/about_belgium/government/federale_staat']}}]},
#    {'value': 'Q150',
#     'references': [{'wikibase-entityid': {'P457': ['Q2865544']}},
#      {'string': {'P854': ['https://www.cia.gov/library/publications/the-world-factbook/geos/be.html']},
#       'time': {'P813': ['2015-06-01']}}]},
#    {'value': 'Q188',
#     'references': [{'wikibase-entityid': {'P457': ['Q2865544']}}]}],
#   'P30': [{'value': 'Q46',
#     'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]}],
#   'P36': [{'value': 'Q239',
#     'references': [{'wikibase-entityid': {'P143': ['Q10000']}},
#      {'string': {'P854': ['https://www.cia.gov/library/publications/the-world-factbook/geos/be.html']},
#       'time': {'P813': ['2015-06-01']}},
#      {'string': {'P854': ['http://www.traveldir.org/belgium/']},
#       'time': {'P813': ['2015-06-01']}}]}],
#   'P237': [{'value': 'Q199614',
#     'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]}],
#   'P910': [{'value': 'Q4366768',
#     'references': [{'wikibase-entityid': {'P3452': ['Q4366768']}}]}],
#   'P35': [{'value': 'Q155004',
#     'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#    {'value': 'Q12971'},
#    {'value': 'Q12967'},
#    {'value': 'Q55008046'},
#    {'value': 'Q12973'},
#    {'value': 'Q12976'},
#    {'value': 'Q3911'},
#    {'value': 'Q445553'},
#    {'value': 'Q1079522'}],
#   'P1791': [{'value': 'Q7974978'}],
#   'P5008': [{'value': 'Q54439832'}],
#   'P6': [{'value': 'Q18434995'}, {'value': 'Q950958'}, {'value': 'Q476596'}],
#   'P463': [{'value': 'Q458'},
#    {'value': 'Q1065'},
#    {'value': 'Q7184'},
#    {'value': 'Q41550'},
#    {'value': 'Q8908'},
#    {'value': 'Q13116'},
#    {'value': 'Q42262'},
#    {'value': 'Q7825'},
#    {'value': 'Q141720',
#     'references': [{'string': {'P854': ['http://eatc-mil.com/8/About-us']},
#       'time': {'P813': ['2017-12-08']}}]},
#    {'value': 'Q1542735'},
#    {'value': 'Q152299'},
#    {'value': 'Q151991'},
#    {'value': 'Q81299'},
#    {'value': 'Q191384'},
#    {'value': 'Q827525'},
#    {'value': 'Q656801'},
#    {'value': 'Q1043527'},
#    {'value': 'Q899770'},
#    {'value': 'Q340195'},
#    {'value': 'Q188822'},
#    {'value': 'Q782942'},
#    {'value': 'Q161549'},
#    {'value': 'Q1377612'},
#    {'value': 'Q663492'},
#    {'value': 'Q1928989'},
#    {'value': 'Q1072120',
#     'references': [{'string': {'P854': ['http://mtcr.info/partners/']},
#       'time': {'P813': ['2017-12-04']}}]},
#    {'value': 'Q8475',
#     'references': [{'string': {'P854': ['https://www.interpol.int/Member-countries/World']},
#       'wikibase-entityid': {'P123': ['Q8475']},
#       'time': {'P813': ['2017-12-07']}}]},
#    {'value': 'Q1480793',
#     'references': [{'string': {'P854': ['http://www.nuclearsuppliersgroup.org/en/participants1']},
#       'wikibase-entityid': {'P123': ['Q1480793']},
#       'time': {'P813': ['2017-12-07']}}]},
#    {'value': 'Q842490',
#     'references': [{'string': {'P854': ['https://www.opcw.org/about-opcw/member-states/']},
#       'wikibase-entityid': {'P123': ['Q842490']},
#       'time': {'P813': ['2017-12-07']}}]},
#    {'value': 'Q3866537',
#     'references': [{'string': {'P854': ['http://mcce-mil.com/wp-content/uploads/glance/MCCE-AT-A-Glance-September-2017.pdf']},
#       'time': {'P813': ['2017-12-08']}},
#      {'string': {'P854': ['http://mcce-mil.com/wp-content/uploads/glance/MCCE-AT-A-Glance-September-2017.pdf']},
#       'wikibase-entityid': {'P123': ['Q3866537']},
#       'time': {'P813': ['2017-12-08']}}]},
#    {'value': 'Q521227',
#     'references': [{'string': {'P854': ['http://www.occar.int/185']},
#       'wikibase-entityid': {'P123': ['Q521227']},
#       'time': {'P813': ['2017-12-08']}}]},
#    {'value': 'Q233611',
#     'references': [{'string': {'P854': ['https://www.iho.int/srv1/index.php?option=com_wrapper&view=wrapper&Itemid=452&lang=en']},
#       'wikibase-entityid': {'P123': ['Q233611']},
#       'time': {'P813': ['2017-12-08']}}]},
#    {'value': 'Q826700',
#     'references': [{'string': {'P854': ['https://www.iea.org/countries/membercountries/']},
#       'wikibase-entityid': {'P123': ['Q826700']},
#       'time': {'P813': ['2017-12-08']}}]},
#    {'value': 'Q7809',
#     'references': [{'string': {'P854': ['http://www.unesco.org/eri/cp/ListeMS_Indicators.asp']}}]},
#    {'value': 'Q5611262'},
#    {'value': 'Q17495',
#     'references': [{'string': {'P854': ['http://www.upu.int/en/the-upu/member-countries.html']},
#       'time': {'P813': ['2019-05-04']}}]},
#    {'value': 'Q376150',
#     'references': [{'string': {'P854': ['https://www.itu.int/online/mm/scripts/gensel8']},
#       'time': {'P813': ['2019-05-04']}}]},
#    {'value': 'Q1969730',
#     'references': [{'string': {'P854': ['https://www.touteleurope.eu/les-pays-membres-de-l-espace-schengen.html']}}]},
#    {'value': 'Q1531570',
#     'references': [{'string': {'P854': ['https://www.gbif.org/country/BE/summary']}}]},
#    {'value': 'Q134102'},
#    {'value': 'Q45177',
#     'references': [{'string': {'P854': ['https://www.dhs.gov/visa-waiver-program-requirements']},
#       'time': {'P813': ['2020-03-07']}}]},
#    {'value': 'Q170424',
#     'references': [{'string': {'P854': ['https://public.wmo.int/en/members/belgium']},
#       'time': {'P813': ['2020-05-26']}}]},
#    {'value': 'Q7817',
#     'references': [{'string': {'P854': ['https://www.who.int/choice/demography/by_country/en/']},
#       'time': {'P813': ['2020-07-21']}}]}],
#   'P5658': [{'value': 'Q13196750',
#     'references': [{'string': {'P4656': ['https://de.wikipedia.org/wiki/Mehrgleisigkeit#Fahrordnung_in_den_einzelnen_L%C3%A4ndern']}}]}],
#   'P1740': [{'value': 'Q7522716'}],
#   'P208': [{'value': 'Q390947'}],
#   'P2238': [{'value': 'Q130201'}],
#   'P1465': [{'value': 'Q8366417',
#     'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]}],
#   'P85': [{'value': 'Q161539',
#     'references': [{'string': {'P856': ['http://www.belgium.be/fr/la_belgique/connaitre_le_pays/la_belgique_en_bref/symboles/hymnes/']}}]}],
#   'P209': [{'value': 'Q1755321'},
#    {'value': 'Q1230309'},
#    {'value': 'Q1761425'}],
#   'P361': [{'value': 'Q215669'},
#    {'value': 'Q458'},
#    {'value': 'Q46'},
#    {'value': 'Q1065'},
#    {'value': 'Q13116'},
#    {'value': 'Q476033'}],
#   'P78': [{'value': 'Q39773',
#     'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]}],
#   'P47': [{'value': 'Q183',
#     'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#    {'value': 'Q32',
#     'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#    {'value': 'Q142',
#     'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#    {'value': 'Q55'},
#    {'value': 'Q29999'},
#    {'value': 'Q151938'}],
#   'P31': [{'value': 'Q3624078',
#     'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#    {'value': 'Q43702',
#     'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#    {'value': 'Q6256'},
#    {'value': 'Q20181813'},
#    {'value': 'Q185441'},
#    {'value': 'Q1250464'}],
#   'P610': [{'value': 'Q322824'}],
#   'P1464': [{'value': 'Q7463296',
#     'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]}],
#   'P1622': [{'value': 'Q14565199',
#     'references': [{'string': {'P854': ['http://chartsbin.com/view/edr']}}]}],
#   'P421': [{'value': 'Q25989',
#     'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]},
#    {'value': 'Q6655'},
#    {'value': 'Q6723'},
#    {'value': 'Q207020'},
#    {'value': 'Q5412099'}],
#   'P150': [{'value': 'Q9337'},
#    {'value': 'Q240'},
#    {'value': 'Q9331'},
#    {'value': 'Q89959'},
#    {'value': 'Q90027'},
#    {'value': 'Q231'}],
#   'P138': [{'value': 'Q337104',
#     'references': [{'wikibase-entityid': {'P143': ['Q848525']}}]}],
#   'P163': [{'value': 'Q12990'}],
#   'P1343': [{'value': 'Q302556'},
#    {'value': 'Q2657718'},
#    {'value': 'Q4114391'},
#    {'value': 'Q602358'},
#    {'value': 'Q19211082'},
#    {'value': 'Q19180675'},
#    {'value': 'Q4173137'},
#    {'value': 'Q3181656'},
#    {'value': 'Q20078554'},
#    {'value': 'Q867541'},
#    {'value': 'Q15987490'}],
#   'P92': [{'value': 'Q633629'}],
#   'P6104': [{'value': 'Q14455339'}],
#   'P527': [{'value': 'Q234'},
#    {'value': 'Q231'},
#    {'value': 'Q240'},
#    {'value': 'Q9331'},
#    {'value': 'Q89959'},
#    {'value': 'Q90027'}],
#   'P1304': [{'value': 'Q685918'}],
#   'P2936': [{'value': 'Q100103'},
#    {'value': 'Q102172'},
#    {'value': 'Q2107617'},
#    {'value': 'Q3217332'},
#    {'value': 'Q7411'},
#    {'value': 'Q9051'},
#    {'value': 'Q188'},
#    {'value': 'Q150'},
#    {'value': 'Q34024'},
#    {'value': 'Q34219'},
#    {'value': 'Q430018'},
#    {'value': 'Q671198'},
#    {'value': 'Q151156'},
#    {'value': 'Q34147'},
#    {'value': 'Q1404296'},
#    {'value': 'Q815549'},
#    {'value': 'Q2668371'},
#    {'value': 'Q8641'},
#    {'value': 'Q33282'},
#    {'value': 'Q1793299'}],
#   'P2596': [{'value': 'Q792363'}],
#   'P7867': [{'value': 'Q8607310'}],
#   'P8402': [{'value': 'Q63413946'}],
#   'P1365': [{'value': 'Q15864',
#     'references': [{'wikibase-entityid': {'P3452': ['Q15864']}}]}],
#   'P8744': [{'value': 'Q1769535'}],
#   'P9241': [{'value': 'Q1996422'}]},
#  'quantity': {'P1082': [{'value': ('11150516', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2014-01-01']}}]},
#    {'value': ('11099554', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2013-01-01']}}]},
#    {'value': ('11035948', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2012-01-01']}}]},
#    {'value': ('10951266', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2011-01-01']}}]},
#    {'value': ('10839905', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2010-01-01']}}]},
#    {'value': ('10753080', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2009-01-01']}}]},
#    {'value': ('10666866', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2008-01-01']}}]},
#    {'value': ('10584534', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2007-01-01']}}]},
#    {'value': ('10511382', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2006-01-01']}}]},
#    {'value': ('10445852', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2005-01-01']}}]},
#    {'value': ('10396421', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2004-01-01']}}]},
#    {'value': ('10355844', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2003-01-01']}}]},
#    {'value': ('10309725', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2002-01-01']}}]},
#    {'value': ('10263414', 1),
#     'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#       'time': {'P585': ['2001-01-01']}}]},
#    {'value': ('9153489', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9183948', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9220578', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9289770', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9378113', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9463667', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9527807', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9580991', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9618756', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9646032', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9655549', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9673162', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9711115', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9741720', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9772419', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9800700', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9818227', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9830358', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9839534', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9848382', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9859242', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9858982', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9856303', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9855520', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9855372', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9858308', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9861823', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9870234', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9901664', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9937697', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('9967379', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10004486', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10045158', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10084475', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10115603', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10136811', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10156637', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10181245', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10203008', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10226419', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10251250', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10286570', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10332785', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10376133', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10421137', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10478617', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10547958', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10625700', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10709973', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10796493', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('10920272', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('11047744', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('11128246', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('11182817', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('11372068', 1),
#     'references': [{'string': {'P854': ['https://data.worldbank.org/indicator/SP.POP.TOTL']},
#       'time': {'P813': ['2019-04-08']},
#       'wikibase-entityid': {'P248': ['Q21540096']}}]},
#    {'value': ('11431406', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population']}}]},
#    {'value': ('11492641', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('11431406', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('11376070', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('11322088', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('11267910', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('11209044', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('11150516', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('11099554', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('11035948', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10951266', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10839905', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10753080', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10665140', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10584534', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10511382', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10445852', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10396421', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10355844', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10309725', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10263414', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10239085', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10213752', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10192264', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10170226', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10142776', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10130398', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10100341', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10068319', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('10021997', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('9978681', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('9848647', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('9650944', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('9189737', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('8512185', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('8091997', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('7405570', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('7423784', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('6693546', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('6069317', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('5520016', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('4827834', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('4529465', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('4337198', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]},
#    {'value': ('3786556', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/en/themes/population/structure-population#figures']}}]}],
#   'P3529': [{'value': ('31112', 'Q4917')}],
#   'P2573': [{'value': ('8330', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q3152127']},
#       'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=3372']}}]},
#    {'value': ('11357', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q3152127']},
#       'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=3372']}}]},
#    {'value': ('12063', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q3152127']},
#       'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=3372']}}]},
#    {'value': ('95560', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q3152127']},
#       'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=3372']}}]},
#    {'value': ('97774', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q3152127']},
#       'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=3372']}}]}],
#   'P3271': [{'value': ('18', 'Q24564698'),
#     'references': [{'wikibase-entityid': {'P143': ['Q328']}}]}],
#   'P4841': [{'value': ('1.62', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.67', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.67', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.65', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.67', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.72', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.76', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.8', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.82', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.85', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.84', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.86', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.81', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.79', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.75', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('1.75', 1),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/index.aspx?queryid=239']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]}],
#   'P3270': [{'value': ('6', 'Q24564698'),
#     'references': [{'wikibase-entityid': {'P143': ['Q328']}}]}],
#   'P3001': [{'value': ('65', 'Q24564698'),
#     'references': [{'string': {'P854': ['https://web.archive.org/web/20190103162918/https://www.onprvp.fgov.be/NL/profes/benefits/retirement/age/paginas/default.aspx']}}]},
#    {'value': ('66', 'Q24564698'),
#     'references': [{'string': {'P854': ['https://web.archive.org/web/20190103162918/https://www.onprvp.fgov.be/NL/profes/benefits/retirement/age/paginas/default.aspx']}}]},
#    {'value': ('67', 'Q24564698')}],
#   'P3000': [{'value': ('18', 'Q24564698')}],
#   'P2997': [{'value': ('18', 'Q24564698'),
#     'references': [{'wikibase-entityid': {'P143': ['Q48183']}}]}],
#   'P1081': [{'value': ('0.755', 1)},
#    {'value': ('0.774', 1)},
#    {'value': ('0.806', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/countries/profiles/BEL']}},
#      {'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.851', 1)},
#    {'value': ('0.874', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/countries/profiles/BEL']}}]},
#    {'value': ('0.866', 1)},
#    {'value': ('0.883', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/countries/profiles/BEL']}}]},
#    {'value': ('0.886', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/countries/profiles/BEL']}}]},
#    {'value': ('0.889', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/countries/profiles/BEL']}}]},
#    {'value': ('0.888', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/countries/profiles/BEL']}}]},
#    {'value': ('0.890', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/countries/profiles/BEL']}}]},
#    {'value': ('0.810', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.825', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.839', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.845', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.852', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.857', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.862', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.866', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.868', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.873', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.876', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.879', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.882', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.885', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.889', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.896', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.899', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.899', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.899', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.903', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.904', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.905', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.908', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.909', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.913', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.915', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]},
#    {'value': ('0.916', 1),
#     'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#       'wikibase-entityid': {'P248': ['Q1185686']}}]}],
#   'P1198': [{'value': ('8', 'Q11229'),
#     'references': [{'string': {'P854': ['http://data.worldbank.org/indicator/SL.UEM.TOTL.ZS']}}]}],
#   'P2884': [{'value': ('230', 'Q25250'),
#     'references': [{'wikibase-entityid': {'P143': ['Q48183']}}]}],
#   'P2250': [{'value': ('77.61951', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('77.72195', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('77.97317', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('78.07561', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('78.12927', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('78.87805', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('78.98049', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('79.38049', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('79.78293', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('79.68049', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('80.03415', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('80.18293', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('80.58537', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('80.38537', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('80.5878', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('81.2878', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]},
#    {'value': ('80.99268', 'Q577'),
#     'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#       'wikibase-entityid': {'P248': ['Q3152127']}}]}],
#   'P2046': [{'value': ('30528', 'Q712226'),
#     'references': [{'wikibase-entityid': {'P143': ['Q24237997']}}]}],
#   'P2927': [{'value': ('0.8', 'Q11229'),
#     'references': [{'string': {'P854': ['http://en.worldstat.info/World/List_of_countries_by_Water_surface_(percentage_of_total_area)']},
#       'time': {'P813': ['2016-08-02']}}]}],
#   'P5982': [{'value': ('44725', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/fr/themes/population/mariages-et-divorces/mariages']},
#       'time': {'P813': ['2018-10-19']}},
#      {'string': {'P854': ['http://www.lalibre.be/actu/belgique/voici-le-nombre-de-mariages-et-divorces-par-communes-en-belgique-5a32911bcd700ea8c6f461b7']}}]},
#    {'value': ('45005', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/fr/themes/population/mariages-et-divorces/mariages#figures']}}]},
#    {'value': ('44858', 1),
#     'references': [{'string': {'P854': ['https://statbel.fgov.be/fr/themes/population/mariages-et-divorces/mariages#figures']}}]}],
#   'P6897': [{'value': ('99', 'Q11229'),
#     'references': [{'string': {'P854': ['https://www.worldatlas.com/articles/the-highest-literacy-rates-in-the-world.html']}}]}],
#   'P3864': [{'value': ('20.7', 1),
#     'references': [{'string': {'P854': ['https://apps.who.int/gho/athena/data/xmart.csv?target=GHO/SDGSUICIDE,SDG_SH_STA_SCIDEN&profile=crosstable&filter=COUNTRY:*;REGION:*;AGEGROUP:-&x-sideaxis=COUNTRY;SEX&x-topaxis=GHO;YEAR']}}]},
#    {'value': ('20.1', 1),
#     'references': [{'string': {'P854': ['https://apps.who.int/gho/athena/data/xmart.csv?target=GHO/SDGSUICIDE,SDG_SH_STA_SCIDEN&profile=crosstable&filter=COUNTRY:*;REGION:*;AGEGROUP:-&x-sideaxis=COUNTRY;SEX&x-topaxis=GHO;YEAR']}}]},
#    {'value': ('21.3', 1),
#     'references': [{'string': {'P854': ['https://apps.who.int/gho/athena/data/xmart.csv?target=GHO/SDGSUICIDE,SDG_SH_STA_SCIDEN&profile=crosstable&filter=COUNTRY:*;REGION:*;AGEGROUP:-&x-sideaxis=COUNTRY;SEX&x-topaxis=GHO;YEAR']}}]},
#    {'value': ('21.2', 1),
#     'references': [{'string': {'P854': ['https://apps.who.int/gho/athena/data/xmart.csv?target=GHO/SDGSUICIDE,SDG_SH_STA_SCIDEN&profile=crosstable&filter=COUNTRY:*;REGION:*;AGEGROUP:-&x-sideaxis=COUNTRY;SEX&x-topaxis=GHO;YEAR']}}]},
#    {'value': ('22.7', 1),
#     'references': [{'string': {'P854': ['https://apps.who.int/gho/athena/data/xmart.csv?target=GHO/SDGSUICIDE,SDG_SH_STA_SCIDEN&profile=crosstable&filter=COUNTRY:*;REGION:*;AGEGROUP:-&x-sideaxis=COUNTRY;SEX&x-topaxis=GHO;YEAR']}}]}],
#   'P2855': [{'value': ('21', 'Q11229')}],
#   'P8328': [{'value': ('7.51', 1),
#     'references': [{'wikibase-entityid': {'P248': ['Q105264748']},
#       'time': {'P813': ['2021-11-14']}}]},
#    {'value': ('7.64', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]},
#    {'value': ('7.78', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]},
#    {'value': ('7.78', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]},
#    {'value': ('7.77', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]},
#    {'value': ('7.93', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]},
#    {'value': ('7.93', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]},
#    {'value': ('8.05', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]},
#    {'value': ('8.05', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]},
#    {'value': ('8.05', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]},
#    {'value': ('8.05', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]},
#    {'value': ('8.16', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]},
#    {'value': ('8.15', 1),
#     'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#       'time': {'P813': ['2021-11-15']}}]}],
#   'P8843': [{'value': ('14.8', 'Q11229'),
#     'references': [{'string': {'P854': ['https://data.worldbank.org/indicator/SI.POV.NAHC?']}}]}]},
#  'globecoordinate': {'P1333': [{'value': {'latitude': 49.497111111111,
#      'longitude': 5.4726111111111,
#      'altitude': None,
#      'precision': 2.7777777777778e-05,
#      'globe': 'http://www.wikidata.org/entity/Q2'}}],
#   'P1335': [{'value': {'latitude': 51.08972292,
#      'longitude': 2.54882813,
#      'altitude': None,
#      'precision': 0.0001,
#      'globe': 'http://www.wikidata.org/entity/Q2'}}],
#   'P1332': [{'value': {'latitude': 51.5,
#      'longitude': 4.77,
#      'altitude': None,
#      'precision': 1e-06,
#      'globe': 'http://www.wikidata.org/entity/Q2'}}],
#   'P1334': [{'value': {'latitude': 50.3358193,
#      'longitude': 6.40743256,
#      'altitude': None,
#      'precision': 0.0001,
#      'globe': 'http://www.wikidata.org/entity/Q2'}}],
#   'P625': [{'value': {'latitude': 50.641111111111,
#      'longitude': 4.6680555555556,
#      'altitude': None,
#      'precision': 0.00027777777777778,
#      'globe': 'http://www.wikidata.org/entity/Q2'}}],
#   'P5140': [{'value': {'latitude': 50.641111111111,
#      'longitude': 4.6680555555556,
#      'altitude': None,
#      'precision': 0.00027777777777778,
#      'globe': 'http://www.wikidata.org/entity/Q2'},
#     'references': [{'wikibase-entityid': {'P459': ['Q511093']}}]}]},
#  'monolingualtext': {'P1448': [{'value': 'Königreich Belgien'},
#    {'value': 'Kingdom of Belgium',
#     'references': [{'wikibase-entityid': {'P248': ['Q107602286']}}]},
#    {'value': 'Koninkrijk België'},
#    {'value': 'Royaume de Belgique'}],
#   'P1549': [{'value': 'Belg'},
#    {'value': 'Belgian'},
#    {'value': 'belga'},
#    {'value': 'Belgische'},
#    {'value': 'Belge',
#     'references': [{'string': {'P854': ['http://cnig.gouv.fr/wp-content/uploads/2020/02/CNT-PVM_r%C3%A9vis%C3%A9_2020-01-27-1.pdf']}}]},
#    {'value': 'Belgier'},
#    {'value': 'belgier'},
#    {'value': 'Belgiano'},
#    {'value': 'belgo'},
#    {'value': 'Belgänan'},
#    {'value': 'பெல்ஜியர்'},
#    {'value': 'Belgičan'},
#    {'value': 'بلجيكي'},
#    {'value': 'بلجيكية'},
#    {'value': 'بلجيكيون'},
#    {'value': 'бельгієць'},
#    {'value': 'бельгійка'},
#    {'value': 'бельгійці'},
#    {'value': 'бельгийцы'},
#    {'value': 'belga'},
#    {'value': 'בלגי'},
#    {'value': 'בלגית'},
#    {'value': 'belgieni'},
#    {'value': 'belgian'},
#    {'value': 'belgiancă'},
#    {'value': 'Belsch'},
#    {'value': 'Belsch'},
#    {'value': 'belga'},
#    {'value': 'belgi'},
#    {'value': 'belghe'},
#    {'value': '比利时'},
#    {'value': 'beljes'},
#    {'value': 'belgisk'},
#    {'value': 'belxicanu'},
#    {'value': 'belxicana'},
#    {'value': 'belga'},
#    {'value': 'belxicano'},
#    {'value': 'Bedje'},
#    {'value': 'Belgen'},
#    {'value': 'Belzje'},
#    {'value': 'belgijanac'},
#    {'value': 'belgijanka'},
#    {'value': 'belgijanci'},
#    {'value': 'belgijanke'},
#    {'value': 'Belgierin'},
#    {'value': 'بیلج'},
#    {'value': 'بیلج'},
#    {'value': 'belgo'},
#    {'value': 'belghe'},
#    {'value': 'belzi'},
#    {'value': 'belghi'}],
#   'P1813': [{'value': '🇧🇪'}],
#   'P1451': [{'value': 'Eendracht maakt macht'},
#    {'value': "L'union fait la force",
#     'references': [{'string': {'P854': ['https://www.belgium.be/en/about_belgium/country/belgium_in_nutshell/symbols/coats_of_arms']}}]},
#    {'value': 'Unity makes strength'},
#    {'value': 'La unión hace la fuerza'},
#    {'value': "Undod sy'n creu cryfder"},
#    {'value': 'La Unió fa la força'},
#    {'value': 'The place to be',
#     'references': [{'wikibase-entityid': {'P143': ['Q328']}}]}],
#   'P1705': [{'value': 'Koninkrijk België'},
#    {'value': 'Royaume de Belgique'},
#    {'value': 'Königreich Belgien'}]},
#  'time': {'P571': [{'value': '1830-10-04',
#     'references': [{'wikibase-entityid': {'P143': ['Q328']}}]}]}}

# %% [markdown]
# Get all information

# %%
db.get_item("Q31")
# Out:
# {'wikidata_id': 'Q31',
#  'label': 'Belgium',
#  'labels': {'el': 'Βέλγιο',
#   'ay': 'Bilkiya',
#   'pnb': 'بیلجیئم',
#   'na': 'Berdjiyum',
#   'mk': 'Белгија',
#   'bn': 'বেলজিয়াম',
#   'bpy': 'বেলজিয়াম',
#   'lt': 'Belgija',
#   'jam': 'Beljiom',
#   'sk': 'Belgicko',
#   'so': 'Beljim',
#   'tl': 'Belgium',
#   'uk': 'Бельгія',
#   'tt': 'Билгия',
#   'sc': 'Bèlgiu',
#   'bxr': 'Бельги',
#   'ff': 'Beljik',
#   'za': 'Bijliswz',
#   'yo': 'Bẹ́ljíọ̀m',
#   'ext': 'Bélgica',
#   'zea': 'Belhië',
#   'es': 'Bélgica',
#   'or': 'ବେଲଜିଅମ',
#   'myv': 'Бельгия Мастор',
#   'yi': 'בעלגיע',
#   'ga': 'An Bheilg',
#   'csb': 'Belgijskô',
#   'gag': 'Belgiya',
#   'oc': 'Belgica',
#   'pfl': 'Belgje',
#   'rw': 'Ububiligi',
#   'sco': 'Belgium',
#   'sgs': 'Belgėjė',
#   'ltg': 'Beļgeja',
#   'zh-sg': '比利时',
#   'tet': 'Béljika',
#   'az': 'Belçika',
#   'mzn': 'بلژیک',
#   'zh-hk': '比利時',
#   'bar': 'Bäigien',
#   'zh': '比利時',
#   'nl': 'België',
#   'lez': 'Бельгия',
#   'ast': 'Bélxica',
#   'bm': 'Bɛliziki',
#   'ta': 'பெல்ஜியம்',
#   'jv': 'Bélgié',
#   'inh': 'Бельги',
#   'hi': 'बेल्जियम',
#   'co': 'Belgica',
#   'mn': 'Бельги',
#   'pms': 'Belgi',
#   'om': 'Beeljiyeem',
#   'sl': 'Belgija',
#   'crh': 'Belçika',
#   'ms': 'Belgium',
#   'ro': 'Belgia',
#   'bho': 'बेल्जियम',
#   'av': 'Бельгия',
#   'lb': 'Belsch',
#   'en-gb': 'Belgium',
#   'kaa': 'Belgiya',
#   'ps': 'بلجیم',
#   'stq': 'Belgien',
#   'aeb-arab': 'بلجيكيا',
#   'lo': 'ປະເທດແບນຊິກ',
#   'sw': 'Ubelgiji',
#   'nds': 'Belgien',
#   'ksh': 'Belgien',
#   'bcl': 'Belhika',
#   'pag': 'Belhika',
#   'da': 'Belgien',
#   'ca': 'Bèlgica',
#   'crh-latn': 'Belçika',
#   'lv': 'Beļģija',
#   'rup': 'Belghia',
#   'ady': 'Белгие',
#   'ty': 'Peretita',
#   'gv': 'Yn Velg',
#   'kbp': 'Pɛliziki',
#   'pt-br': 'Bélgica',
#   'ar': 'بلجيكا',
#   'srn': 'Belgikondre',
#   'ch': 'Belgika',
#   'diq': 'Belçıka',
#   'pih': 'Beljum',
#   'szl': 'Belgijŏ',
#   'ace': 'Bèlgia',
#   'cv': 'Бельги',
#   'ak': 'Belgium',
#   'pt': 'Bélgica',
#   'io': 'Belgia',
#   'zh-my': '比利时',
#   'ru': 'Бельгия',
#   'tpi': 'Beljiam',
#   'th': 'ประเทศเบลเยียม',
#   'ha': 'Beljik',
#   'mg': 'Belzika',
#   'azb': 'بلژیک',
#   'an': 'Belchica',
#   'eml': 'Bélgi',
#   'hy': 'Բելգիա',
#   'vep': "Bel'gii",
#   'mai': 'बेल्जियम',
#   'nov': 'Belgia',
#   'ne': 'बेल्जियम',
#   'eo': 'Belgio',
#   'de': 'Belgien',
#   'ig': 'Belgium',
#   'sm': 'Peleseuma',
#   'pam': 'Belhika',
#   'war': 'Belhika',
#   'rmy': 'Beljiya',
#   'jbo': 'beldjym',
#   'kbd': 'Белгэ',
#   'ug': 'بېلگىيە',
#   'mdf': 'Бельгие',
#   'mwl': 'Bélgica',
#   'lrc': 'بلجیک',
#   'en': 'Belgium',
#   'as': 'বেলজিয়াম',
#   'bgn': 'بلجیم',
#   'os': 'Бельги',
#   'my': 'ဘယ်လ်ဂျီယမ်နိုင်ငံ',
#   'zh-cn': '比利时',
#   'sma': 'Belgia',
#   'dz': 'བེལ་ཇིཡམ',
#   'et': 'Belgia',
#   'cbk-zam': 'Bélgica',
#   'wo': 'Belsik',
#   'bug': 'Belgia',
#   'zh-tw': '比利時',
#   'nn': 'Belgia',
#   'chr': 'ᏇᎵᏥᎥᎻ',
#   'wuu': '比利时',
#   'lg': 'Bubirigi',
#   'nrm': 'Belgique',
#   'gl': 'Bélxica',
#   'zh-mo': '比利時',
#   'ee': 'Belgium',
#   'bi': 'Belgium',
#   'rm': 'Belgia',
#   'pdc': 'Belgien',
#   'ckb': 'بەلجیکا',
#   'ln': 'Bɛ́ljika',
#   'rn': 'Ububirigi',
#   'frp': 'Bèlg·ique',
#   'cy': 'Gwlad Belg',
#   'nso': 'Belgium',
#   'la': 'Belgica',
#   'ky': 'Бельгия',
#   'mr': 'बेल्जियम',
#   'fo': 'Belgia',
#   'fr': 'Belgique',
#   'got': '𐌱𐌰𐌹𐌻𐌲𐌰𐌻𐌰𐌽𐌳',
#   'is': 'Belgía',
#   'hsb': 'Belgiska',
#   'mt': 'Belġju',
#   'li': 'Belsj',
#   'vro': 'Belgiä',
#   'fi': 'Belgia',
#   'zh-hant': '比利時',
#   'id': 'Belgia',
#   'gom': 'बेल्जियम',
#   'gu': 'બેલ્જિયમ',
#   'su': 'Bélgia',
#   'ia': 'Belgica',
#   'pa': 'ਬੈਲਜੀਅਮ',
#   'wa': 'Beldjike',
#   'vi': 'Bỉ',
#   'ilo': 'Belhika',
#   'roa-tara': 'Bèlge',
#   'gom-latn': 'Belgium',
#   'af': 'België',
#   'ceb': 'Belhika',
#   'krc': 'Бельгия',
#   'sg': 'Bêleze',
#   'nb': 'Belgia',
#   'gsw': 'Belgie',
#   'si': 'බෙල්ජියම',
#   'zh-hans': '比利时',
#   'sv': 'Belgien',
#   'tum': 'Belgium',
#   'scn': 'Belgiu',
#   'kab': 'Biljik',
#   'bg': 'Белгия',
#   'eu': 'Belgika',
#   'xmf': 'ბელგია',
#   'vo': 'Belgän',
#   'it': 'Belgio',
#   'pap': 'Bélgika',
#   'gom-deva': 'बेल्जियम',
#   'haw': 'Pelekiuma',
#   'liv': 'Beļgij',
#   'pcd': 'Bergike',
#   'kl': 'Belgia',
#   'he': 'בלגיה',
#   'dsb': 'Belgiska',
#   'be-tarask': 'Бэльгія',
#   'vec': 'Belzo',
#   'cdo': 'Bī-lé-sì',
#   'nan': 'Pe̍k-ní-gī',
#   'gn': 'Véyhika',
#   'tg': 'Белгия',
#   'bs': 'Belgija',
#   'sd': 'بيلجيم',
#   'sh': 'Belgija',
#   'hu': 'Belgium',
#   'yue': '比利時',
#   'te': 'బెల్జియం',
#   'koi': 'Белгия',
#   'ba': 'Бельгия',
#   'sah': 'Бельгия',
#   'ang': 'Belgice',
#   'pi': 'बेल्जियम',
#   'uz': 'Belgiya',
#   'tk': 'Belgiýa',
#   'hif': 'Belgium',
#   'xal': 'Бельҗмудин Нутг',
#   'cu': 'Бєлгїѥ',
#   'new': 'बेल्जियम',
#   'fur': 'Belgjo',
#   'ht': 'Bèljik',
#   'sn': 'Belgium',
#   'tr': 'Belçika',
#   'ie': 'Belgia',
#   'gd': "A' Bheilg",
#   'be': 'Бельгія',
#   'ka': 'ბელგია',
#   'ce': 'Бельги',
#   'kv': 'Бельгия',
#   'fa': 'بلژیک',
#   'nds-nl': 'België',
#   'bo': 'པེར་ཅིན།',
#   'mi': 'Pehiamu',
#   'pl': 'Belgia',
#   'en-ca': 'Belgium',
#   'tw': 'Belgium',
#   'am': 'ቤልጅግ',
#   'sr-el': 'Belgija',
#   'udm': 'Бельгия',
#   'kk': 'Бельгия',
#   'kn': 'ಬೆಲ್ಜಿಯಂ',
#   'nap': 'Belge',
#   'ur': 'بیلجیئم',
#   'frr': 'Belgien',
#   'vls': 'België',
#   'sq': 'Belgjika',
#   'kg': 'Belezi',
#   'pnt': 'Βέλγιον',
#   'de-ch': 'Belgien',
#   'mhr': 'Бельгий',
#   'ml': 'ബെൽജിയം',
#   'rue': 'Белґія',
#   'fy': 'Belgje',
#   'ku': 'Belçîka',
#   'olo': "Bel'gii",
#   'arc': 'ܒܠܓܝܩܐ',
#   'ss': 'IBhelijiyamu',
#   'ts': 'Belgium',
#   'dv': 'ބެލްޖިއަމް',
#   'arz': 'بلجيكا',
#   'se': 'Belgia',
#   'nah': 'Belgica',
#   'qu': 'Bilhika',
#   'cs': 'Belgie',
#   'kw': 'Pow Belg',
#   'lij': 'Belgio',
#   'lad': 'Beljika',
#   'sr-ec': 'Белгија',
#   'hr': 'Belgija',
#   'ja': 'ベルギー',
#   'ko': '벨기에',
#   'lfn': 'Beljia',
#   'br': 'Belgia',
#   'lzh': '比利時',
#   'sa': 'बेल्जियम्',
#   'lmo': 'Belgi',
#   'hak': 'Pí-li-sṳ̀',
#   'dty': 'बेल्जियम',
#   'sr': 'Белгија',
#   'de-at': 'Belgien',
#   'hyw': 'Պելճիքա',
#   'ab': 'Бельгиа',
#   'kea': 'Béljika',
#   'ban': 'Belgia',
#   'szy': 'Belguim',
#   'gcr': 'Bèljik',
#   'km': 'បែលស៊ិក',
#   'sat': 'ᱵᱮᱞᱡᱤᱭᱚᱢ',
#   'ary': 'بلجيكا',
#   'map-bms': 'Belgia',
#   'shn': 'မိူင်းပႄႇၵျီႇယမ်ႇ',
#   'smn': 'Belgia',
#   'sms': 'Belgia',
#   'awa': 'बेल्जियम',
#   'avk': 'Belga',
#   'lld': 'Belje',
#   'mad': 'Belgia',
#   'tay': 'Belguim',
#   'shi': 'Bljika',
#   'ny': 'Belgium',
#   'grc': 'Βέλγιον',
#   'mni': 'ꯕꯦꯜꯖꯤꯌꯝ',
#   'als': 'Belgien',
#   'trv': 'Belguim'},
#  'descriptions': {'cy': 'wlad yn Ewrop',
#   'sk': 'štát v Europe',
#   'mk': 'земја во Европа',
#   'vls': "pays d'europe",
#   'fr': "État d'Europe occidentale",
#   'zh': '西歐國家',
#   'it': "stato dell'Europa occidentale, membro dell'Unione europea",
#   'jv': 'nagara ing Éropah',
#   'pl': 'państwo w Europie',
#   'bn': 'পশ্চিম ইউরোপের যুক্তরাষ্ট্রীয় সাংবিধানিক রাজতন্ত্র',
#   'fi': 'valtio Länsi-Euroopassa',
#   'en-ca': 'constitutional monarchy in Western Europe',
#   'uk': 'держава у Західній Європі',
#   'id': 'negara di Eropa Barat',
#   'vi': 'một quốc gia có chủ quyền tại Tây Âu',
#   'pt': 'país da Europa',
#   'pa': "ਯੂਰਪ 'ਚ ਦੇਸ਼",
#   'zh-my': '西欧国家',
#   'ru': 'государство в Западной Европе',
#   'de-ch': 'Staat in Westeuropa',
#   'fa': 'کشوری در قاره اروپا',
#   'th': 'ราชอาณาจักรในยุโรปตะวันตก',
#   'zh-tw': '西歐國家',
#   'ilo': 'pederal nga estado idiay Lumaud nga Europa',
#   'es': 'país de Europa',
#   'tr': "Batı Avrupa'da bir ülke",
#   'hy': 'դաշնային թագավորություն Եվրոպայում',
#   'de-at': 'Staat in Westeuropa',
#   'hu': 'állam Nyugat-Európában',
#   'zh-hant': '西歐國家',
#   'nb': 'land i Europa',
#   'gsw': 'Staat in Mitteleuropa',
#   'eo': 'federacio en Eŭropo',
#   'ne': 'युरोपको देश',
#   'zh-hans': '西欧国家',
#   'sv': 'konstitutionell monarki i Västeuropa',
#   'nl': 'federale staat in West-Europa',
#   'de': 'föderaler Staat in Westeuropa',
#   'bg': 'държава в Западна Европа',
#   'la': 'civitas Europae',
#   'scn': "paìsi di l'Europa di punenti",
#   'el': 'χώρα της δυτικής Ευρώπης',
#   'tet': 'rai iha Europa',
#   'ar': 'دولة في أوروبا الغربية',
#   'zh-hk': '西歐國家',
#   'pt-br': 'país da Europa',
#   'sr-el': 'država u zapadnoj Evropi',
#   'kn': 'ಪಶ್ಚಿಮ ಯುರೋಪಿನ ಸಾಂವಿಧಾನಿಕ ರಾಜಾಡಳಿತ ಹೊಂದಿರುವ ದೇಶ',
#   'en': 'country in western Europe',
#   'ta': 'மேற்கு ஐரோப்பிய நாடு',
#   'zh-cn': '西欧国家',
#   'hsb': 'stat w zapadnej Europje',
#   'hi': 'पश्चिमी यूरोप में एक संघीय संवैधानिक राजशाही',
#   'cs': 'stát v Evropě',
#   'zh-sg': '西欧国家',
#   'he': 'מדינה באירופה',
#   'ro': 'stat în Europa de Vest',
#   'bho': 'पच्छिमी यूरोप में एगो संघीय संबैधानिक राजतंत्र',
#   'lb': 'Staat an Europa',
#   'sr-ec': 'држава у западној Европи',
#   'en-gb': 'country in Europe',
#   'hr': 'država u zapadnoj Europi',
#   'ja': '西ヨーロッパに位置する国家',
#   'ko': '서유럽에 위치한 국가',
#   'te': 'ఐరోపా లోని ఒక దేశం',
#   'br': 'stad Europa',
#   'zh-mo': '西歐國家',
#   'sw': 'nchi katika Ulaya Magharibi',
#   'nds': 'Staat in Mitteleuropa',
#   'da': 'Et land i Europa',
#   'sr': 'држава у западној Европи',
#   'ca': "país d'Europa",
#   'lv': 'Valsts Eiropā',
#   'ie': 'Un Land in Europa',
#   'ml': 'വടക്കുപടിഞ്ഞാറേ യൂറോപ്പിൽ ഉള്ള ഒരു രാജ്യം',
#   'se': 'riika Eurohpás',
#   'az': 'Qərbi Avropada konstusiyalı monarxiya ölkə',
#   'ht': 'peyi ki nan pati oksidantal kontinan Ewopeyen',
#   'wa': "payis di l' Urope do Coûtchant",
#   'gl': 'país europeo',
#   'sd': 'اولاھين يورپ ۾ ملڪ',
#   'vec': 'Stato del Nord Eoropa',
#   'ku': 'Welatekî Ewropayê',
#   'ckb': 'دەوڵەتی باڵادەست لە ڕۆژاوای ئەورووپا',
#   'mr': 'पश्चिम यूरपातील एक देश',
#   'bs': 'država u zapadnoj Evropi',
#   'szl': 'państwo we zachodnij Ojropie',
#   'pap': 'pais na Oropa',
#   'mt': 'pajjiż fl-Ewropa tal-Punent',
#   'yue': '西歐國家',
#   'be': 'краіна',
#   'be-tarask': 'краіна',
#   'grc': 'Εὐρώπης χώρα',
#   'pnb': 'لہندا یورپ دا اک دیش',
#   'ur': 'مغربی یورپ کا ایک ملک'},
#  'aliases': {'bg': ['Кралство Белгия'],
#   'en-gb': ['Southern Netherlands'],
#   'mk': ['Кралство Белгија'],
#   'zh-hk': ['比利時王國'],
#   'pt-br': ['Reino da Bélgica'],
#   'fr': ['BE', 'Belg.', 'Royaume de Belgique', 'be', '🇧🇪'],
#   'en': ['BE', 'BEL', 'Kingdom of Belgium', 'be', '🇧🇪'],
#   'zh': ['比利时', '比利时王国', '比利時王國'],
#   'tr': ['Belçika Krallığı'],
#   'jv': ['Bèlgi', 'Kraton Bélgié'],
#   'bho': ['बेलजियम', 'बेल्जियम राज', 'बेल्जीयम'],
#   'be-tarask': ['Бэльґія'],
#   'bn': ['বেলজিয়াম রাজ্য'],
#   'ta': ['பெல்சியம்', 'பெல்ஜிய பேரரசு'],
#   'zh-cn': ['比利时王国'],
#   'ko': ['벨기에 왕국', '벨기에왕국'],
#   'uk': ['Королівство Бельгія'],
#   'th': ['Belgium',
#    'ประเทศเบลเยี่ยม',
#    'ราชอาณาจักรเบลเยียม',
#    'ราชอาณาจักรเบลเยี่ยม',
#    'เบลเยียม',
#    'เบลเยี่ยม'],
#   'zh-my': ['比利时王国'],
#   'zh-tw': ['比利時王國'],
#   'ru': ['Belgique', 'Королевство Бельгия'],
#   'tl': ['Belhika'],
#   'lij': ['Belgiò'],
#   'zh-sg': ['比利时王国'],
#   'nds-nl': ['Belgie'],
#   'roa-tara': ['Belge', 'Belgio'],
#   'hy': ['Բելգիայի Թագավորություն'],
#   'es': ['BE', 'Belgica', 'Reino de Belgica', 'Reino de Bélgica'],
#   'pa': ['ਬੈਲਜੀਅਮ ਦਾ ਰਾਜ'],
#   'nan': ['Belgie', 'Belgien', 'Belgium', 'België', 'Pí-lī-sî', 'Tāi-pí-kok'],
#   'hr': ['Kraljevina Belgija'],
#   'pl': ['Królestwo Belgii'],
#   'zh-hant': ['比利時王國'],
#   'nb': ['Kongeriket Belgia'],
#   'zh-mo': ['比利時王國'],
#   'fi': ['Belgian kuningaskunta'],
#   'zh-hans': ['比利时王国'],
#   'nl': ['BE', 'BEL', 'Belgenland', 'Belgie', 'Koninkrijk België', 'be', '🇧🇪'],
#   'yue': ['Belgien',
#    'Belgique',
#    'Belgium',
#    'België',
#    'Koninkrijk België',
#    'Königreich Belgien',
#    'Royaume de Belgique'],
#   'ca': ['België', 'Bélgica', 'Estat belga', 'Regne de Bèlgica'],
#   'pam': ['Belgika', 'Belgium', 'Belika'],
#   'el': ['Βασίλειο του Βελγίου'],
#   'vls': ['BE'],
#   'ak': ['Ɔman Belgium'],
#   'ast': ['🇧🇪'],
#   'de': ['BE', 'BEL', 'Königreich Belgien', '🇧🇪'],
#   'hi': ['बेल्जियम बादशाहत', '🇧🇪'],
#   'mr': ['🇧🇪'],
#   'ne': ['🇧🇪'],
#   'sa': ['🇧🇪'],
#   'ja': ['ベルギー王国'],
#   'da': ['Belgique',
#    'België',
#    'Kongeriget Belgien',
#    'Koninkrijk België',
#    'Royaume de Belgique'],
#   'se': ['Belgia gonagasriika'],
#   'smn': ['Belgia kunâgâskodde'],
#   'sms': ['Belgia koonǥõskåʹdd'],
#   'szl': ['Krōlestwo Belgije'],
#   'mt': ['Renju tal-Belġju'],
#   'vec': ['BE', 'BEL', 'Bèlzega'],
#   'ku': ['Belgiya'],
#   'av': ['Белген'],
#   'bar': ['Bejgien'],
#   'bi': ['Beljiom'],
#   'frp': ['Bèlgica'],
#   'kbd': ['Белгиэ'],
#   'ksh': ['Beljie'],
#   'mzn': ['بلجیک'],
#   'pfl': ['Belgien'],
#   'ps': ['بېلجیم'],
#   'sat': ['ᱵᱮᱞᱡᱤᱭᱟᱢ'],
#   'tt': ['Бельгия'],
#   'tw': ['Bɛlgyiom'],
#   'zea': ['België'],
#   'ban': ['Bélgia'],
#   'gsw': ['Belgien'],
#   'grc': ['Βελγική'],
#   'ckb': ['بەلژیک', 'بەلژیکا'],
#   'frr': ['Belgien/fe'],
#   'km': ['បែលហ្សិក'],
#   'ur': ['بلجئیم', 'بیلجیم', 'مملکت بیلجیئم']},
#  'sitelinks': {'itwikivoyage': 'Belgio',
#   'zhwikivoyage': '比利时',
#   'ruwikivoyage': 'Бельгия',
#   'fawikiquote': 'بلژیک',
#   'dewikivoyage': 'Belgien',
#   'enwikivoyage': 'Belgium',
#   'hewikivoyage': 'בלגיה',
#   'eowikinews': 'Kategorio:Belgujo',
#   'frwikinews': 'Catégorie:Belgique',
#   'trwikinews': 'Kategori:Belçika',
#   'plwikiquote': 'Belgia',
#   'nlwikinews': 'Categorie:België',
#   'rowikivoyage': 'Belgia',
#   'svwikivoyage': 'Belgien',
#   'arwikinews': 'تصنيف:بلجيكا',
#   'frwikivoyage': 'Belgique',
#   'nlwikibooks': 'Atlas van Europa/België',
#   'enwikiquote': 'Belgium',
#   'rowikinews': 'Categorie:Belgia',
#   'jawikinews': 'カテゴリ:ベルギー',
#   'itwikiquote': 'Belgio',
#   'ptwikibooks': 'Bélgica',
#   'viwikivoyage': 'Bỉ',
#   'kowikinews': '분류:벨기에',
#   'ptwikinews': 'Categoria:Bélgica',
#   'fawikivoyage': 'بلژیک',
#   'fiwikinews': 'Luokka:Belgia',
#   'plwikivoyage': 'Belgia',
#   'cawikinews': 'Categoria:Bèlgica',
#   'srwikinews': 'Категорија:Белгија',
#   'ptwikivoyage': 'Bélgica',
#   'enwikinews': 'Category:Belgium',
#   'svwikinews': 'Kategori:Belgien',
#   'eswikivoyage': 'Bélgica',
#   'elwikinews': 'Κατηγορία:Βέλγιο',
#   'bswikinews': 'Kategorija:Belgija',
#   'sqwikinews': 'Kategoria:Belgjikë',
#   'eswikinews': 'Categoría:Bélgica',
#   'nlwikiquote': 'België',
#   'ukwikinews': 'Категорія:Бельгія',
#   'hewikiquote': 'בלגיה',
#   'cswikinews': 'Kategorie:Belgie',
#   'nowikinews': 'Kategori:Belgia',
#   'zhwikinews': 'Category:比利時',
#   'ukwikivoyage': 'Бельгія',
#   'hywikiquote': 'Բելգիա',
#   'frwikiquote': 'Belgique',
#   'nlwikivoyage': 'België',
#   'eswikiquote': 'Bélgica',
#   'huwikinews': 'Kategória:Belgium',
#   'plwikinews': 'Kategoria:Belgia',
#   'ruwikinews': 'Категория:Бельгия',
#   'tawikinews': 'பகுப்பு:பெல்ஜியம்',
#   'dewikinews': 'Kategorie:Belgien',
#   'liwikibooks': 'Belsj',
#   'itwikinews': 'Categoria:Belgio',
#   'elwikivoyage': 'Βέλγιο',
#   'fawikinews': 'رده:بلژیک',
#   'fiwikivoyage': 'Belgia',
#   'commonswiki': 'België - Belgique - Belgien',
#   'arwikiquote': 'بلجيكا',
#   'jawikivoyage': 'ベルギー',
#   'eowikivoyage': 'Belgio',
#   'trwikivoyage': 'Belçika',
#   'hewikinews': 'קטגוריה:בלגיה',
#   'eowikiquote': 'Belgio',
#   'etwikiquote': 'Belgia',
#   'enwiki': 'Belgium',
#   'dewiki': 'Belgien',
#   'frwiki': 'Belgique',
#   'eswiki': 'Bélgica',
#   'ruwiki': 'Бельгия',
#   'itwiki': 'Belgio',
#   'jawiki': 'ベルギー',
#   'nlwiki': 'België',
#   'plwiki': 'Belgia',
#   'ptwiki': 'Bélgica',
#   'zhwiki': '比利时',
#   'svwiki': 'Belgien',
#   'fawiki': 'بلژیک',
#   'hewiki': 'בלגיה',
#   'trwiki': 'Belçika',
#   'huwiki': 'Belgium',
#   'fiwiki': 'Belgia',
#   'arwiki': 'بلجيكا',
#   'viwiki': 'Bỉ',
#   'nowiki': 'Belgia',
#   'ukwiki': 'Бельгія',
#   'kowiki': '벨기에',
#   'cawiki': 'Bèlgica',
#   'cswiki': 'Belgie',
#   'srwiki': 'Белгија',
#   'rowiki': 'Belgia',
#   'idwiki': 'Belgia',
#   'dawiki': 'Belgien',
#   'simplewiki': 'Belgium',
#   'bgwiki': 'Белгия',
#   'abwiki': 'Бельгиа',
#   'acewiki': 'Bèlgia',
#   'adywiki': 'Белгие',
#   'afwiki': 'België',
#   'akwiki': 'Belgium',
#   'alswiki': 'Belgien',
#   'amwiki': 'ቤልጅግ',
#   'amiwiki': 'Belguim',
#   'anwiki': 'Belchica',
#   'angwiki': 'Belgice',
#   'arcwiki': 'ܒܠܓܝܩܐ',
#   'arywiki': 'بلجيكا',
#   'arzwiki': 'بلجيكا',
#   'astwiki': 'Bélxica',
#   'avwiki': 'Белген',
#   'avkwiki': 'Belga',
#   'awawiki': 'बेल्जियम',
#   'aywiki': 'Bilkiya',
#   'azwiki': 'Belçika',
#   'azbwiki': 'بلژیک',
#   'bawiki': 'Бельгия',
#   'banwiki': 'Bélgia',
#   'barwiki': 'Bejgien',
#   'bat_smgwiki': 'Belgėjė',
#   'bclwiki': 'Belhika',
#   'bewiki': 'Бельгія',
#   'be_x_oldwiki': 'Бэльгія',
#   'bhwiki': 'बेल्जियम',
#   'biwiki': 'Beljiom',
#   'bmwiki': 'Bɛliziki',
#   'bnwiki': 'বেলজিয়াম',
#   'bowiki': 'པེར་ཅིན།',
#   'bpywiki': 'বেলজিয়াম',
#   'brwiki': 'Belgia',
#   'bswiki': 'Belgija',
#   'bugwiki': 'Belgia',
#   'bxrwiki': 'Бельги',
#   'cbk_zamwiki': 'Bélgica',
#   'cdowiki': 'Bī-lé-sì',
#   'cewiki': 'Бельги',
#   'cebwiki': 'Belhika',
#   'chwiki': 'Belgika',
#   'chrwiki': 'ᏇᎵᏥᎥᎻ',
#   'ckbwiki': 'بەلجیکا',
#   'cowiki': 'Belgica',
#   'crhwiki': 'Belçika',
#   'csbwiki': 'Belgijskô',
#   'cuwiki': 'Бєлгїѥ',
#   'cvwiki': 'Бельги',
#   'cywiki': 'Gwlad Belg',
#   'diqwiki': 'Belçıka',
#   'dsbwiki': 'Belgiska',
#   'dtywiki': 'बेल्जियम',
#   'dvwiki': 'ބެލްޖިއަމް',
#   'dzwiki': 'བེལ་ཇིཡམ',
#   'eewiki': 'Belgium',
#   'elwiki': 'Βέλγιο',
#   'emlwiki': 'Bélgi',
#   'eowiki': 'Belgio',
#   'etwiki': 'Belgia',
#   'euwiki': 'Belgika',
#   'extwiki': 'Bélgica',
#   'ffwiki': 'Beljik',
#   'fiu_vrowiki': 'Belgiä',
#   'fowiki': 'Belgia',
#   'frpwiki': 'Bèlgica',
#   'frrwiki': 'Belgien/fe',
#   'furwiki': 'Belgjo',
#   'fywiki': 'Belgje',
#   'gawiki': 'An Bheilg',
#   'gagwiki': 'Belgiya',
#   'gcrwiki': 'Bèljik',
#   'gdwiki': "A' Bheilg",
#   'glwiki': 'Bélxica',
#   'gnwiki': 'Véyhika',
#   'gomwiki': 'बेल्जियम',
#   'gotwiki': '𐌱𐌰𐌹𐌻𐌲𐌰𐌻𐌰𐌽𐌳',
#   'guwiki': 'બેલ્જિયમ',
#   'gvwiki': 'Yn Velg',
#   'hawiki': 'Beljik',
#   'hakwiki': 'Pí-li-sṳ̀',
#   'hawwiki': 'Pelekiuma',
#   'hiwiki': 'बेल्जियम',
#   'hifwiki': 'Belgium',
#   'hrwiki': 'Belgija',
#   'hsbwiki': 'Belgiska',
#   'htwiki': 'Bèljik',
#   'hywiki': 'Բելգիա',
#   'hywwiki': 'Պելճիքա',
#   'iawiki': 'Belgica',
#   'iewiki': 'Belgia',
#   'igwiki': 'Belgium',
#   'ilowiki': 'Belhika',
#   'inhwiki': 'Бельги',
#   'iowiki': 'Belgia',
#   'iswiki': 'Belgía',
#   'jamwiki': 'Beljiom',
#   'jbowiki': 'beldjym',
#   'jvwiki': 'Bèlgi',
#   'kawiki': 'ბელგია',
#   'kaawiki': 'Belgiya',
#   'kabwiki': 'Biljik',
#   'kbdwiki': 'Белгиэ',
#   'kbpwiki': 'Pɛliziki',
#   'kgwiki': 'Belezi',
#   'kkwiki': 'Бельгия',
#   'klwiki': 'Belgia',
#   'kmwiki': 'បែលហ្សិក',
#   'knwiki': 'ಬೆಲ್ಜಿಯಂ',
#   'koiwiki': 'Белгия',
#   'krcwiki': 'Бельгия',
#   'kshwiki': 'Beljie',
#   'kuwiki': 'Belçîka',
#   'kvwiki': 'Бельгия',
#   'kwwiki': 'Pow Belg',
#   'kywiki': 'Бельгия',
#   'lawiki': 'Belgica',
#   'ladwiki': 'Beljika',
#   'lbwiki': 'Belsch',
#   'lezwiki': 'Бельгия',
#   'lfnwiki': 'Beljia',
#   'lgwiki': 'Bubirigi',
#   'liwiki': 'Belsj',
#   'lijwiki': 'Belgio',
#   'lldwiki': 'Belje',
#   'lmowiki': 'Belgi',
#   'lnwiki': 'Bɛ́ljika',
#   'lowiki': 'ປະເທດແບນຊິກ',
#   'ltwiki': 'Belgija',
#   'ltgwiki': 'Beļgeja',
#   'lvwiki': 'Beļģija',
#   'madwiki': 'Belgia',
#   'maiwiki': 'बेल्जियम',
#   'map_bmswiki': 'Belgia',
#   'mdfwiki': 'Бельгие',
#   'mgwiki': 'Belzika',
#   'mhrwiki': 'Бельгий',
#   'miwiki': 'Pehiamu',
#   'mkwiki': 'Белгија',
#   'mlwiki': 'ബെൽജിയം',
#   'mnwiki': 'Бельги',
#   'mniwiki': 'ꯕꯦꯜꯖꯤꯌꯝ',
#   'mrwiki': 'बेल्जियम',
#   'mswiki': 'Belgium',
#   'mtwiki': 'Belġju',
#   'mwlwiki': 'Bélgica',
#   'mywiki': 'ဘယ်လ်ဂျီယမ်နိုင်ငံ',
#   'myvwiki': 'Бельгия Мастор',
#   'mznwiki': 'بلجیک',
#   'nawiki': 'Berdjiyum',
#   'nahwiki': 'Belgica',
#   'napwiki': 'Belge',
#   'ndswiki': 'Belgien',
#   'nds_nlwiki': 'België',
#   'newiki': 'बेल्जियम',
#   'newwiki': 'बेल्जियम',
#   'nnwiki': 'Belgia',
#   'novwiki': 'Belgia',
#   'nrmwiki': 'Belgique',
#   'nsowiki': 'Belgium',
#   'nywiki': 'Belgium',
#   'ocwiki': 'Belgica',
#   'olowiki': "Bel'gii",
#   'omwiki': 'Beeljiyeem',
#   'oswiki': 'Бельги',
#   'pawiki': 'ਬੈਲਜੀਅਮ',
#   'pagwiki': 'Belhika',
#   'pamwiki': 'Belgika',
#   'papwiki': 'Bélgika',
#   'pcdwiki': 'Bergike',
#   'pdcwiki': 'Belgien',
#   'pflwiki': 'Belgien',
#   'piwiki': 'बेल्जियम',
#   'pihwiki': 'Beljum',
#   'pmswiki': 'Belgi',
#   'pnbwiki': 'بیلجیم',
#   'pntwiki': 'Βέλγιον',
#   'pswiki': 'بېلجیم',
#   'quwiki': 'Bilhika',
#   'rmwiki': 'Belgia',
#   'rmywiki': 'Beljiya',
#   'rnwiki': 'Ububirigi',
#   'roa_tarawiki': 'Bèlge',
#   'ruewiki': 'Белґія',
#   'rwwiki': 'Ububiligi',
#   'sawiki': 'बेल्जियम्',
#   'sahwiki': 'Бельгия',
#   'satwiki': 'ᱵᱮᱞᱡᱤᱭᱟᱢ',
#   'scwiki': 'Bèlgiu',
#   'scnwiki': 'Belgiu',
#   'scowiki': 'Belgium',
#   'sdwiki': 'بيلجيم',
#   'sewiki': 'Belgia',
#   'sgwiki': 'Bêleze',
#   'shwiki': 'Belgija',
#   'shiwiki': 'Bljika',
#   'shnwiki': 'မိူင်းပႄႇၵျီႇယမ်ႇ',
#   'siwiki': 'බෙල්ජියම',
#   'skwiki': 'Belgicko',
#   'slwiki': 'Belgija',
#   'smwiki': 'Peleseuma',
#   'smnwiki': 'Belgia',
#   'snwiki': 'Belgium',
#   'sowiki': 'Beljim',
#   'sqwiki': 'Belgjika',
#   'srnwiki': 'Belgikondre',
#   'sswiki': 'IBhelijiyamu',
#   'stqwiki': 'Belgien',
#   'suwiki': 'Bélgia',
#   'swwiki': 'Ubelgiji',
#   'szlwiki': 'Belgijŏ',
#   'szywiki': 'Belguim',
#   'tawiki': 'பெல்ஜியம்',
#   'taywiki': 'Belguim',
#   'tewiki': 'బెల్జియం',
#   'tetwiki': 'Béljika',
#   'tgwiki': 'Белгия',
#   'thwiki': 'ประเทศเบลเยียม',
#   'tkwiki': 'Belgiýa',
#   'tlwiki': 'Belhika',
#   'tpiwiki': 'Beljiam',
#   'trvwiki': 'Belguim',
#   'tswiki': 'Belgium',
#   'ttwiki': 'Бельгия',
#   'tumwiki': 'Belgium',
#   'twwiki': 'Bɛlgyiom',
#   'udmwiki': 'Бельгия',
#   'ugwiki': 'بېلگىيە',
#   'urwiki': 'بلجئیم',
#   'uzwiki': 'Belgiya',
#   'vecwiki': 'Belzo',
#   'vepwiki': "Bel'gii",
#   'vlswiki': 'België',
#   'vowiki': 'Belgän',
#   'wawiki': 'Beldjike',
#   'warwiki': 'Belhika',
#   'wowiki': 'Belsik',
#   'wuuwiki': '比利时',
#   'xalwiki': 'Бельҗмудин Нутг',
#   'xmfwiki': 'ბელგია',
#   'yiwiki': 'בעלגיע',
#   'yowiki': 'Bẹ́ljíọ̀m',
#   'zawiki': 'Bijliswz',
#   'zeawiki': 'België',
#   'zh_classicalwiki': '比利時',
#   'zh_min_nanwiki': 'Pe̍k-ní-gī',
#   'zh_yuewiki': '比利時'},
#  'claims': {'string': {'P2924': [{'value': '4075290'}],
#    'P1667': [{'value': '1000063'}],
#    'P3348': [{'value': '2020'}],
#    'P349': [{'value': '00560624'}],
#    'P3365': [{'value': 'belgio'}],
#    'P3221': [{'value': 'destination/belgium'}],
#    'P2581': [{'value': '00009714n',
#      'references': [{'wikibase-entityid': {'P248': ['Q4837690']}}]}],
#    'P1566': [{'value': '2802361'}],
#    'P227': [{'value': '4005406-8',
#      'references': [{'wikibase-entityid': {'P143': ['Q48183']}}]}],
#    'P487': [{'value': '🇧🇪'}],
#    'P3916': [{'value': 'concept893'}],
#    'P395': [{'value': 'B'}],
#    'P3238': [{'value': '0'}],
#    'P298': [{'value': 'BEL'}],
#    'P3417': [{'value': 'Belgium'}, {'value': 'Belge'}],
#    'P998': [{'value': 'Regional/Europe/Belgium/'}],
#    'P486': [{'value': 'D001530'}],
#    'P3106': [{'value': 'world/belgium'}],
#    'P982': [{'value': '5b8a5ee5-0bb3-34cf-9a75-c27c44e341fc',
#      'references': [{'wikibase-entityid': {'P248': ['Q14005']}}]}],
#    'P94': [{'value': 'Great coat of arms of Belgium.svg'},
#     {'value': 'State Coat of Arms of Belgium.svg'},
#     {'value': 'Arms of Belgium (with crown).svg'},
#     {'value': 'Royal Arms of Belgium.svg'}],
#    'P2981': [{'value': 'B',
#      'references': [{'string': {'P854': ['http://otif.org/fileadmin/user_upload/otif_verlinkte_files/06_tech_zulass/05_Reglementation_en_vigueur/Neu_ab_01_01_2015/UTP_MARKING_2015_e_in_force.pdf']}}]}],
#    'P3422': [{'value': '99131'}],
#    'P935': [{'value': 'België - Belgique - Belgien'}],
#    'P214': [{'value': '144248059'}],
#    'P5180': [{'value': 'belgium'}],
#    'P605': [{'value': 'BE'}],
#    'P4613': [{'value': '39061'}],
#    'P3911': [{'value': '17201-5'}],
#    'P3984': [{'value': 'belgium',
#      'references': [{'time': {'P813': ['2018-05-06']}}]}],
#    'P856': [{'value': 'https://www.belgium.be/nl'},
#     {'value': 'https://www.belgium.be/en'},
#     {'value': 'https://www.belgium.be/fr'},
#     {'value': 'https://www.belgium.be/de'}],
#    'P3896': [{'value': 'Data:Belgium.map'}],
#    'P949': [{'value': '000981380',
#      'references': [{'wikibase-entityid': {'P248': ['Q54919']},
#        'string': {'P214': ['259064514'],
#         'P854': ['http://www.viaf.org/viaf/259064514/']},
#        'time': {'P813': ['2016-04-01']}}]}],
#    'P402': [{'value': '52411'}],
#    'P4725': [{'value': '19875'}],
#    'P3068': [{'value': 'BE'}],
#    'P691': [{'value': 'ge128735'}],
#    'P906': [{'value': '140654'}],
#    'P3241': [{'value': '02395a'}],
#    'P2258': [{'value': '206'}],
#    'P2979': [{'value': '205'}],
#    'P1225': [{'value': '10035761'}],
#    'P5198': [{'value': '294901094',
#      'references': [{'wikibase-entityid': {'P248': ['Q54856619']},
#        'time': {'P813': ['2018-06-13']}}]}],
#    'P1315': [{'value': '1028458'}],
#    'P3612': [{'value': 'pays/belgique'}],
#    'P268': [{'value': '15238382r',
#      'references': [{'wikibase-entityid': {'P248': ['Q54919']},
#        'string': {'P214': ['144248059']},
#        'time': {'P813': ['2018-10-07']}}]}],
#    'P242': [{'value': 'EU-Belgium.svg'},
#     {'value': 'Belgium (orthographic projection).svg'}],
#    'P1617': [{'value': 'e68c5b82-50e8-47d8-953c-bf61a2de0a85'}],
#    'P1036': [{'value': '2--493'}],
#    'P3743': [{'value': '2.16.56'}],
#    'P984': [{'value': 'BEL',
#      'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]}],
#    'P2163': [{'value': '1210278'}],
#    'P4342': [{'value': 'Belgia'}],
#    'P4427': [{'value': '766'}],
#    'P5573': [{'value': '2969',
#      'references': [{'string': {'P854': ['https://www.archinform.net/service/wd_aiort.php']},
#        'wikibase-entityid': {'P248': ['Q265049']},
#        'time': {'P813': ['2018-08-05']}}]}],
#    'P1417': [{'value': 'place/Belgium'}],
#    'P4629': [{'value': 'Belgium'}],
#    'P948': [{'value': 'Belgium Banner.jpg'}],
#    'P2347': [{'value': '105206'}],
#    'P1296': [{'value': '0008719'}],
#    'P373': [{'value': 'Belgium'}],
#    'P6150': [{'value': '6974'}],
#    'P4672': [{'value': '3b33aed2-40bc-48a9-baa0-3ff78ba4a5aa',
#      'references': [{'wikibase-entityid': {'P143': ['Q28054658']}}]}],
#    'P2982': [{'value': '88',
#      'references': [{'string': {'P854': ['http://uic.org/country-codes']}}]}],
#    'P3222': [{'value': 'belgien'}],
#    'P898': [{'value': 'ˈbɛlgɪɑ'},
#     {'value': 'ˈbʲelʲɡʲɪjə'},
#     {'value': 'bɛl.ʒik'}],
#    'P299': [{'value': '056'}],
#    'P269': [{'value': '026360608'}],
#    'P5247': [{'value': '3035-254'}],
#    'P3024': [{'value': 'BEL'}],
#    'P474': [{'value': '+32'}],
#    'P646': [{'value': '/m/0154j',
#      'references': [{'wikibase-entityid': {'P248': ['Q15241312']},
#        'time': {'P577': ['2013-10-28']}}]}],
#    'P3175': [{'value': 'ube'}],
#    'P244': [{'value': 'n80126041'}],
#    'P297': [{'value': 'BE'}],
#    'P901': [{'value': 'BE',
#      'references': [{'wikibase-entityid': {'P248': ['Q3063249']},
#        'string': {'P1065': ['https://web.archive.org/web/20010208080459/http://www.itl.nist.gov:80/fipspubs/fip10-4.htm']}}]}],
#    'P3509': [{'value': 'belgien'}],
#    'P41': [{'value': 'Flag of Belgium (civil).svg'},
#     {'value': 'Flag of Belgium.svg'}],
#    'P5019': [{'value': 'belgien'}],
#    'P1842': [{'value': 'Belgium'}],
#    'P6573': [{'value': 'Belgien'}],
#    'P5250': [{'value': '1249'}],
#    'P4801': [{'value': 'countries/be'}],
#    'P6363': [{'value': 'http://data.thenextweb.com/tnw/entity/belgium',
#      'references': [{'string': {'P854': ['https://thenextweb.com/vocabulary/belgium/']}}]}],
#    'P5905': [{'value': '4020-55916'}],
#    'P6404': [{'value': 'belgio'}],
#    'P7012': [{'value': 'belgium'}],
#    'P6766': [{'value': '85632997'}],
#    'P5002': [{'value': '77978'}],
#    'P6849': [{'value': 'belgien'}],
#    'P989': [{'value': 'Nl-België-article.ogg'}],
#    'P7471': [{'value': '7008',
#      'references': [{'wikibase-entityid': {'P248': ['Q16958215']}}]}],
#    'P1245': [{'value': '5689'}],
#    'P7314': [{'value': 'belcika'}],
#    'P902': [{'value': '003349'}],
#    'P3067': [{'value': '540-549'}],
#    'P5400': [{'value': 'wxtrbw'}],
#    'P7870': [{'value': '6826'}],
#    'P7818': [{'value': 'Belgique'}],
#    'P7829': [{'value': 'Belgium'}],
#    'P7827': [{'value': 'Bélgica'}],
#    'P7832': [{'value': 'Belgika'}],
#    'P7822': [{'value': 'Belgio'}],
#    'P443': [{'value': 'Lb-Belsch.ogg'},
#     {'value': 'LL-Q7913 (ron)-KlaudiuMihaila-Belgia.wav'}],
#    'P5437': [{'value': '4839'}],
#    'P7982': [{'value': '6718'}],
#    'P6058': [{'value': 'pays/wd/108227'}],
#    'P7859': [{'value': 'lccn-n80126041',
#      'references': [{'string': {'P214': ['144248059']}}]}],
#    'P7322': [{'value': '14'}],
#    'P8349': [{'value': '11670'}],
#    'P8408': [{'value': 'Belgium',
#      'references': [{'wikibase-entityid': {'P248': ['Q64139102']},
#        'time': {'P813': ['2020-07-09']}}]}],
#    'P6385': [{'value': 'strany_mira/BELGIYA.html'}],
#    'P8406': [{'value': 'T007414'}],
#    'P8519': [{'value': '3995'}],
#    'P5063': [{'value': 'i83329'}],
#    'P1438': [{'value': '10489'}],
#    'P3749': [{'value': '5182502652099301362'}],
#    'P6200': [{'value': 'cz4pr2gdgrdt'}],
#    'P8714': [{'value': 'BEL'}],
#    'P5587': [{'value': 'xv8b9nqg4r1hd2b'}],
#    'P7157': [{'value': '124'}],
#    'P8826': [{'value': 'H0005189'}],
#    'P6839': [{'value': 'UsefulNotes/Belgium'}],
#    'P8309': [{'value': '18-193836'}],
#    'P4527': [{'value': '8617'}],
#    'P5456': [{'value': 'belgium'}],
#    'P8974': [{'value': 'p/b4bc3740-2d3e-4ce2-875c-a2f6eb090a45'}],
#    'P9037': [{'value': 'ffd382be-2f2b-4c19-ae5a-6ba50f65aec5',
#      'references': [{'wikibase-entityid': {'P248': ['Q63411600']},
#        'string': {'P9037': ['ffd382be-2f2b-4c19-ae5a-6ba50f65aec5'],
#         'P691': ['ge128735']},
#        'time': {'P813': ['2020-12-22']}}]}],
#    'P9100': [{'value': 'belgium'}],
#    'P8814': [{'value': '08868745-n'}],
#    'P9123': [{'value': 'Bèlgica'}],
#    'P6592': [{'value': '7'}],
#    'P9223': [{'value': '5f4e5f29-55d6-4216-8da8-951c4651586d'}],
#    'P5739': [{'value': '6967'}],
#    'P9318': [{'value': 'belgia'}],
#    'P6293': [{'value': 'Y105206'}],
#    'P7850': [{'value': 'T84-674'}],
#    'P7960': [{'value': 'T115-332'}],
#    'P3553': [{'value': '19627981'}],
#    'P8217': [{'value': '2075743'}],
#    'P9368': [{'value': 'belgium',
#      'references': [{'string': {'P854': ['https://www.channelnewsasia.com/news/topic/belgium']},
#        'monolingualtext': {'P1476': ['BELGIUM latest news & coverage']},
#        'time': {'P813': ['2021-07-20']}}]}],
#    'P9629': [{'value': '2405'}],
#    'P9757': [{'value': '1062'}],
#    'P7841': [{'value': 'Բելգիա'}],
#    'P9948': [{'value': 'belgium'}],
#    'P8189': [{'value': '987007559777605171'}],
#    'P8248': [{'value': 'SG--5961',
#      'references': [{'wikibase-entityid': {'P248': ['Q95449814']}}]}],
#    'P3847': [{'value': 'place:belgium'}, {'value': 'belgium'}],
#    'P8885': [{'value': '벨기에'}],
#    'P10234': [{'value': 'belgien'}, {'value': 'belgium_en'}],
#    'P9466': [{'value': 'Belgien'}],
#    'P10297': [{'value': 'm0154j'}]},
#   'wikibase-entityid': {'P1344': [{'value': 'Q1088364'}],
#    'P1151': [{'value': 'Q3247091'}],
#    'P1546': [{'value': 'Q1308013'}],
#    'P5125': [{'value': 'Q7112200'}],
#    'P38': [{'value': 'Q4916',
#      'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#     {'value': 'Q232415'}],
#    'P1792': [{'value': 'Q7021332',
#      'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]}],
#    'P2852': [{'value': 'Q1061257'},
#     {'value': 'Q25648793',
#      'references': [{'string': {'P854': ['http://www.itu.int/net/itu-t/inrdb/e129_important_numbers.aspx']},
#        'time': {'P813': ['2016-07-10']},
#        'monolingualtext': {'P1680': ['ITU-T E.129 National-only numbers linked with emergency services and other services of social value'],
#         'P1476': ['International Numbering Resources Database']},
#        'wikibase-entityid': {'P98': ['Q376150']}}]},
#     {'value': 'Q25648794',
#      'references': [{'string': {'P854': ['http://www.itu.int/net/itu-t/inrdb/e129_important_numbers.aspx']},
#        'time': {'P813': ['2016-07-10']},
#        'monolingualtext': {'P1680': ['ITU-T E.129 National-only numbers linked with emergency services and other services of social value'],
#         'P1476': ['International Numbering Resources Database']},
#        'wikibase-entityid': {'P98': ['Q376150']}}]},
#     {'value': 'Q25648798'}],
#    'P2853': [{'value': 'Q1378312',
#      'references': [{'string': {'P854': ['http://www.iec.ch/worldplugs/list_bylocation.htm']},
#        'time': {'P813': ['2016-06-10']},
#        'wikibase-entityid': {'P98': ['Q193858']},
#        'monolingualtext': {'P1476': ['World Plugs']}}]},
#     {'value': 'Q2335536',
#      'references': [{'string': {'P854': ['http://www.iec.ch/worldplugs/list_bylocation.htm']},
#        'time': {'P813': ['2016-06-10']},
#        'wikibase-entityid': {'P98': ['Q193858']},
#        'monolingualtext': {'P1476': ['World Plugs']}}]}],
#    'P2633': [{'value': 'Q1115035'}],
#    'P1313': [{'value': 'Q213107'}],
#    'P417': [{'value': 'Q128267'}],
#    'P17': [{'value': 'Q31'}],
#    'P2959': [{'value': 'Q25929919'},
#     {'value': 'Q42311082',
#      'references': [{'wikibase-entityid': {'P3452': ['Q42311082']}}]},
#     {'value': 'Q52884026',
#      'references': [{'wikibase-entityid': {'P3452': ['Q52884026']}}]}],
#    'P122': [{'value': 'Q41614'}, {'value': 'Q3330103'}],
#    'P1552': [{'value': 'Q3174312',
#      'references': [{'string': {'P854': ['https://freedomhouse.org/report/freedom-world/freedom-world-2017']}}]}],
#    'P793': [{'value': 'Q223933'}, {'value': 'Q1160895'}],
#    'P530': [{'value': 'Q32'},
#     {'value': 'Q38'},
#     {'value': 'Q183',
#      'references': [{'wikibase-entityid': {'P3452': ['Q183']}}]},
#     {'value': 'Q347'},
#     {'value': 'Q408'},
#     {'value': 'Q212',
#      'references': [{'wikibase-entityid': {'P3452': ['Q212']}}]},
#     {'value': 'Q1246'},
#     {'value': 'Q142'},
#     {'value': 'Q145'},
#     {'value': 'Q16'},
#     {'value': 'Q252'},
#     {'value': 'Q35'},
#     {'value': 'Q43'},
#     {'value': 'Q55'},
#     {'value': 'Q77'},
#     {'value': 'Q833'},
#     {'value': 'Q843'},
#     {'value': 'Q865'},
#     {'value': 'Q96'},
#     {'value': 'Q974'},
#     {'value': 'Q30'},
#     {'value': 'Q159'},
#     {'value': 'Q668'},
#     {'value': 'Q41'},
#     {'value': 'Q148'},
#     {'value': 'Q230'},
#     {'value': 'Q801'},
#     {'value': 'Q29999'},
#     {'value': 'Q28'},
#     {'value': 'Q423',
#      'references': [{'time': {'P813': ['2020-06-03']},
#        'string': {'P854': ['https://www.ncnk.org/sites/default/files/content/resources/publications/NCNK_Issue_Brief_DPRK_Diplomatic_Relations.pdf']}}]}],
#    'P1906': [{'value': 'Q13592862'}],
#    'P194': [{'value': 'Q1137059'}],
#    'P2184': [{'value': 'Q205317'}],
#    'P37': [{'value': 'Q7411',
#      'references': [{'wikibase-entityid': {'P457': ['Q2865544']}},
#       {'string': {'P854': ['http://www.belgium.be/en/about_belgium/government/federale_staat']}}]},
#     {'value': 'Q150',
#      'references': [{'wikibase-entityid': {'P457': ['Q2865544']}},
#       {'string': {'P854': ['https://www.cia.gov/library/publications/the-world-factbook/geos/be.html']},
#        'time': {'P813': ['2015-06-01']}}]},
#     {'value': 'Q188',
#      'references': [{'wikibase-entityid': {'P457': ['Q2865544']}}]}],
#    'P30': [{'value': 'Q46',
#      'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]}],
#    'P36': [{'value': 'Q239',
#      'references': [{'wikibase-entityid': {'P143': ['Q10000']}},
#       {'string': {'P854': ['https://www.cia.gov/library/publications/the-world-factbook/geos/be.html']},
#        'time': {'P813': ['2015-06-01']}},
#       {'string': {'P854': ['http://www.traveldir.org/belgium/']},
#        'time': {'P813': ['2015-06-01']}}]}],
#    'P237': [{'value': 'Q199614',
#      'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]}],
#    'P910': [{'value': 'Q4366768',
#      'references': [{'wikibase-entityid': {'P3452': ['Q4366768']}}]}],
#    'P35': [{'value': 'Q155004',
#      'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#     {'value': 'Q12971'},
#     {'value': 'Q12967'},
#     {'value': 'Q55008046'},
#     {'value': 'Q12973'},
#     {'value': 'Q12976'},
#     {'value': 'Q3911'},
#     {'value': 'Q445553'},
#     {'value': 'Q1079522'}],
#    'P1791': [{'value': 'Q7974978'}],
#    'P5008': [{'value': 'Q54439832'}],
#    'P6': [{'value': 'Q18434995'}, {'value': 'Q950958'}, {'value': 'Q476596'}],
#    'P463': [{'value': 'Q458'},
#     {'value': 'Q1065'},
#     {'value': 'Q7184'},
#     {'value': 'Q41550'},
#     {'value': 'Q8908'},
#     {'value': 'Q13116'},
#     {'value': 'Q42262'},
#     {'value': 'Q7825'},
#     {'value': 'Q141720',
#      'references': [{'string': {'P854': ['http://eatc-mil.com/8/About-us']},
#        'time': {'P813': ['2017-12-08']}}]},
#     {'value': 'Q1542735'},
#     {'value': 'Q152299'},
#     {'value': 'Q151991'},
#     {'value': 'Q81299'},
#     {'value': 'Q191384'},
#     {'value': 'Q827525'},
#     {'value': 'Q656801'},
#     {'value': 'Q1043527'},
#     {'value': 'Q899770'},
#     {'value': 'Q340195'},
#     {'value': 'Q188822'},
#     {'value': 'Q782942'},
#     {'value': 'Q161549'},
#     {'value': 'Q1377612'},
#     {'value': 'Q663492'},
#     {'value': 'Q1928989'},
#     {'value': 'Q1072120',
#      'references': [{'string': {'P854': ['http://mtcr.info/partners/']},
#        'time': {'P813': ['2017-12-04']}}]},
#     {'value': 'Q8475',
#      'references': [{'string': {'P854': ['https://www.interpol.int/Member-countries/World']},
#        'wikibase-entityid': {'P123': ['Q8475']},
#        'time': {'P813': ['2017-12-07']}}]},
#     {'value': 'Q1480793',
#      'references': [{'string': {'P854': ['http://www.nuclearsuppliersgroup.org/en/participants1']},
#        'wikibase-entityid': {'P123': ['Q1480793']},
#        'time': {'P813': ['2017-12-07']}}]},
#     {'value': 'Q842490',
#      'references': [{'string': {'P854': ['https://www.opcw.org/about-opcw/member-states/']},
#        'wikibase-entityid': {'P123': ['Q842490']},
#        'time': {'P813': ['2017-12-07']}}]},
#     {'value': 'Q3866537',
#      'references': [{'string': {'P854': ['http://mcce-mil.com/wp-content/uploads/glance/MCCE-AT-A-Glance-September-2017.pdf']},
#        'time': {'P813': ['2017-12-08']}},
#       {'string': {'P854': ['http://mcce-mil.com/wp-content/uploads/glance/MCCE-AT-A-Glance-September-2017.pdf']},
#        'wikibase-entityid': {'P123': ['Q3866537']},
#        'time': {'P813': ['2017-12-08']}}]},
#     {'value': 'Q521227',
#      'references': [{'string': {'P854': ['http://www.occar.int/185']},
#        'wikibase-entityid': {'P123': ['Q521227']},
#        'time': {'P813': ['2017-12-08']}}]},
#     {'value': 'Q233611',
#      'references': [{'string': {'P854': ['https://www.iho.int/srv1/index.php?option=com_wrapper&view=wrapper&Itemid=452&lang=en']},
#        'wikibase-entityid': {'P123': ['Q233611']},
#        'time': {'P813': ['2017-12-08']}}]},
#     {'value': 'Q826700',
#      'references': [{'string': {'P854': ['https://www.iea.org/countries/membercountries/']},
#        'wikibase-entityid': {'P123': ['Q826700']},
#        'time': {'P813': ['2017-12-08']}}]},
#     {'value': 'Q7809',
#      'references': [{'string': {'P854': ['http://www.unesco.org/eri/cp/ListeMS_Indicators.asp']}}]},
#     {'value': 'Q5611262'},
#     {'value': 'Q17495',
#      'references': [{'string': {'P854': ['http://www.upu.int/en/the-upu/member-countries.html']},
#        'time': {'P813': ['2019-05-04']}}]},
#     {'value': 'Q376150',
#      'references': [{'string': {'P854': ['https://www.itu.int/online/mm/scripts/gensel8']},
#        'time': {'P813': ['2019-05-04']}}]},
#     {'value': 'Q1969730',
#      'references': [{'string': {'P854': ['https://www.touteleurope.eu/les-pays-membres-de-l-espace-schengen.html']}}]},
#     {'value': 'Q1531570',
#      'references': [{'string': {'P854': ['https://www.gbif.org/country/BE/summary']}}]},
#     {'value': 'Q134102'},
#     {'value': 'Q45177',
#      'references': [{'string': {'P854': ['https://www.dhs.gov/visa-waiver-program-requirements']},
#        'time': {'P813': ['2020-03-07']}}]},
#     {'value': 'Q170424',
#      'references': [{'string': {'P854': ['https://public.wmo.int/en/members/belgium']},
#        'time': {'P813': ['2020-05-26']}}]},
#     {'value': 'Q7817',
#      'references': [{'string': {'P854': ['https://www.who.int/choice/demography/by_country/en/']},
#        'time': {'P813': ['2020-07-21']}}]}],
#    'P5658': [{'value': 'Q13196750',
#      'references': [{'string': {'P4656': ['https://de.wikipedia.org/wiki/Mehrgleisigkeit#Fahrordnung_in_den_einzelnen_L%C3%A4ndern']}}]}],
#    'P1740': [{'value': 'Q7522716'}],
#    'P208': [{'value': 'Q390947'}],
#    'P2238': [{'value': 'Q130201'}],
#    'P1465': [{'value': 'Q8366417',
#      'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]}],
#    'P85': [{'value': 'Q161539',
#      'references': [{'string': {'P856': ['http://www.belgium.be/fr/la_belgique/connaitre_le_pays/la_belgique_en_bref/symboles/hymnes/']}}]}],
#    'P209': [{'value': 'Q1755321'},
#     {'value': 'Q1230309'},
#     {'value': 'Q1761425'}],
#    'P361': [{'value': 'Q215669'},
#     {'value': 'Q458'},
#     {'value': 'Q46'},
#     {'value': 'Q1065'},
#     {'value': 'Q13116'},
#     {'value': 'Q476033'}],
#    'P78': [{'value': 'Q39773',
#      'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]}],
#    'P47': [{'value': 'Q183',
#      'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#     {'value': 'Q32',
#      'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#     {'value': 'Q142',
#      'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#     {'value': 'Q55'},
#     {'value': 'Q29999'},
#     {'value': 'Q151938'}],
#    'P31': [{'value': 'Q3624078',
#      'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#     {'value': 'Q43702',
#      'references': [{'wikibase-entityid': {'P143': ['Q10000']}}]},
#     {'value': 'Q6256'},
#     {'value': 'Q20181813'},
#     {'value': 'Q185441'},
#     {'value': 'Q1250464'}],
#    'P610': [{'value': 'Q322824'}],
#    'P1464': [{'value': 'Q7463296',
#      'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]}],
#    'P1622': [{'value': 'Q14565199',
#      'references': [{'string': {'P854': ['http://chartsbin.com/view/edr']}}]}],
#    'P421': [{'value': 'Q25989',
#      'references': [{'wikibase-entityid': {'P143': ['Q206855']}}]},
#     {'value': 'Q6655'},
#     {'value': 'Q6723'},
#     {'value': 'Q207020'},
#     {'value': 'Q5412099'}],
#    'P150': [{'value': 'Q9337'},
#     {'value': 'Q240'},
#     {'value': 'Q9331'},
#     {'value': 'Q89959'},
#     {'value': 'Q90027'},
#     {'value': 'Q231'}],
#    'P138': [{'value': 'Q337104',
#      'references': [{'wikibase-entityid': {'P143': ['Q848525']}}]}],
#    'P163': [{'value': 'Q12990'}],
#    'P1343': [{'value': 'Q302556'},
#     {'value': 'Q2657718'},
#     {'value': 'Q4114391'},
#     {'value': 'Q602358'},
#     {'value': 'Q19211082'},
#     {'value': 'Q19180675'},
#     {'value': 'Q4173137'},
#     {'value': 'Q3181656'},
#     {'value': 'Q20078554'},
#     {'value': 'Q867541'},
#     {'value': 'Q15987490'}],
#    'P92': [{'value': 'Q633629'}],
#    'P6104': [{'value': 'Q14455339'}],
#    'P527': [{'value': 'Q234'},
#     {'value': 'Q231'},
#     {'value': 'Q240'},
#     {'value': 'Q9331'},
#     {'value': 'Q89959'},
#     {'value': 'Q90027'}],
#    'P1304': [{'value': 'Q685918'}],
#    'P2936': [{'value': 'Q100103'},
#     {'value': 'Q102172'},
#     {'value': 'Q2107617'},
#     {'value': 'Q3217332'},
#     {'value': 'Q7411'},
#     {'value': 'Q9051'},
#     {'value': 'Q188'},
#     {'value': 'Q150'},
#     {'value': 'Q34024'},
#     {'value': 'Q34219'},
#     {'value': 'Q430018'},
#     {'value': 'Q671198'},
#     {'value': 'Q151156'},
#     {'value': 'Q34147'},
#     {'value': 'Q1404296'},
#     {'value': 'Q815549'},
#     {'value': 'Q2668371'},
#     {'value': 'Q8641'},
#     {'value': 'Q33282'},
#     {'value': 'Q1793299'}],
#    'P2596': [{'value': 'Q792363'}],
#    'P7867': [{'value': 'Q8607310'}],
#    'P8402': [{'value': 'Q63413946'}],
#    'P1365': [{'value': 'Q15864',
#      'references': [{'wikibase-entityid': {'P3452': ['Q15864']}}]}],
#    'P8744': [{'value': 'Q1769535'}],
#    'P9241': [{'value': 'Q1996422'}]},
#   'quantity': {'P1082': [{'value': ('11150516', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2014-01-01']}}]},
#     {'value': ('11099554', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2013-01-01']}}]},
#     {'value': ('11035948', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2012-01-01']}}]},
#     {'value': ('10951266', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2011-01-01']}}]},
#     {'value': ('10839905', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2010-01-01']}}]},
#     {'value': ('10753080', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2009-01-01']}}]},
#     {'value': ('10666866', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2008-01-01']}}]},
#     {'value': ('10584534', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2007-01-01']}}]},
#     {'value': ('10511382', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2006-01-01']}}]},
#     {'value': ('10445852', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2005-01-01']}}]},
#     {'value': ('10396421', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2004-01-01']}}]},
#     {'value': ('10355844', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2003-01-01']}}]},
#     {'value': ('10309725', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2002-01-01']}}]},
#     {'value': ('10263414', 1),
#      'references': [{'wikibase-entityid': {'P123': ['Q12480']},
#        'time': {'P585': ['2001-01-01']}}]},
#     {'value': ('9153489', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9183948', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9220578', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9289770', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9378113', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9463667', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9527807', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9580991', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9618756', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9646032', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9655549', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9673162', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9711115', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9741720', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9772419', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9800700', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9818227', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9830358', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9839534', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9848382', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9859242', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9858982', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9856303', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9855520', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9855372', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9858308', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9861823', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9870234', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9901664', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9937697', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('9967379', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('10004486', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('10045158', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('10084475', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('10115603', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('10136811', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('10156637', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q21540096']}}]},
#     {'value': ('10181245', 1),
# ...
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.866', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.868', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.873', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.876', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.879', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.882', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.885', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.889', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.896', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.899', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.899', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.899', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.903', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.904', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.905', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.908', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.909', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.913', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.915', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]},
#     {'value': ('0.916', 1),
#      'references': [{'string': {'P854': ['http://hdr.undp.org/en/data']},
#        'wikibase-entityid': {'P248': ['Q1185686']}}]}],
#    'P1198': [{'value': ('8', 'Q11229'),
#      'references': [{'string': {'P854': ['http://data.worldbank.org/indicator/SL.UEM.TOTL.ZS']}}]}],
#    'P2884': [{'value': ('230', 'Q25250'),
#      'references': [{'wikibase-entityid': {'P143': ['Q48183']}}]}],
#    'P2250': [{'value': ('77.61951', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('77.72195', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('77.97317', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('78.07561', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('78.12927', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('78.87805', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('78.98049', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('79.38049', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('79.78293', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('79.68049', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('80.03415', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('80.18293', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('80.58537', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('80.38537', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('80.5878', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('81.2878', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]},
#     {'value': ('80.99268', 'Q577'),
#      'references': [{'string': {'P854': ['http://data.uis.unesco.org/Index.aspx?DataSetCode=DEMO_DS']},
#        'wikibase-entityid': {'P248': ['Q3152127']}}]}],
#    'P2046': [{'value': ('30528', 'Q712226'),
#      'references': [{'wikibase-entityid': {'P143': ['Q24237997']}}]}],
#    'P2927': [{'value': ('0.8', 'Q11229'),
#      'references': [{'string': {'P854': ['http://en.worldstat.info/World/List_of_countries_by_Water_surface_(percentage_of_total_area)']},
#        'time': {'P813': ['2016-08-02']}}]}],
#    'P5982': [{'value': ('44725', 1),
#      'references': [{'string': {'P854': ['https://statbel.fgov.be/fr/themes/population/mariages-et-divorces/mariages']},
#        'time': {'P813': ['2018-10-19']}},
#       {'string': {'P854': ['http://www.lalibre.be/actu/belgique/voici-le-nombre-de-mariages-et-divorces-par-communes-en-belgique-5a32911bcd700ea8c6f461b7']}}]},
#     {'value': ('45005', 1),
#      'references': [{'string': {'P854': ['https://statbel.fgov.be/fr/themes/population/mariages-et-divorces/mariages#figures']}}]},
#     {'value': ('44858', 1),
#      'references': [{'string': {'P854': ['https://statbel.fgov.be/fr/themes/population/mariages-et-divorces/mariages#figures']}}]}],
#    'P6897': [{'value': ('99', 'Q11229'),
#      'references': [{'string': {'P854': ['https://www.worldatlas.com/articles/the-highest-literacy-rates-in-the-world.html']}}]}],
#    'P3864': [{'value': ('20.7', 1),
#      'references': [{'string': {'P854': ['https://apps.who.int/gho/athena/data/xmart.csv?target=GHO/SDGSUICIDE,SDG_SH_STA_SCIDEN&profile=crosstable&filter=COUNTRY:*;REGION:*;AGEGROUP:-&x-sideaxis=COUNTRY;SEX&x-topaxis=GHO;YEAR']}}]},
#     {'value': ('20.1', 1),
#      'references': [{'string': {'P854': ['https://apps.who.int/gho/athena/data/xmart.csv?target=GHO/SDGSUICIDE,SDG_SH_STA_SCIDEN&profile=crosstable&filter=COUNTRY:*;REGION:*;AGEGROUP:-&x-sideaxis=COUNTRY;SEX&x-topaxis=GHO;YEAR']}}]},
#     {'value': ('21.3', 1),
#      'references': [{'string': {'P854': ['https://apps.who.int/gho/athena/data/xmart.csv?target=GHO/SDGSUICIDE,SDG_SH_STA_SCIDEN&profile=crosstable&filter=COUNTRY:*;REGION:*;AGEGROUP:-&x-sideaxis=COUNTRY;SEX&x-topaxis=GHO;YEAR']}}]},
#     {'value': ('21.2', 1),
#      'references': [{'string': {'P854': ['https://apps.who.int/gho/athena/data/xmart.csv?target=GHO/SDGSUICIDE,SDG_SH_STA_SCIDEN&profile=crosstable&filter=COUNTRY:*;REGION:*;AGEGROUP:-&x-sideaxis=COUNTRY;SEX&x-topaxis=GHO;YEAR']}}]},
#     {'value': ('22.7', 1),
#      'references': [{'string': {'P854': ['https://apps.who.int/gho/athena/data/xmart.csv?target=GHO/SDGSUICIDE,SDG_SH_STA_SCIDEN&profile=crosstable&filter=COUNTRY:*;REGION:*;AGEGROUP:-&x-sideaxis=COUNTRY;SEX&x-topaxis=GHO;YEAR']}}]}],
#    'P2855': [{'value': ('21', 'Q11229')}],
#    'P8328': [{'value': ('7.51', 1),
#      'references': [{'wikibase-entityid': {'P248': ['Q105264748']},
#        'time': {'P813': ['2021-11-14']}}]},
#     {'value': ('7.64', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]},
#     {'value': ('7.78', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]},
#     {'value': ('7.78', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]},
#     {'value': ('7.77', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]},
#     {'value': ('7.93', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]},
#     {'value': ('7.93', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]},
#     {'value': ('8.05', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]},
#     {'value': ('8.05', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]},
#     {'value': ('8.05', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]},
#     {'value': ('8.05', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]},
#     {'value': ('8.16', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]},
#     {'value': ('8.15', 1),
#      'references': [{'string': {'P854': ['https://github.com/xmarquez/democracyData/blob/master/data-raw/EIU%20Democracy%20Index%202020.csv']},
#        'time': {'P813': ['2021-11-15']}}]}],
#    'P8843': [{'value': ('14.8', 'Q11229'),
#      'references': [{'string': {'P854': ['https://data.worldbank.org/indicator/SI.POV.NAHC?']}}]}]},
#   'globecoordinate': {'P1333': [{'value': {'latitude': 49.497111111111,
#       'longitude': 5.4726111111111,
#       'altitude': None,
#       'precision': 2.7777777777778e-05,
#       'globe': 'http://www.wikidata.org/entity/Q2'}}],
#    'P1335': [{'value': {'latitude': 51.08972292,
#       'longitude': 2.54882813,
#       'altitude': None,
#       'precision': 0.0001,
#       'globe': 'http://www.wikidata.org/entity/Q2'}}],
#    'P1332': [{'value': {'latitude': 51.5,
#       'longitude': 4.77,
#       'altitude': None,
#       'precision': 1e-06,
#       'globe': 'http://www.wikidata.org/entity/Q2'}}],
#    'P1334': [{'value': {'latitude': 50.3358193,
#       'longitude': 6.40743256,
#       'altitude': None,
#       'precision': 0.0001,
#       'globe': 'http://www.wikidata.org/entity/Q2'}}],
#    'P625': [{'value': {'latitude': 50.641111111111,
#       'longitude': 4.6680555555556,
#       'altitude': None,
#       'precision': 0.00027777777777778,
#       'globe': 'http://www.wikidata.org/entity/Q2'}}],
#    'P5140': [{'value': {'latitude': 50.641111111111,
#       'longitude': 4.6680555555556,
#       'altitude': None,
#       'precision': 0.00027777777777778,
#       'globe': 'http://www.wikidata.org/entity/Q2'},
#      'references': [{'wikibase-entityid': {'P459': ['Q511093']}}]}]},
#   'monolingualtext': {'P1448': [{'value': 'Königreich Belgien'},
#     {'value': 'Kingdom of Belgium',
#      'references': [{'wikibase-entityid': {'P248': ['Q107602286']}}]},
#     {'value': 'Koninkrijk België'},
#     {'value': 'Royaume de Belgique'}],
#    'P1549': [{'value': 'Belg'},
#     {'value': 'Belgian'},
#     {'value': 'belga'},
#     {'value': 'Belgische'},
#     {'value': 'Belge',
#      'references': [{'string': {'P854': ['http://cnig.gouv.fr/wp-content/uploads/2020/02/CNT-PVM_r%C3%A9vis%C3%A9_2020-01-27-1.pdf']}}]},
#     {'value': 'Belgier'},
#     {'value': 'belgier'},
#     {'value': 'Belgiano'},
#     {'value': 'belgo'},
#     {'value': 'Belgänan'},
#     {'value': 'பெல்ஜியர்'},
#     {'value': 'Belgičan'},
#     {'value': 'بلجيكي'},
#     {'value': 'بلجيكية'},
#     {'value': 'بلجيكيون'},
#     {'value': 'бельгієць'},
#     {'value': 'бельгійка'},
#     {'value': 'бельгійці'},
#     {'value': 'бельгийцы'},
#     {'value': 'belga'},
#     {'value': 'בלגי'},
#     {'value': 'בלגית'},
#     {'value': 'belgieni'},
#     {'value': 'belgian'},
#     {'value': 'belgiancă'},
#     {'value': 'Belsch'},
#     {'value': 'Belsch'},
#     {'value': 'belga'},
#     {'value': 'belgi'},
#     {'value': 'belghe'},
#     {'value': '比利时'},
#     {'value': 'beljes'},
#     {'value': 'belgisk'},
#     {'value': 'belxicanu'},
#     {'value': 'belxicana'},
#     {'value': 'belga'},
#     {'value': 'belxicano'},
#     {'value': 'Bedje'},
#     {'value': 'Belgen'},
#     {'value': 'Belzje'},
#     {'value': 'belgijanac'},
#     {'value': 'belgijanka'},
#     {'value': 'belgijanci'},
#     {'value': 'belgijanke'},
#     {'value': 'Belgierin'},
#     {'value': 'بیلج'},
#     {'value': 'بیلج'},
#     {'value': 'belgo'},
#     {'value': 'belghe'},
#     {'value': 'belzi'},
#     {'value': 'belghi'}],
#    'P1813': [{'value': '🇧🇪'}],
#    'P1451': [{'value': 'Eendracht maakt macht'},
#     {'value': "L'union fait la force",
#      'references': [{'string': {'P854': ['https://www.belgium.be/en/about_belgium/country/belgium_in_nutshell/symbols/coats_of_arms']}}]},
#     {'value': 'Unity makes strength'},
#     {'value': 'La unión hace la fuerza'},
#     {'value': "Undod sy'n creu cryfder"},
#     {'value': 'La Unió fa la força'},
#     {'value': 'The place to be',
#      'references': [{'wikibase-entityid': {'P143': ['Q328']}}]}],
#    'P1705': [{'value': 'Koninkrijk België'},
#     {'value': 'Royaume de Belgique'},
#     {'value': 'Königreich Belgien'}]},
#   'time': {'P571': [{'value': '1830-10-04',
#      'references': [{'wikibase-entityid': {'P143': ['Q328']}}]}]}}}

# %%
# Get redirect of Belgium (Q31)
redirects = db.get_redirect_of("Q31")
redirects
# Out:
# ['Q2766311', 'Q19747260', 'Q15719907', 'Q20086775', 'Q25653510', 'Q25705716']

# %%
# Get redirect of
db.get_redirect(redirects[0])
# Out:
# 'Q31'

# %%
# Get instance of Belgium (Q31)
instance_ofs = db.get_instance_of("Q31")
for i, wd_id in enumerate(instance_ofs):
    print(f"{i}: {wd_id} - {db.get_label(wd_id)}")
# Out:
# 0: Q3624078 - sovereign state
# 1: Q43702 - federation
# 2: Q6256 - country
# 3: Q20181813 - colonial power
# 4: Q185441 - Member state of the European Union
# 5: Q1250464 - realm

# %% [markdown]
# Get subclass of

# %%
db.get_subclass_of("Q31")

# %% [markdown]
# Get all types of

# %%
types = db.get_all_types("Q31")
for i, wd_id in enumerate(types):
    print(f"{i}: {wd_id} - {db.get_label(wd_id)}")
# Out:
# 0: Q23958946 - individual entity
# 1: Q4406616 - concrete object
# 2: Q4393498 - representation
# 3: Q1319773 - consistency
# 4: Q7275 - state
# 5: Q2221906 - geographic location
# 6: Q100195948 - relative quality
# 7: Q61788060 - human activity
# 8: Q246672 - mathematical object
# 9: Q96196009 - state (former or current)
# 10: Q9200127 - member
# 11: Q7184903 - abstract object
# 12: Q35120 - entity
# 13: Q29651519 - mental object
# 14: Q5469988 - formalization
# 15: Q864377 - multiset
# 16: Q15916540 - semantic unit
# 17: Q22676603 - federal system
# 18: Q11028 - information
# 19: Q628523 - message
# 20: Q56061 - administrative territorial entity
# 21: Q1864008 - legal act
# 22: Q93288 - contract
# 23: Q327197 - legal transaction
# 24: Q16334298 - group of living things
# 25: Q4330518 - research object
# 26: Q43702 - federation
# 27: Q20937557 - series
# 28: Q27096213 - geographic entity
# 29: Q155076 - juridical person
# 30: Q1646605 - member state
# 31: Q386724 - work
# 32: Q183046 - meaning
# 33: Q1496967 - territorial entity
# 34: Q185441 - Member state of the European Union
# 35: Q15642541 - human-geographic territorial entity
# 36: Q618123 - geographical feature
# 37: Q2995644 - result
# 38: Q35459920 - three-dimensional object
# 39: Q184754 - string
# 40: Q1207505 - quality
# 41: Q1896989 - subject of international law
# 42: Q82794 - geographic region
# 43: Q2198779 - unit
# 44: Q36161 - set
# 45: Q106559804 - person or organization
# 46: Q234460 - text
# 47: Q41796 - sentence
# 48: Q76806512 - interstate agreement
# 49: Q3778211 - legal person
# 50: Q2135540 - legal action
# 51: Q1856757 - legal fact
# 52: Q203066 - relation
# 53: Q1063239 - polity
# 54: Q488383 - object
# 55: Q61961344 - group of physical objects
# 56: Q15401930 - product
# 57: Q26907166 - temporal entity
# 58: Q27096235 - artificial geographic entity
# 59: Q15621286 - intellectual work
# 60: Q1454986 - physical system
# 61: Q9332 - behavior
# 62: Q1554231 - resource
# 63: Q1048835 - political territorial entity
# 64: Q7887142 - unit of analysis
# 65: Q1914636 - activity
# 66: Q28813620 - set
# 67: Q223557 - physical object
# 68: Q3624078 - sovereign state
# 69: Q1150771 - output
# 70: Q99527517 - collective entity
# 71: Q31464082 - source
# 72: Q108163 - proposition
# 73: Q3505845 - state
# 74: Q103940464 - continuant
# 75: Q3924032 - mathematical property
# 76: Q177634 - community
# 77: Q937228 - property
# 78: Q16887380 - group
# 79: Q37866906 - information resource
# 80: Q42848 - data
# 81: Q16686448 - artificial entity
# 82: Q4897819 - role
# 83: Q830077 - subject
# 84: Q451967 - intentional human activity
# 85: Q16889133 - class
# 86: Q16334295 - group of humans
# 87: Q107435521 - record
# 88: Q7048977 - non-physical entity
# 89: Q5371079 - emic unit
# 90: Q43229 - organization
# 91: Q20817253 - linguistic unit
# 92: Q2006324 - agreement
# 93: Q58416391 - spatial entity
# 94: Q20181813 - colonial power
# 95: Q28108 - political system
# 96: Q26720107 - subject of a right
# 97: Q24229398 - agent
# 98: Q3769299 - human behavior
# 99: Q58778 - system
# 100: Q286583 - manifestation
# 101: Q874405 - social group
# 102: Q1786828 - constituent
# 103: Q98119401 - group or class of physical objects
# 104: Q9380010 - denunciation
# 105: Q930933 - relation
# 106: Q474328 - declarative sentence
# 107: Q1639378 - social system
# 108: Q1250464 - realm
# 109: Q47461344 - written work
# 110: Q483247 - phenomenon
# 111: Q4164871 - position
# 112: Q214339 - role
# 113: Q6256 - country
# 114: Q1190554 - occurrence
# 115: Q58415929 - spatio-temporal entity
# 116: Q17334923 - location
# 117: Q8205328 - artificial physical object
# 118: Q49848 - document
# 119: Q188572 - fact
# 120: Q202722 - consensus
# 121: Q16877783 - meaning
# 122: Q30060700 - scientific object
# 123: Q7210356 - political organization
# 124: Q321839 - agreement
# 125: Q217594 - class
# 126: Q2684591 - statement
# 127: Q183366 - territory
# 128: Q17537576 - creative work
# 129: Q6671777 - structure

# %% [markdown]
# Get properties between two Wikidata items

# %%
properties = db.get_properties_from_head_qid_tail_qid("Q1490", "Q17")
for i, wd_id in enumerate(properties):
    print(f"{i+1}: {wd_id} - {db.get_label(wd_id)}")
# Out:
# 1: P17 - country
# 2: P131 - located in the administrative territorial entity
# 3: P1376 - capital of

# %% [markdown]
# ### 2. Get Provenance nodes

# %%
# Print provenance list
def print_provenance_list(iter_obj, top=3):
    for i, provenance in enumerate(iter_obj):
        if i > top:
            break
        subject = provenance["subject"]
        predicate = provenance["predicate"]
        value = provenance["value"]
        reference_node = provenance["reference"]
        print(
            f"{i+1}: <{subject}[{db.get_label(subject)}] - {predicate}[{db.get_label(predicate)}] - {value}>"
        )
        print(f"  Reference Node:")
        for ref_type, ref_objs in reference_node.items():
            for ref_prop, ref_v in ref_objs.items():
                print(f"    {ref_prop}[{db.get_label(ref_prop)}]: {ref_v}")
    print()


# Get provenance of Belgium (Q31)
print_provenance_list(db.iter_provenances("Q31"))
# Get provenance of Belgium (Q31), and Tokyo (Q1490)
print_provenance_list(db.iter_provenances(["Q31", "Q1490"]))
# Get provenance of all items
print_provenance_list(db.iter_provenances())
# Out:
# 1: <Q31[Belgium] - P2581[BabelNet ID] - 00009714n>
#   Reference Node:
#     P248[stated in]: ['Q4837690']
# 2: <Q31[Belgium] - P227[GND ID] - 4005406-8>
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q48183']
# 3: <Q31[Belgium] - P982[MusicBrainz area ID] - 5b8a5ee5-0bb3-34cf-9a75-c27c44e341fc>
#   Reference Node:
#     P248[stated in]: ['Q14005']
# 4: <Q31[Belgium] - P2981[UIC alphabetical country code] - B>
#   Reference Node:
#     P854[reference URL]: ['http://otif.org/fileadmin/user_upload/otif_verlinkte_files/06_tech_zulass/05_Reglementation_en_vigueur/Neu_ab_01_01_2015/UTP_MARKING_2015_e_in_force.pdf']
#
# 1: <Q31[Belgium] - P2581[BabelNet ID] - 00009714n>
#   Reference Node:
#     P248[stated in]: ['Q4837690']
# 2: <Q31[Belgium] - P227[GND ID] - 4005406-8>
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q48183']
# 3: <Q31[Belgium] - P982[MusicBrainz area ID] - 5b8a5ee5-0bb3-34cf-9a75-c27c44e341fc>
#   Reference Node:
#     P248[stated in]: ['Q14005']
# 4: <Q31[Belgium] - P2981[UIC alphabetical country code] - B>
#   Reference Node:
#     P854[reference URL]: ['http://otif.org/fileadmin/user_upload/otif_verlinkte_files/06_tech_zulass/05_Reglementation_en_vigueur/Neu_ab_01_01_2015/UTP_MARKING_2015_e_in_force.pdf']
#
# 1: <Q1[universe] - P373[Commons category] - Universe>
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q328']
# 2: <Q1[universe] - P18[image] - Hubble ultra deep field.jpg>
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q48183']
#     P4656[Wikimedia import URL]: ['https://de.wikipedia.org/w/index.php?title=Universum&oldid=211589784']
#     P813[retrieved]: ['2021-05-22']
# 3: <Q1[universe] - P18[image] - CMB Timeline300 no WMAP.jpg>
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q328']
#     P4656[Wikimedia import URL]: ['https://en.wikipedia.org/w/index.php?title=Universe&oldid=1023252612']
#     P813[retrieved]: ['2021-05-22']
# 4: <Q1[universe] - P18[image] - NASA-HS201427a-HubbleUltraDeepField2014-20140603.jpg>
#   Reference Node:
#     P143[imported from Wikimedia project]: ['Q328']
#     P4656[Wikimedia import URL]: ['https://en.wikipedia.org/w/index.php?title=Universe&oldid=1023252612']
#     P813[retrieved]: ['2021-05-22']

# %% [markdown]
# Get references of a statement

# %%
db.print_get_provenances_from_statement("Q1490", "P17", "Q17")
db.print_get_provenances_from_statement("Q1490", "P1082", 14049146)
# Out:
# Q1490[Tokyo] - P17[country] - Q17[Japan]
#  + Reference:
#    - P143[imported from Wikimedia project] - Q328[English Wikipedia]
# Q1490[Tokyo] - P1082[population] - 14049146
#  + Reference:
#    - P143[imported from Wikimedia project] - Q177837[Japanese Wikipedia]
#    - P364[original language of film or TV show] - Q5287[Japanese]
#    - P1476[title] - 東京都の人口（推計）トップページ

# %% [markdown]
# Wikidata provenances stats

# %%
from collections import Counter
from tqdm.notebook import tqdm

c_entities = 0
c_facts = 0
c_refs = 0
ref_types = Counter()
ref_props = Counter()
ref_props_c = 0
ref_types_c = 0


def update_desc():
    return f"Facts:{c_facts:,}|Refs:{c_refs:,}"

step = 10000
for wd_id, claims in tqdm(db.iter_item_provenances(), total=db.size()):
    c_entities += 1
    for claim_type, claim_objs in claims.items():
        for claim_prop, claim_values in claim_objs.items():
            for claim_value in claim_values:
                c_facts += 1
                refs = claim_value.get("references")
                if not refs:
                    continue
                for reference_node in refs:
                    c_refs += 1
                    for ref_type, ref_objs in reference_node.items():
                        ref_types_c += 1
                        ref_types[ref_type] += 1
                        for ref_prop in ref_objs.keys():
                            ref_props_c += 1
                            ref_props[ref_prop] += 1

print("Reference node stats")
print(f"Items: {c_entities:,} entities")
print(f"Facts: {c_facts:,} facts, {c_facts/c_entities:.2f} facts/entity")
print(f"References: {c_refs:,} references, {c_refs/c_facts:.2f} references/fact")

print("\nReference stats:")
print(f"Types/reference: {ref_types_c / c_refs:.2f}")
print(f"Properties/reference: {ref_props_c / c_refs:.2f}")


def print_top(counter_obj, total, top=100, message="", get_label=False):
    print(f"Top {top} {message}: ")
    top_k = sorted(counter_obj.items(), key=lambda x: x[1], reverse=True)[:top]
    for i, (obj, obj_c) in enumerate(top_k):
        if get_label:
            obj = f"{obj}\t{db.get_label(obj)}"
        print(f"{i+1}\t{obj_c:,}\t{obj_c/total*100:.2f}%\t{obj}")


print_top(ref_types, total=c_refs, message="types")
print_top(ref_props, total=c_refs, message="properties", get_label=True)
# Out:
#   0%|          | 0/99774350 [00:00<?, ?it/s]
# Reference node stats
# Items: 90,390,635 entities
# Facts: 1,402,155,075 facts, 15.51 facts/entity
# References: 1,091,434,781 references, 0.78 references/fact
#
# Reference stats:
# Types/reference: 2.83
# Properties/reference: 2.83
# Top 100 types:
# 1	1,055,489,692	96.71%	wikibase-entityid
# 2	818,793,432	75.02%	time
# 3	807,716,741	74.01%	string
# 4	5,615,919	0.51%	monolingualtext
# 5	4,026	0.00%	quantity
# 6	587	0.00%	globecoordinate
# Top 100 properties:
# 1	974,966,659	89.33%	P248	stated in
# 2	807,324,817	73.97%	P813	retrieved
# 3	640,589,738	58.69%	P854	reference URL
# 4	334,260,209	30.63%	P698	PubMed ID
# 5	101,059,502	9.26%	P887	based on heuristic
# 6	67,105,515	6.15%	P932	PMCID
# 7	62,197,526	5.70%	P143	imported from Wikimedia project
# 8	13,331,745	1.22%	P577	publication date
# 9	8,730,465	0.80%	P4656	Wikimedia import URL
# 10	7,123,102	0.65%	P351	Entrez Gene ID
# 11	5,537,881	0.51%	P1476	title
# 12	5,217,339	0.48%	P214	VIAF ID
# 13	4,742,407	0.43%	P352	UniProt protein ID
# 14	4,612,229	0.42%	P2326	GNS Unique Feature ID
# 15	4,481,609	0.41%	P1640	curator
# 16	4,143,730	0.38%	P459	determination method
# 17	3,965,816	0.36%	P1810	named as
# 18	3,704,081	0.34%	P407	language of work or name
# 19	3,366,184	0.31%	P3452	inferred from
# 20	2,076,479	0.19%	P590	GNIS ID
# 21	1,624,138	0.15%	P594	Ensembl gene ID
# 22	1,623,903	0.15%	P227	GND ID
# 23	1,402,903	0.13%	P123	publisher
# 24	1,163,723	0.11%	P7793	filename in archive
# 25	1,142,243	0.10%	P662	PubChem CID
# 26	1,111,101	0.10%	P4638	The Peerage person ID
# 27	956,993	0.09%	P9300	Terezín Memorial Database ID
# 28	914,705	0.08%	P356	DOI
# 29	880,685	0.08%	P691	NKCR AUT ID
# 30	871,244	0.08%	P3289	Cellosaurus ID
# 31	853,584	0.08%	P5017	last update
# 32	815,872	0.07%	P3181	OpenCitations bibliographic resource ID
# 33	760,028	0.07%	P496	ORCID iD
# 34	657,175	0.06%	P304	page(s)
# 35	597,892	0.05%	P268	Bibliothèque nationale de France ID
# 36	596,275	0.05%	P9109	Holocaust.cz person ID
# 37	527,660	0.05%	P1065	archive URL
# 38	497,682	0.05%	P236	ISSN
# 39	497,066	0.05%	P1440	FIDE player ID
# 40	453,946	0.04%	P434	MusicBrainz artist ID
# 41	433,777	0.04%	P1216	National Heritage List for England number
# 42	405,277	0.04%	P1047	Catholic Hierarchy person ID
# 43	404,633	0.04%	P3937	Reactome ID
# 44	370,537	0.03%	P6786	National Library of Wales Catalogue ID
# 45	330,533	0.03%	P2960	archive date
# 46	320,694	0.03%	P593	HomoloGene ID
# 47	317,815	0.03%	P2646	mirTarBase ID
# 48	301,808	0.03%	P2253	DfE URN
# 49	283,597	0.03%	P2427	GRID ID
# 50	269,357	0.02%	P585	point in time
# 51	268,131	0.02%	P2163	FAST ID
# 52	266,386	0.02%	P686	Gene Ontology ID
# 53	264,095	0.02%	P705	Ensembl protein ID
# 54	263,577	0.02%	P6844	abART person ID
# 55	259,760	0.02%	P9789	Yale Center for British Art artwork Lido ID
# 56	249,946	0.02%	P345	IMDb ID
# 57	220,173	0.02%	P3318	Guía Digital del Patrimonio Cultural de Andalucía identifier
# 58	220,113	0.02%	P6736	Drobné památky ID
# 59	219,875	0.02%	P3430	SNAC ARK ID
# 60	208,341	0.02%	P683	ChEBI ID
# 61	202,482	0.02%	P4663	DACS ID
# 62	195,521	0.02%	P1932	stated as
# 63	193,828	0.02%	P4525	MuIS object ID
# 64	190,020	0.02%	P1683	quotation
# 65	184,571	0.02%	P217	inventory number
# 66	183,372	0.02%	P2249	RefSeq genome ID
# 67	181,918	0.02%	P2880	NIOSHTIC-2 ID
# 68	174,224	0.02%	P627	IUCN taxon ID
# 69	171,683	0.02%	P652	UNII
# 70	143,924	0.01%	P235	InChIKey
# 71	141,887	0.01%	P661	ChemSpider ID
# 72	138,232	0.01%	P2926	InterPro ID
# 73	137,781	0.01%	P724	Internet Archive ID
# 74	137,165	0.01%	P2477	BDRC Resource ID
# 75	136,419	0.01%	P4075	Czech Monument Catalogue Number
# 76	132,141	0.01%	P1866	Catholic Hierarchy diocese ID
# 77	130,039	0.01%	P958	section, verse, paragraph, or clause
# 78	126,474	0.01%	P5270	MonDO ID
# 79	126,387	0.01%	P792	chapter
# 80	125,446	0.01%	P2446	Transfermarkt player ID
# 81	122,342	0.01%	P699	Disease Ontology ID
# 82	122,295	0.01%	P650	RKDartists ID
# 83	120,727	0.01%	P535	Find A Grave memorial ID
# 84	120,468	0.01%	P4327	BHL bibliography ID
# 85	114,190	0.01%	P1850	SSR place name number
# 86	109,790	0.01%	P50	author
# 87	97,872	0.01%	P1953	Discogs artist ID
# 88	97,168	0.01%	P7411	Pubs Galore ID
# 89	96,390	0.01%	P1207	NUKAT ID
# 90	92,728	0.01%	P2566	ECHA InfoCard ID
# 91	90,292	0.01%	P244	Library of Congress authority ID
# 92	90,276	0.01%	P8433	Swedish Riksdag document ID
# 93	90,026	0.01%	P402	OpenStreetMap relation ID
# 94	88,960	0.01%	P586	IPNI author ID
# 95	86,571	0.01%	P6184	reference has role
# 96	81,764	0.01%	P1402	Foundational Model of Anatomy ID
# 97	80,978	0.01%	P245	Union List of Artist Names ID
# 98	75,325	0.01%	P638	PDB structure ID
# 99	74,520	0.01%	P1871	CERL Thesaurus ID
# 100	74,291	0.01%	P3517	Geographical Names Board of NSW ID

# %% [markdown]
# ### 3. Attribute Item Search (boolean search)
# Find subset of entities (head entities) with information about tail entities and properties (triples: <head entities, property, tail entities>)

# %%
import time
import config as cf
def find_wikidata_items_haswbstatements(params, print_top=3, get_qid=True):
    start = time.time()
    wd_ids = db.get_haswbstatements(params, get_qid=get_qid)
    end = time.time() - start
    print("Query:")
    for logic, prop, qid in params:
        if prop is None:
            prop_label = " - None "
        else:
            prop_label = f" - {prop} [{db.get_label(prop)}]"

        qid_label = db.get_label(qid)
        print(f"{logic}{prop_label} - {qid} [{qid_label}]")

    print(f"Answers: Found {len(wd_ids):,} items in {end:.5f}s")
    for i, wd_id in enumerate(wd_ids[:print_top]):
        print(f"{i+1}. {wd_id} - {db.get_label(wd_id)}")
    print(f"{4}. ...")
    print()

# %% [markdown]
# Get all female (Q6581072)

# %%
find_wikidata_items_haswbstatements(
    [
        ["AND", None, "Q6581072"]
    ]
)
# Out:
# Query:
# AND - None  - Q6581072 [female]
# Answers: Found 1,874,319 items in 2.46141s
# 1. Q814 - Coco Austin
# 2. Q873 - Meryl Streep
# 3. Q839 - Georgina Cassar
# 4. ...

# %% [markdown]
# Get all female (Q6581072) using local IDs

# %%
find_wikidata_items_haswbstatements(
    [
        ["AND", None, "Q6581072"]
    ],
    get_qid=False
)
# Out:
# Query:
# AND - None  - Q6581072 [female]
# Answers: Found 1,874,319 items in 0.00490s
# 1. 247 - Coco Austin
# 2. 269 - Meryl Streep
# 3. 301 - Georgina Cassar
# 4. ...

# %% [markdown]
# Get all male (Q6581097)

# %%
find_wikidata_items_haswbstatements(
    [
        ["AND", None, "Q6581097"]
    ],
    get_qid=False
)
# Out:
# Query:
# AND - None  - Q6581097 [male]
# Answers: Found 5,868,897 items in 0.01211s
# 1. 24 - Tim Berners-Lee
# 2. 31 - Barack Obama
# 3. 45 - Douglas Adams
# 4. ...

# %% [markdown]
# Get all entities who are human, male, educated at Todai, and work at Graduate University for Advanced Studies

# %%
find_wikidata_items_haswbstatements(
    [
        # instance of - human
        ["AND", "P31", "Q5"],
        # gender - male
        ["AND", "P21", "Q6581097"],
        # educated at - Todai
        ["AND", "P69", "Q7842"],
        # employer - Graduate University for Advanced Studies
        ["AND", "P108", "Q2983844"],
    ]
)
# Out:
# Query:
# AND - P31 [instance of] - Q5 [human]
# AND - P21 [sex or gender] - Q6581097 [male]
# AND - P69 [educated at] - Q7842 [University of Tokyo]
# AND - P108 [employer] - Q2983844 [Graduate University for Advanced Studies]
# Answers: Found 28 items in 0.01309s
# 1. Q1620298 - Hirotaka Sugawara
# 2. Q1737903 - Keiichi Kodaira
# 3. Q8056214 - Ōsumi Yoshinori
# 4. ...

# %% [markdown]
# Get all entities that have relation with human, male, Todai, and SOKENDAI

# %%
find_wikidata_items_haswbstatements(
    [
        # instance of - human
        ["AND", None, "Q5"],
        # gender - male
        ["AND", None, "Q6581097"],
        # educated at - Todai
        ["AND", None, "Q7842"],
        # employer - Graduate University for Advanced Studies
        ["AND", None, "Q2983844"],
    ]
)
# Out:
# Query:
# AND - None  - Q5 [human]
# AND - None  - Q6581097 [male]
# AND - None  - Q7842 [University of Tokyo]
# AND - None  - Q2983844 [Graduate University for Advanced Studies]
# Answers: Found 34 items in 0.01123s
# 1. Q758600 - Tatsuya Horita
# 2. Q1620298 - Hirotaka Sugawara
# 3. Q1737903 - Keiichi Kodaira
# 4. ...

# %% [markdown]
# Get all entities that have relation with scholarly article or DNA, X-ray diffraction, and Francis Crick and Nature

# %%
find_wikidata_items_haswbstatements(
    [
        # ? - scholarly article
        ["AND", None, "Q13442814"],
        # ? - DNA
        ["OR", None, "Q7430"],
        # ? - X-ray diffraction
        ["OR", None, "Q12101244"],
        # ? - DNA
        ["OR", None, "Q911331"],
        # Francis Crick
        ["AND", None, "Q123280"],
        # ? - Nature
        ["AND", None, "Q180445"],
    ]
)
# Out:
# Query:
# AND - None  - Q13442814 [scholarly article]
# OR - None  - Q7430 [DNA]
# OR - None  - Q12101244 [X-ray diffraction]
# OR - None  - Q911331 [molecular geometry]
# AND - None  - Q123280 [Francis Crick]
# AND - None  - Q180445 [Nature]
# Answers: Found 46 items in 0.01536s
# 1. Q1895685 - Molecular Structure of Nucleic Acids: A Structure for Deoxyribose Nucleic Acid
# 2. Q40010403 - Letter: Molecular structure of NAD.
# 3. Q49026943 - X-ray diffraction study of the interaction of phospholipids with cytochrome c in the aqueous phase.
# 4. ...

# %% [markdown]
# ### 4. Keyword item search

# %%
from core.keyword_search import KeywordSearch
searcher = KeywordSearch()
queries = [
        "Sweden",
        "TV-Browser",
        "hideaki takeda",
        "HIdeki Tedaka",
        "2MASS J10540655-0031018",
        "Tokyo",
        "武田英明",
        "Град Скопјее",
        "Préfecture de Kanagawa",
        "Paulys Realenzyklopädie der klassischen Altertumswissenschaft",
        "La gran bretaña",
        "제주 유나이티드 FC",
        "অ্যাটলেটিকো ডি কলকাতা",
        "Nguyễn Ái Quốc",
        "ホー・チ・ミン",
    ]
modes = ["a"]  # "a", "b", "f"
lang_opts = ["en"]  # "en", "all"
expensive_opts = [0]  # 0, 1
info = 1 # get entity information
for query in queries:
        for mode in modes:
            for lang in lang_opts:
                for expensive in expensive_opts:
                    responds, run_time = searcher.get(query, limit=20, mode=mode, lang=lang, expensive=expensive, info=info)
                    print(f"\n[{lang}|{mode}|{expensive}] About {len(responds)} results in {run_time:.4f} seconds | {query}")

                    if info:
                        for i, (r, s, l, d) in enumerate(responds[:3]):
                            print(f"{i + 1:2}. {s:.4f} - {r}[{l}] - {d}")
                    else:
                        for i, (r, s) in enumerate(responds[:3]):
                            print(f"{i+1:2}. {s:.4f} - {r}[]")
# Out:
# [en|a|0] About 20 results in 0.4505 seconds | Sweden
#  1. 0.2512 - Q34[Sweden] - sovereign state in northern Europe
#  2. 0.2485 - Q99282565[Sweden] - the country of Sweden as depicted in Star Trek
#  3. 0.2484 - Q7654285[Sweden] - 1995 studio album by music group Mountain Goats
#
# [en|a|0] About 20 results in 0.1791 seconds | TV-Browser
#  1. 0.4839 - Q1715028[TV-Browser] - electronic program guide (tv, radio)
#  2. 0.0812 - Q11334456[Browser] - None
#  3. 0.0806 - Q104574429[browser] - type of software dedicated to browse items
#
# [en|a|0] About 20 results in 0.1131 seconds | hideaki takeda
#  1. 0.5823 - Q2330082[Hideaki Takeda] - Japanese association football player
#  2. 0.5823 - Q57886243[Hideaki Takeda] - informatics researcher, National Institute of Informatics, Japan
#  3. 0.0807 - Q65030936[Hideaki Yamada] - Japanese cross-country skier
#
# [en|a|0] About 20 results in 0.0721 seconds | HIdeki Tedaka
#  1. 0.3727 - Q4924099[Hideki Todaka] - Japanese boxer
#  2. 0.2135 - Q5354164[Hideki Tasaka] - Japanese voice actor
#  3. 0.2132 - Q3545942[Hideki Takahashi] - Japanese actor
#
# [en|a|0] About 20 results in 0.5685 seconds | 2MASS J10540655-0031018
#  1. 0.3512 - Q222120[2MASS J00540655-0031018] - brown dwarf
#  2. 0.2115 - Q87130330[TYC 4151-458-1] - None
#  3. 0.0298 - Q84765954[TYC 132-926-1] - star in the constellation Orion
#
# [en|a|0] About 20 results in 0.3103 seconds | Tokyo
#  1. 0.2397 - Q1490[Tokyo] - capital and most populous prefecture of Japan
#  2. 0.2386 - Q65120889[Tokyo] - 2019 single by White Lies
#  3. 0.2385 - Q7813799[Tokyo] - novel by Mo Hayder
#
# [en|a|0] About 20 results in 0.2804 seconds | 武田英明
#  1. 0.4455 - Q2330082[Hideaki Takeda] - Japanese association football player
#  2. 0.4455 - Q57886243[Hideaki Takeda] - informatics researcher, National Institute of Informatics, Japan
#  3. 0.0284 - Q27920828[Akira Takeda] - Japanese folklorist
#
# [en|a|0] About 20 results in 0.1777 seconds | Град Скопјее
#  1. 0.3684 - Q2575820[Greater Skopje] - administrative division within the Republic of Macedonia constituted of 10 municipalities
#  2. 0.2096 - Q1065374[Grad, Grad] - human settlement
#  3. 0.0293 - Q515[city] - large permanent human settlement
#
# [en|a|0] About 12 results in 0.3238 seconds | Préfecture de Kanagawa
#  1. 0.5807 - Q127513[Kanagawa Prefecture] - prefecture of Japan
#  2. 0.0771 - Q10215446[Q10215446] - Wikimedia category
#  3. 0.0284 - Q22800872[Q22800872] - Wikimedia template
#
# [en|a|0] About 10 results in 0.3096 seconds | Paulys Realenzyklopädie der klassischen Altertumswissenschaft
#  1. 0.5781 - Q1138524[Paulys Realenzyklopädie der klassischen Altertumswissenschaft] - extensive and comprehensive German encyclopedia of classical scholarship
#  2. 0.0038 - Q47459707[Paulys Realencyclopädie der classischen Altertumswissenschaft] - document published in 1997
#  3. 0.0014 - Q20727924[Paulys Realencyclopädie der classischen Altertumswissenschaft/Autoren] - Wikimedia list article
#
# [en|a|0] About 20 results in 0.2015 seconds | La gran bretaña
#  1. 0.2331 - Q60748786[La Gran Cruzada] - None
#  2. 0.2331 - Q20807651[La Gran Cruzada] - 2015 International Wrestling Revolution Group event
#  3. 0.2331 - Q16212931[La Gran Cruzada] - 2011 International Wrestling Revolution Group event
#
# [en|a|0] About 13 results in 0.1448 seconds | 제주 유나이티드 FC
#  1. 0.5782 - Q482617[Jeju United FC] - football club in South Korea
#  2. 0.5782 - Q16842231[Jeju United FC in Asian football] - None
#  3. 0.0284 - Q4591117[1996-2005 Jeju United FC (Bucheon Yukong / Bucheon SK) seasons] - South Korean football seasons
#
# [en|a|0] About 20 results in 0.1449 seconds | অ্যাটলেটিকো ডি কলকাতা
#  1. 0.5786 - Q16836329[ATK] - association football club
#  2. 0.0772 - Q104523027[Bheshe Ashey Kolkata] - song by Moheener Ghoraguli
#  3. 0.0104 - Q5203547[D. D. Daniel] - Indian politician
#
# [en|a|0] About 20 results in 0.1139 seconds | Nguyễn Ái Quốc
#  1. 0.4459 - Q36014[Ho Chi Minhhhhj] - Vietnamese communist leader and Chairman of the Workers' Party of Vietnam (1890-1969)
#  2. 0.4459 - Q19661055[Nguyễn Thị Thanh] - Sister of Ho Chi Minh
#  3. 0.4455 - Q10841005[The Revolutionary Road] - Revolution work of Ho Chi Minh
#
# [en|a|0] About 20 results in 0.0929 seconds | ホー・チ・ミン
#  1. 0.5784 - Q36014[Ho Chi Minhhhhj] - Vietnamese communist leader and Chairman of the Workers' Party of Vietnam (1890-1969)
#  2. 0.5784 - Q19661055[Nguyễn Thị Thanh] - Sister of Ho Chi Minh
#  3. 0.0771 - Q7410171[Category:Ho Chi Minh] - Wikimedia category
